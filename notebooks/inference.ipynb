# %%
from minecraft_schematic_generator.converter import SchematicArrayConverter
from minecraft_schematic_generator.modules import LightningTransformerMinecraftStructureGenerator

experiment_name = 'center_data'
model_version = 13
# checkpoint_path = f'../lightning_logs/{experiment_name}/version_{model_version}/checkpoints/epoch=20-step=3096980 copy 2.ckpt'
checkpoint_path = f'../lightning_logs/{experiment_name}/version_{model_version}/checkpoints/last.ckpt'
model = LightningTransformerMinecraftStructureGenerator.load_from_checkpoint(
    checkpoint_path)
model.eval()

converter = SchematicArrayConverter()

# %%
import os

from minecraft_schematic_generator.converter import SchematicArrayConverter
from minecraft_schematic_generator.modules.data_module import MinecraftDataModule

hdf5_file = '../data/data_v2.h5'
data_module = MinecraftDataModule(
    file_path=hdf5_file,
    batch_size=1,
    # num_workers=4
)

data_module.setup(index=1)
val_dataloaders = data_module.val_dataloader()
# val_dataloaders = [data_module.train_dataloader()]
schematic_array_converter = SchematicArrayConverter()
# Out:
# Loading training datasets: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Loading validation datasets: 100%|██████████| 1/1 [00:00<00:00,  6.96it/s]
# Loading test datasets: 100%|██████████| 1/1 [00:00<00:00,  7.63it/s]

# %%
import random
from pathlib import Path

# Pick a random validation dataloader
dataloader = random.choice(val_dataloaders)
i = val_dataloaders.index(dataloader)
dataset = data_module.val_datasets[i][1]

# Pick a random sample from the dataloader
i = random.randint(0, len(dataset) - 1)
full_structure, masked_structure = dataset[i]

full_structure_schematic = schematic_array_converter.array_to_schematic(full_structure)
full_structure_schematic.name = 'Test'
full_structure_schematic.save_to_file(Path('full_structure.schem'), 2)

# Fill the masked positions with pink stained glass for visualization
masked_structure_visual = masked_structure.clone()
masked_structure_visual[masked_structure == 0] = 1

masked_structure_schematic = schematic_array_converter.array_to_schematic(masked_structure_visual)
masked_structure_schematic.name = 'Test'

# Save the sample
masked_structure_schematic.save_to_file(Path('masked_structure.schem'), 2)

# %%
import torch
import torch.nn.functional as F

# Fill the masked positions with pink stained glass for visualization
masked_structure = dataset._mask_structure(full_structure)
masked_structure_visual = masked_structure.clone()

kernel = torch.ones((1, 1, 3, 3, 3), dtype=masked_structure_visual.dtype, device=masked_structure_visual.device)
kernel[0, 0, 1, 1, 1] = 0  # Ignore the central element

# Create a mask of elements greater than 1
greater_than_1 = masked_structure_visual > 1
print(greater_than_1.sum())

# Convolve to count neighbors that are greater than 1
greater_than_1 = greater_than_1.unsqueeze(0).unsqueeze(0)
neighbors_greater_than_1 = F.conv3d(
    greater_than_1.float(), kernel.float(), padding=1) >= 1
neighbors_greater_than_1 = neighbors_greater_than_1.squeeze(0).squeeze(0)
print(neighbors_greater_than_1.sum())

# Create a mask for elements that are 0
is_zero = masked_structure_visual == 0
print(is_zero.sum())

# Combine the masks
mask = neighbors_greater_than_1 & is_zero
print(mask.sum())

masked_structure_visual[masked_structure == 0] = 2173
masked_structure_visual[mask == 1] = 456
masked_structure_schematic = schematic_array_converter.array_to_schematic(masked_structure_visual)
masked_structure_schematic.name = 'Test'

# Save the sample
masked_structure_schematic.save_to_file(Path('masked_structure.schem'), 2)
# Out:
# tensor(695)
# tensor(1137)
# tensor(636)
# tensor(442)

# %%
import torch

# Prepare the masked structure for the model
filled_structure = masked_structure.clone()
filled_structure = filled_structure.to(model.device)
filled_structure = filled_structure.view(-1)
filled_structure[filled_structure == 1] = 0
filled_structure = filled_structure.unsqueeze(0)

# Inference
filled_structure = model(filled_structure)

# Convert the output
filled_structure = filled_structure.squeeze(0)
filled_structure = torch.argmax(filled_structure, dim=0)
filled_structure = filled_structure.view(masked_structure.size())

filled_structure_schematic = schematic_array_converter.array_to_schematic(
    filled_structure)
filled_structure_schematic.name = 'Test'

# Save the sample
filled_structure_schematic.save_to_file(Path('filled_structure.schem'), 2)
# Out:
# c:\Users\mmmfr\Documents\Repositories\minecraft-schematic-generator\.venv\Lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)

# %%
import time

filled_structure = masked_structure.clone()

# Remove air
filled_structure[filled_structure == 1] = 0

# Generate a sample using the model
start_time = time.time()
for predicted_token, z, y, x in model.fill_structure(filled_structure, temperature=0.7, start_radius=1, max_iterations=5, max_blocks=50, air_probability_iteration_scaling=0.0):
    print(f'({z}, {y}, {x}): {predicted_token}')
    filled_structure[z, y, x] = predicted_token
end_time = time.time()
print(f'Generation time: {end_time - start_time}')

filled_structure[filled_structure == 0] = 2173

filled_structure_schematic = schematic_array_converter.array_to_schematic(
    filled_structure)
filled_structure_schematic.name = 'Test'

# Save the sample
filled_structure_schematic.save_to_file(Path('filled_structure.schem'), 2)
# Out:
# Iteration 1/5
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 5, 4): 4
# Filled 1/5000 blocks
# Selected token 4 with probability 99.1%, air probability 0.0%
# (6, 4, 5): 4
# Filled 2/5000 blocks
# Selected token 12 with probability 95.3%, air probability 0.0%
# (5, 4, 6): 12
# Filled 3/5000 blocks
# Selected token 12 with probability 30.2%, air probability 0.0%
# (4, 4, 5): 12
# Filled 4/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 4, 4): 4
# Filled 5/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 6, 6): 4
# Filled 6/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 6, 3): 4
# Filled 7/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 5, 7): 4
# Filled 8/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (5, 3, 4): 12
# Filled 9/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (3, 4, 5): 12
# Filled 10/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 7, 4): 4
# Filled 11/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 4, 3): 4
# Filled 12/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (7, 4, 4): 4
# Filled 13/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 6, 3): 4
# Filled 14/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 7, 6): 4
# Filled 15/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (6, 4, 7): 12
# Filled 16/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (6, 3, 6): 12
# Filled 17/5000 blocks
# Selected token 4 with probability 90.3%, air probability 0.0%
# (4, 4, 3): 4
# Filled 18/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 3, 5): 12
# Filled 19/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (7, 5, 7): 4
# Filled 20/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 7, 7): 4
# Filled 21/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 7, 4): 4
# Filled 22/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 6, 3): 4
# Filled 23/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 4, 7): 12
# Filled 24/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (6, 3, 3): 12
# Filled 25/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (7, 7, 4): 4
# Filled 26/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 3, 7): 12
# Filled 27/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 7, 3): 4
# Filled 28/5000 blocks
# Iteration 2/5
# Selected token 4 with probability 100.0%, air probability 0.0%
# (8, 5, 5): 4
# Filled 29/5000 blocks
# Selected token 12 with probability 72.8%, air probability 0.0%
# (2, 5, 6): 12
# Filled 30/5000 blocks
# Selected token 4 with probability 92.6%, air probability 0.0%
# (4, 5, 8): 4
# Filled 31/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (5, 2, 4): 12
# Filled 32/5000 blocks
# Selected token 4 with probability 98.8%, air probability 0.0%
# (5, 4, 2): 4
# Filled 33/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (6, 2, 5): 12
# Filled 34/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (8, 5, 6): 4
# Filled 35/5000 blocks
# Selected token 12 with probability 99.0%, air probability 0.0%
# (2, 4, 4): 12
# Filled 36/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 4, 6): 12
# Filled 37/5000 blocks
# Selected token 4 with probability 66.3%, air probability 0.0%
# (4, 4, 2): 4
# Filled 38/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (4, 4, 8): 12
# Filled 39/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 6, 2): 4
# Filled 40/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (6, 2, 6): 12
# Filled 41/5000 blocks
# Selected token 12 with probability 50.1%, air probability 0.0%
# (8, 4, 6): 12
# Filled 42/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 3, 3): 12
# Filled 43/5000 blocks
# Selected token 12 with probability 99.6%, air probability 0.0%
# (2, 5, 7): 12
# Filled 44/5000 blocks
# Selected token 12 with probability 89.4%, air probability 0.0%
# (3, 5, 8): 12
# Filled 45/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 8, 7): 4
# Filled 46/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 2, 5): 12
# Filled 47/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 3, 5): 12
# Filled 48/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 3, 6): 12
# Filled 49/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 4, 7): 12
# Filled 50/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 2, 6): 12
# Filled 51/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 4, 8): 12
# Filled 52/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (4, 2, 7): 12
# Filled 53/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (4, 3, 8): 12
# Filled 54/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 7, 8): 4
# Filled 55/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (6, 2, 3): 12
# Filled 56/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (6, 3, 2): 12
# Filled 57/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 7, 8): 4
# Filled 58/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (7, 6, 8): 4
# Filled 59/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 3, 7): 12
# Filled 60/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 2, 7): 12
# Filled 61/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 3, 8): 12
# Filled 62/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 7, 2): 4
# Filled 63/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 2, 3): 12
# Filled 64/5000 blocks
# Selected token 12 with probability 99.8%, air probability 0.0%
# (2, 5, 8): 12
# Filled 65/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (5, 2, 2): 12
# Filled 66/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (8, 8, 5): 4
# Filled 67/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 2, 6): 12
# Filled 68/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 4, 8): 12
# Filled 69/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (4, 2, 8): 12
# Filled 70/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 8, 8): 4
# Filled 71/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 2, 6): 12
# Filled 72/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 4, 8): 12
# Filled 73/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 2, 7): 12
# Filled 74/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 3, 8): 12
# Filled 75/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 2, 8): 12
# Filled 76/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 2, 2): 12
# Filled 77/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (2, 2, 8): 12
# Filled 78/5000 blocks
# Iteration 3/5
# Selected token 12 with probability 99.9%, air probability 0.0%
# (2, 4, 3): 12
# Filled 79/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (2, 6, 7): 4
# Filled 80/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 6, 8): 4
# Filled 81/5000 blocks
# Selected token 4 with probability 98.5%, air probability 0.0%
# (1, 5, 5): 4
# Filled 82/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (5, 1, 5): 12
# Filled 83/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (5, 5, 9): 4
# Filled 84/5000 blocks
# Selected token 12 with probability 97.0%, air probability 0.1%
# (1, 4, 5): 12
# Filled 85/5000 blocks
# Selected token 4 with probability 74.8%, air probability 0.0%
# (1, 5, 6): 4
# Filled 86/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (1, 6, 5): 4
# Filled 87/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 7, 8): 4
# Filled 88/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 8, 7): 4
# Filled 89/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 5, 1): 4
# Filled 90/5000 blocks
# Selected token 4 with probability 99.2%, air probability 0.0%
# (4, 5, 9): 4
# Filled 91/5000 blocks
# Selected token 4 with probability 87.2%, air probability 0.0%
# (5, 4, 1): 4
# Filled 92/5000 blocks
# Selected token 12 with probability 97.2%, air probability 0.0%
# (5, 4, 9): 12
# Filled 93/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 6, 9): 4
# Filled 94/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (1, 4, 4): 12
# Filled 95/5000 blocks
# Selected token 12 with probability 99.8%, air probability 0.0%
# (1, 4, 6): 12
# Filled 96/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (1, 6, 6): 4
# Filled 97/5000 blocks
# Selected token 12 with probability 99.6%, air probability 0.0%
# (2, 2, 5): 12
# Filled 98/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (4, 4, 9): 12
# Filled 99/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 6, 9): 4
# Filled 100/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 9, 6): 4
# Filled 101/5000 blocks
# Selected token 12 with probability 98.1%, air probability 0.1%
# (5, 2, 8): 12
# Filled 102/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (6, 1, 4): 12
# Filled 103/5000 blocks
# Selected token 12 with probability 47.8%, air probability 0.0%
# (9, 4, 6): 12
# Filled 104/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (2, 6, 8): 4
# Filled 105/5000 blocks
# Selected token 12 with probability 99.5%, air probability 0.0%
# (1, 3, 5): 12
# Filled 106/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (1, 5, 3): 4
# Filled 107/5000 blocks
# Selected token 4 with probability 52.8%, air probability 0.0%
# (1, 5, 7): 4
# Filled 108/5000 blocks
# Selected token 4 with probability 78.8%, air probability 0.0%
# (3, 5, 9): 4
# Filled 109/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (5, 3, 1): 12
# Filled 110/5000 blocks
# Selected token 12 with probability 99.6%, air probability 0.0%
# (5, 3, 9): 12
# Filled 111/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 7, 1): 4
# Filled 112/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 7, 9): 4
# Filled 113/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (9, 3, 5): 12
# Filled 114/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (9, 7, 5): 4
# Filled 115/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (1, 3, 4): 12
# Filled 116/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (1, 3, 6): 12
# Filled 117/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (1, 4, 7): 12
# Filled 118/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (1, 6, 7): 4
# Filled 119/5000 blocks
# Selected token 12 with probability 93.6%, air probability 0.2%
# (3, 1, 6): 12
# Filled 120/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (3, 4, 1): 12
# Filled 121/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (3, 4, 9): 12
# Filled 122/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 6, 1): 4
# Filled 123/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 6, 9): 4
# Filled 124/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (4, 1, 3): 12
# Filled 125/5000 blocks
# Selected token 12 with probability 98.4%, air probability 0.0%
# (4, 1, 7): 12
# Filled 126/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (4, 3, 9): 12
# Filled 127/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 7, 9): 4
# Filled 128/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 9, 7): 4
# Filled 129/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (6, 3, 1): 12
# Filled 130/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 7, 9): 4
# Filled 131/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 1, 4): 12
# Filled 132/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 1, 6): 12
# Filled 133/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (7, 9, 6): 4
# Filled 134/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (3, 8, 8): 4
# Filled 135/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (7, 8, 8): 4
# Filled 136/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 2, 3): 12
# Filled 137/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 2, 7): 12
# Filled 138/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 3, 8): 12
# Filled 139/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (1, 3, 7): 12
# Filled 140/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (3, 1, 7): 12
# Filled 141/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (3, 3, 9): 12
# Filled 142/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 7, 9): 4
# Filled 143/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 9, 7): 4
# Filled 144/5000 blocks
# Selected token 12 with probability 99.3%, air probability 0.0%
# (1, 2, 5): 12
# Filled 145/5000 blocks
# Selected token 4 with probability 91.7%, air probability 0.0%
# (1, 5, 8): 4
# Filled 146/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (2, 1, 5): 12
# Filled 147/5000 blocks
# Selected token 4 with probability 93.2%, air probability 0.0%
# (2, 5, 9): 4
# Filled 148/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (5, 1, 2): 12
# Filled 149/5000 blocks
# Selected token 12 with probability 98.5%, air probability 0.0%
# (5, 1, 8): 12
# Filled 150/5000 blocks
# Selected token 12 with probability 99.8%, air probability 0.0%
# (5, 2, 9): 12
# Filled 151/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (5, 8, 9): 4
# Filled 152/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 9, 8): 4
# Filled 153/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (1, 2, 6): 12
# Filled 154/5000 blocks
# Selected token 12 with probability 99.8%, air probability 0.0%
# (1, 4, 8): 12
# Filled 155/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (1, 6, 8): 4
# Filled 156/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (2, 1, 6): 12
# Filled 157/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (2, 4, 9): 12
# Filled 158/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (2, 6, 9): 4
# Filled 159/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (4, 1, 2): 12
# Filled 160/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (4, 1, 8): 12
# Filled 161/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (4, 2, 9): 12
# Filled 162/5000 blocks
# Selected token 4 with probability 98.7%, air probability 0.0%
# (4, 8, 9): 4
# Filled 163/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 9, 8): 4
# Filled 164/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (6, 8, 9): 4
# Filled 165/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (9, 8, 6): 4
# Filled 166/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (1, 2, 7): 12
# Filled 167/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (1, 3, 8): 12
# Filled 168/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (2, 1, 7): 12
# Filled 169/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (2, 3, 9): 12
# Filled 170/5000 blocks
# Selected token 12 with probability 99.5%, air probability 0.0%
# (3, 1, 8): 12
# Filled 171/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (3, 2, 9): 12
# Filled 172/5000 blocks
# Selected token 4 with probability 98.2%, air probability 0.0%
# (3, 8, 9): 4
# Filled 173/5000 blocks
# Selected token 4 with probability 99.7%, air probability 0.0%
# (3, 9, 8): 4
# Filled 174/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 1, 2): 12
# Filled 175/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 2, 1): 12
# Filled 176/5000 blocks
# Selected token 12 with probability 99.0%, air probability 0.0%
# (1, 1, 5): 12
# Filled 177/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (1, 5, 9): 4
# Filled 178/5000 blocks
# Selected token 12 with probability 96.4%, air probability 0.1%
# (5, 1, 9): 12
# Filled 179/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (5, 9, 9): 4
# Filled 180/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (9, 5, 9): 4
# Filled 181/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (9, 9, 5): 298
# Filled 182/5000 blocks
# Selected token 12 with probability 98.8%, air probability 0.0%
# (1, 1, 6): 12
# Filled 183/5000 blocks
# Selected token 12 with probability 99.2%, air probability 0.0%
# (1, 4, 9): 12
# Filled 184/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (1, 6, 9): 4
# Filled 185/5000 blocks
# Selected token 12 with probability 96.7%, air probability 0.1%
# (4, 1, 9): 12
# Filled 186/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (4, 9, 9): 4
# Filled 187/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (9, 4, 9): 12
# Filled 188/5000 blocks
# Selected token 12 with probability 98.8%, air probability 0.1%
# (1, 2, 8): 12
# Filled 189/5000 blocks
# Selected token 12 with probability 93.1%, air probability 0.1%
# (2, 1, 8): 12
# Filled 190/5000 blocks
# Selected token 12 with probability 98.9%, air probability 0.1%
# (2, 2, 9): 12
# Filled 191/5000 blocks
# Selected token 12 with probability 96.3%, air probability 0.1%
# (1, 1, 7): 12
# Filled 192/5000 blocks
# Selected token 12 with probability 99.3%, air probability 0.0%
# (1, 3, 9): 12
# Filled 193/5000 blocks
# Selected token 12 with probability 89.3%, air probability 0.2%
# (3, 1, 9): 12
# Filled 194/5000 blocks
# Selected token 4 with probability 99.7%, air probability 0.0%
# (3, 9, 9): 4
# Filled 195/5000 blocks
# Selected token 12 with probability 88.7%, air probability 0.2%
# (1, 1, 8): 12
# Filled 196/5000 blocks
# Selected token 12 with probability 97.4%, air probability 0.2%
# (1, 2, 9): 12
# Filled 197/5000 blocks
# Selected token 12 with probability 90.1%, air probability 0.1%
# (2, 1, 9): 12
# Filled 198/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 1, 1): 12
# Filled 199/5000 blocks
# Selected token 4 with probability 6.1%, air probability 0.2%
# (1, 1, 9): 4
# Filled 200/5000 blocks
# Iteration 4/5
# Selected token 114 with probability 75.7%, air probability 0.0%
# (2, 7, 6): 114
# Filled 201/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (5, 9, 5): 298
# Filled 202/5000 blocks
# Selected token 114 with probability 99.7%, air probability 0.0%
# (2, 7, 7): 114
# Filled 203/5000 blocks
# Selected token 12 with probability 83.9%, air probability 0.6%
# (6, 4, 9): 12
# Filled 204/5000 blocks
# Selected token 114 with probability 99.0%, air probability 0.5%
# (2, 8, 6): 114
# Filled 205/5000 blocks
# Selected token 4 with probability 33.8%, air probability 0.1%
# (1, 7, 5): 4
# Filled 206/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (3, 9, 5): 298
# Filled 207/5000 blocks
# Selected token 114 with probability 91.5%, air probability 0.1%
# (1, 7, 6): 114
# Filled 208/5000 blocks
# Selected token 12 with probability 86.7%, air probability 0.8%
# (6, 3, 9): 12
# Filled 209/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (2, 2, 3): 12
# Filled 210/5000 blocks
# Selected token 114 with probability 99.4%, air probability 0.1%
# (2, 7, 8): 114
# Filled 211/5000 blocks
# Selected token 114 with probability 98.1%, air probability 1.7%
# (2, 8, 7): 114
# Filled 212/5000 blocks
# Selected token 114 with probability 99.0%, air probability 0.1%
# (1, 7, 7): 114
# Filled 213/5000 blocks
# Selected token 4 with probability 95.5%, air probability 0.1%
# (0, 5, 5): 4
# Filled 214/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (1, 5, 2): 4
# Filled 215/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (5, 5, 0): 4
# Filled 216/5000 blocks
# Selected token 4 with probability 98.0%, air probability 0.0%
# (5, 5, 10): 4
# Filled 217/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (10, 5, 5): 4
# Filled 218/5000 blocks
# Selected token 12 with probability 93.8%, air probability 0.0%
# (0, 4, 5): 12
# Filled 219/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (0, 5, 4): 4
# Filled 220/5000 blocks
# Selected token 4 with probability 99.7%, air probability 0.0%
# (0, 5, 6): 4
# Filled 221/5000 blocks
# Selected token 4 with probability 99.1%, air probability 0.0%
# (0, 6, 5): 4
# Filled 222/5000 blocks
# Selected token 12 with probability 93.9%, air probability 0.4%
# (1, 2, 4): 12
# Filled 223/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (1, 6, 2): 4
# Filled 224/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (2, 1, 4): 12
# Filled 225/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (2, 4, 1): 12
# Filled 226/5000 blocks
# Selected token 114 with probability 44.8%, air probability 47.7%
# (2, 9, 6): 114
# Filled 227/5000 blocks
# Selected token 4 with probability 99.4%, air probability 0.0%
# (4, 5, 10): 4
# Filled 228/5000 blocks
# Selected token 12 with probability 85.0%, air probability 0.0%
# (5, 4, 10): 12
# Filled 229/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (5, 6, 10): 4
# Filled 230/5000 blocks
# Selected token 12 with probability 92.3%, air probability 0.2%
# (6, 1, 8): 12
# Filled 231/5000 blocks
# Selected token 12 with probability 77.3%, air probability 0.5%
# (6, 2, 9): 12
# Filled 232/5000 blocks
# Selected token 4 with probability 99.4%, air probability 0.0%
# (6, 5, 10): 4
# Filled 233/5000 blocks
# Selected token 380 with probability 100.0%, air probability 0.0%
# (6, 10, 5): 380
# Filled 234/5000 blocks
# Selected token 12 with probability 99.2%, air probability 0.0%
# (0, 4, 4): 12
# Filled 235/5000 blocks
# Selected token 12 with probability 98.8%, air probability 0.0%
# (0, 4, 6): 12
# Filled 236/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (0, 6, 4): 4
# Filled 237/5000 blocks
# Selected token 4 with probability 99.7%, air probability 0.0%
# (0, 6, 6): 4
# Filled 238/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.1%
# (2, 8, 8): 114
# Filled 239/5000 blocks
# Selected token 114 with probability 10.0%, air probability 0.6%
# (4, 0, 6): 114
# Filled 240/5000 blocks
# Selected token 12 with probability 97.0%, air probability 0.1%
# (4, 4, 10): 12
# Filled 241/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 6, 10): 4
# Filled 242/5000 blocks
# Selected token 12 with probability 91.8%, air probability 0.2%
# (6, 4, 10): 12
# Filled 243/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (6, 6, 10): 4
# Filled 244/5000 blocks
# Selected token 4 with probability 31.0%, air probability 0.0%
# (10, 4, 6): 4
# Filled 245/5000 blocks
# Selected token 12 with probability 99.1%, air probability 0.1%
# (0, 3, 5): 12
# Filled 246/5000 blocks
# Selected token 4 with probability 99.5%, air probability 0.0%
# (0, 5, 3): 4
# Filled 247/5000 blocks
# Selected token 4 with probability 99.6%, air probability 0.0%
# (0, 5, 7): 4
# Filled 248/5000 blocks
# Selected token 4 with probability 98.2%, air probability 0.0%
# (0, 7, 5): 4
# Filled 249/5000 blocks
# Selected token 12 with probability 97.1%, air probability 0.2%
# (1, 2, 3): 12
# Filled 250/5000 blocks
# Selected token 114 with probability 99.7%, air probability 0.0%
# (1, 7, 8): 114
# Filled 251/5000 blocks
# Selected token 114 with probability 84.8%, air probability 0.1%
# (2, 7, 9): 114
# Filled 252/5000 blocks
# Selected token 114 with probability 98.1%, air probability 1.5%
# (2, 9, 7): 114
# Filled 253/5000 blocks
# Selected token 114 with probability 92.2%, air probability 0.7%
# (3, 0, 5): 114
# Filled 254/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 1, 2): 12
# Filled 255/5000 blocks
# Selected token 4 with probability 98.1%, air probability 0.1%
# (3, 5, 10): 4
# Filled 256/5000 blocks
# Selected token 114 with probability 91.1%, air probability 1.1%
# (5, 0, 7): 114
# Filled 257/5000 blocks
# Selected token 12 with probability 97.9%, air probability 0.2%
# (5, 3, 10): 12
# Filled 258/5000 blocks
# Selected token 4 with probability 97.5%, air probability 0.0%
# (5, 7, 10): 4
# Filled 259/5000 blocks
# Selected token 298 with probability 99.9%, air probability 0.0%
# (5, 10, 7): 298
# Filled 260/5000 blocks
# Selected token 12 with probability 88.7%, air probability 0.5%
# (7, 2, 9): 12
# Filled 261/5000 blocks
# Selected token 380 with probability 100.0%, air probability 0.0%
# (7, 10, 5): 380
# Filled 262/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (8, 9, 7): 4
# Filled 263/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (9, 2, 3): 12
# Filled 264/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (9, 8, 7): 4
# Filled 265/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (10, 5, 7): 4
# Filled 266/5000 blocks
# Selected token 12 with probability 99.8%, air probability 0.0%
# (0, 3, 4): 12
# Filled 267/5000 blocks
# Selected token 12 with probability 99.8%, air probability 0.0%
# (0, 3, 6): 12
# Filled 268/5000 blocks
# Selected token 12 with probability 99.5%, air probability 0.0%
# (0, 4, 3): 12
# Filled 269/5000 blocks
# Selected token 12 with probability 99.3%, air probability 0.0%
# (0, 4, 7): 12
# Filled 270/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (0, 6, 3): 4
# Filled 271/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (0, 6, 7): 4
# Filled 272/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (0, 7, 4): 4
# Filled 273/5000 blocks
# Selected token 4 with probability 96.4%, air probability 0.0%
# (0, 7, 6): 4
# Filled 274/5000 blocks
# Selected token 114 with probability 89.4%, air probability 0.2%
# (3, 0, 4): 114
# Filled 275/5000 blocks
# Selected token 114 with probability 99.2%, air probability 0.1%
# (3, 0, 6): 114
# Filled 276/5000 blocks
# Selected token 12 with probability 98.4%, air probability 0.0%
# (3, 4, 10): 12
# Filled 277/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (3, 6, 10): 4
# Filled 278/5000 blocks
# Selected token 298 with probability 99.6%, air probability 0.1%
# (3, 10, 6): 298
# Filled 279/5000 blocks
# Selected token 114 with probability 99.4%, air probability 0.1%
# (4, 0, 7): 114
# Filled 280/5000 blocks
# Selected token 12 with probability 98.9%, air probability 0.1%
# (4, 3, 10): 12
# Filled 281/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (4, 7, 10): 4
# Filled 282/5000 blocks
# Selected token 298 with probability 99.9%, air probability 0.0%
# (4, 10, 7): 298
# Filled 283/5000 blocks
# Selected token 114 with probability 71.9%, air probability 0.3%
# (6, 0, 7): 114
# Filled 284/5000 blocks
# Selected token 12 with probability 98.0%, air probability 0.1%
# (6, 3, 10): 12
# Filled 285/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (6, 7, 10): 4
# Filled 286/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (6, 10, 7): 298
# Filled 287/5000 blocks
# Selected token 4 with probability 99.7%, air probability 0.0%
# (7, 6, 10): 4
# Filled 288/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (0, 3, 3): 12
# Filled 289/5000 blocks
# Selected token 12 with probability 99.7%, air probability 0.0%
# (0, 3, 7): 12
# Filled 290/5000 blocks
# Selected token 4 with probability 99.1%, air probability 0.0%
# (0, 7, 7): 4
# Filled 291/5000 blocks
# Selected token 12 with probability 82.9%, air probability 1.1%
# (1, 1, 4): 12
# Filled 292/5000 blocks
# Selected token 114 with probability 99.6%, air probability 0.1%
# (3, 0, 7): 114
# Filled 293/5000 blocks
# Selected token 4 with probability 1.1%, air probability 0.1%
# (3, 3, 10): 4
# Filled 294/5000 blocks
# Selected token 4 with probability 99.4%, air probability 0.0%
# (3, 7, 10): 4
# Filled 295/5000 blocks
# Selected token 298 with probability 99.9%, air probability 0.0%
# (3, 10, 7): 298
# Filled 296/5000 blocks
# Selected token 12 with probability 38.1%, air probability 5.5%
# (6, 1, 9): 12
# Filled 297/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 9, 9): 4
# Filled 298/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 0, 3): 12
# Filled 299/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (7, 7, 10): 4
# Filled 300/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (9, 6, 9): 4
# Filled 301/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (10, 7, 7): 4
# Filled 302/5000 blocks
# Selected token 12 with probability 98.6%, air probability 0.1%
# (0, 2, 5): 12
# Filled 303/5000 blocks
# Selected token 4 with probability 96.4%, air probability 0.1%
# (0, 5, 2): 4
# Filled 304/5000 blocks
# Selected token 4 with probability 96.6%, air probability 0.2%
# (0, 5, 8): 4
# Filled 305/5000 blocks
# Selected token 114 with probability 99.2%, air probability 0.1%
# (2, 0, 5): 114
# Filled 306/5000 blocks
# Selected token 4 with probability 97.4%, air probability 0.2%
# (2, 5, 10): 4
# Filled 307/5000 blocks
# Selected token 114 with probability 99.8%, air probability 0.2%
# (2, 8, 9): 114
# Filled 308/5000 blocks
# Selected token 114 with probability 99.6%, air probability 0.3%
# (2, 9, 8): 114
# Filled 309/5000 blocks
# Selected token 114 with probability 98.9%, air probability 0.3%
# (5, 0, 8): 114
# Filled 310/5000 blocks
# Selected token 12 with probability 84.7%, air probability 1.1%
# (5, 2, 10): 12
# Filled 311/5000 blocks
# Selected token 4 with probability 99.3%, air probability 0.0%
# (5, 8, 10): 4
# Filled 312/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (5, 10, 8): 298
# Filled 313/5000 blocks
# Selected token 12 with probability 85.6%, air probability 0.6%
# (8, 2, 9): 12
# Filled 314/5000 blocks
# Selected token 4 with probability 99.6%, air probability 0.0%
# (8, 5, 10): 4
# Filled 315/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (8, 9, 8): 4
# Filled 316/5000 blocks
# Selected token 12 with probability 99.6%, air probability 0.0%
# (0, 2, 4): 12
# Filled 317/5000 blocks
# Selected token 12 with probability 99.6%, air probability 0.0%
# (0, 2, 6): 12
# Filled 318/5000 blocks
# Selected token 12 with probability 98.0%, air probability 0.0%
# (0, 4, 2): 12
# Filled 319/5000 blocks
# Selected token 12 with probability 84.7%, air probability 0.0%
# (0, 4, 8): 12
# Filled 320/5000 blocks
# Selected token 4 with probability 99.4%, air probability 0.0%
# (0, 6, 2): 4
# Filled 321/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (0, 6, 8): 4
# Filled 322/5000 blocks
# Selected token 114 with probability 99.4%, air probability 0.0%
# (2, 0, 4): 114
# Filled 323/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.0%
# (2, 0, 6): 114
# Filled 324/5000 blocks
# Selected token 12 with probability 99.1%, air probability 0.0%
# (2, 4, 0): 12
# Filled 325/5000 blocks
# Selected token 4 with probability 73.1%, air probability 0.1%
# (2, 4, 10): 4
# Filled 326/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (2, 6, 10): 4
# Filled 327/5000 blocks
# Selected token 1 with probability 98.4%, air probability 98.4%
# Selected token 114 with probability 99.9%, air probability 0.0%
# (4, 0, 8): 114
# Filled 328/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (4, 2, 0): 12
# Filled 329/5000 blocks
# Selected token 12 with probability 63.8%, air probability 0.1%
# (4, 2, 10): 12
# Filled 330/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 8, 10): 4
# Filled 331/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (4, 10, 8): 298
# Filled 332/5000 blocks
# Selected token 114 with probability 99.2%, air probability 0.0%
# (6, 0, 8): 114
# Filled 333/5000 blocks
# Selected token 12 with probability 96.4%, air probability 0.1%
# (6, 2, 10): 12
# Filled 334/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 8, 10): 4
# Filled 335/5000 blocks
# Selected token 12 with probability 79.9%, air probability 0.1%
# (8, 4, 10): 12
# Filled 336/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (8, 6, 10): 4
# Filled 337/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (8, 10, 6): 298
# Filled 338/5000 blocks
# Selected token 12 with probability 90.5%, air probability 0.0%
# (10, 2, 6): 12
# Filled 339/5000 blocks
# Selected token 12 with probability 99.2%, air probability 0.0%
# (10, 4, 8): 12
# Filled 340/5000 blocks
# Selected token 114 with probability 98.0%, air probability 0.0%
# (1, 7, 9): 114
# Filled 341/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (3, 1, 1): 12
# Filled 342/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (9, 1, 3): 12
# Filled 343/5000 blocks
# Selected token 12 with probability 98.4%, air probability 0.1%
# (0, 2, 3): 12
# Filled 344/5000 blocks
# Selected token 12 with probability 98.9%, air probability 0.0%
# (0, 2, 7): 12
# Filled 345/5000 blocks
# Selected token 12 with probability 96.0%, air probability 0.0%
# (0, 3, 8): 12
# Filled 346/5000 blocks
# Selected token 4 with probability 97.2%, air probability 0.0%
# (0, 7, 8): 4
# Filled 347/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.0%
# (2, 0, 7): 114
# Filled 348/5000 blocks
# Selected token 4 with probability 91.8%, air probability 0.1%
# (2, 3, 10): 4
# Filled 349/5000 blocks
# Selected token 4 with probability 86.4%, air probability 0.0%
# (2, 7, 10): 4
# Filled 350/5000 blocks
# Selected token 1 with probability 99.9%, air probability 99.9%
# Selected token 114 with probability 99.9%, air probability 0.0%
# (3, 0, 8): 114
# Filled 351/5000 blocks
# Selected token 12 with probability 41.2%, air probability 0.0%
# (3, 2, 10): 12
# Filled 352/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (3, 8, 10): 4
# Filled 353/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (3, 10, 8): 298
# Filled 354/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 0, 2): 12
# Filled 355/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (7, 2, 0): 12
# Filled 356/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (7, 8, 10): 4
# Filled 357/5000 blocks
# Selected token 12 with probability 98.6%, air probability 0.0%
# (8, 3, 10): 12
# Filled 358/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (8, 10, 7): 298
# Filled 359/5000 blocks
# Selected token 12 with probability 99.0%, air probability 0.0%
# (0, 1, 5): 12
# Filled 360/5000 blocks
# Selected token 4 with probability 99.5%, air probability 0.0%
# (0, 5, 9): 4
# Filled 361/5000 blocks
# Selected token 114 with probability 99.0%, air probability 0.0%
# (1, 0, 5): 114
# Filled 362/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (1, 5, 10): 4
# Filled 363/5000 blocks
# Selected token 114 with probability 99.5%, air probability 0.4%
# (2, 9, 9): 114
# Filled 364/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (5, 0, 1): 12
# Filled 365/5000 blocks
# Selected token 114 with probability 95.4%, air probability 0.1%
# (5, 0, 9): 114
# Filled 366/5000 blocks
# Selected token 12 with probability 95.0%, air probability 0.2%
# (5, 1, 10): 12
# Filled 367/5000 blocks
# Selected token 4 with probability 98.6%, air probability 0.0%
# (5, 9, 10): 4
# Filled 368/5000 blocks
# Selected token 298 with probability 99.9%, air probability 0.0%
# (5, 10, 9): 298
# Filled 369/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (9, 5, 10): 4
# Filled 370/5000 blocks
# Selected token 380 with probability 100.0%, air probability 0.0%
# (9, 10, 5): 380
# Filled 371/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (10, 5, 9): 4
# Filled 372/5000 blocks
# Selected token 12 with probability 96.1%, air probability 0.1%
# (0, 1, 4): 12
# Filled 373/5000 blocks
# Selected token 12 with probability 98.6%, air probability 0.0%
# (0, 1, 6): 12
# Filled 374/5000 blocks
# Selected token 12 with probability 56.2%, air probability 0.0%
# (0, 4, 9): 12
# Filled 375/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (0, 6, 9): 4
# Filled 376/5000 blocks
# Selected token 114 with probability 97.2%, air probability 0.1%
# (1, 0, 4): 114
# Filled 377/5000 blocks
# Selected token 114 with probability 100.0%, air probability 0.0%
# (1, 0, 6): 114
# Filled 378/5000 blocks
# Selected token 12 with probability 6.4%, air probability 0.0%
# (1, 4, 10): 12
# Filled 379/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (1, 6, 10): 4
# Filled 380/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (4, 0, 1): 12
# Filled 381/5000 blocks
# Selected token 114 with probability 99.8%, air probability 0.0%
# (4, 0, 9): 114
# Filled 382/5000 blocks
# Selected token 12 with probability 94.7%, air probability 0.1%
# (4, 1, 10): 12
# Filled 383/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (4, 9, 10): 4
# Filled 384/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (4, 10, 9): 298
# Filled 385/5000 blocks
# Selected token 114 with probability 92.9%, air probability 0.1%
# (6, 0, 9): 114
# Filled 386/5000 blocks
# Selected token 12 with probability 99.6%, air probability 0.0%
# (6, 1, 0): 12
# Filled 387/5000 blocks
# Selected token 4 with probability 8.4%, air probability 0.2%
# (6, 1, 10): 4
# Filled 388/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (6, 9, 10): 4
# Filled 389/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (6, 10, 9): 298
# Filled 390/5000 blocks
# Selected token 12 with probability 94.7%, air probability 0.1%
# (9, 4, 10): 12
# Filled 391/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (9, 6, 10): 4
# Filled 392/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (9, 10, 6): 298
# Filled 393/5000 blocks
# Selected token 12 with probability 97.1%, air probability 0.0%
# (0, 2, 8): 12
# Filled 394/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.0%
# (2, 0, 8): 114
# Filled 395/5000 blocks
# Selected token 12 with probability 67.6%, air probability 0.1%
# (2, 2, 10): 12
# Filled 396/5000 blocks
# Selected token 4 with probability 99.4%, air probability 0.0%
# (2, 8, 10): 4
# Filled 397/5000 blocks
# Selected token 1 with probability 99.9%, air probability 99.9%
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 0, 2): 12
# Filled 398/5000 blocks
# Selected token 12 with probability 96.3%, air probability 0.0%
# (0, 1, 7): 12
# Filled 399/5000 blocks
# Selected token 12 with probability 95.5%, air probability 0.0%
# (0, 3, 9): 12
# Filled 400/5000 blocks
# Selected token 4 with probability 99.6%, air probability 0.0%
# (0, 7, 9): 4
# Filled 401/5000 blocks
# Selected token 114 with probability 100.0%, air probability 0.0%
# (1, 0, 7): 114
# Filled 402/5000 blocks
# Selected token 12 with probability 46.4%, air probability 0.0%
# (1, 3, 10): 12
# Filled 403/5000 blocks
# Selected token 4 with probability 97.8%, air probability 0.0%
# (1, 7, 10): 4
# Filled 404/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.0%
# (3, 0, 9): 114
# Filled 405/5000 blocks
# Selected token 4 with probability 14.7%, air probability 0.1%
# (3, 1, 10): 4
# Filled 406/5000 blocks
# Selected token 4 with probability 98.7%, air probability 0.0%
# (3, 9, 10): 4
# Filled 407/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (3, 10, 9): 298
# Filled 408/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (7, 1, 0): 12
# Filled 409/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (7, 9, 10): 4
# Filled 410/5000 blocks
# Selected token 12 with probability 93.4%, air probability 0.2%
# (9, 3, 10): 12
# Filled 411/5000 blocks
# Selected token 114 with probability 98.2%, air probability 0.0%
# (0, 0, 5): 114
# Filled 412/5000 blocks
# Selected token 12 with probability 68.2%, air probability 0.1%
# (0, 1, 8): 12
# Filled 413/5000 blocks
# Selected token 12 with probability 86.1%, air probability 0.0%
# (0, 2, 9): 12
# Filled 414/5000 blocks
# Selected token 4 with probability 99.7%, air probability 0.0%
# (0, 5, 10): 4
# Filled 415/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.0%
# (1, 0, 8): 114
# Filled 416/5000 blocks
# Selected token 12 with probability 65.1%, air probability 0.0%
# (1, 2, 10): 12
# Filled 417/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.0%
# (2, 0, 9): 114
# Filled 418/5000 blocks
# Selected token 12 with probability 18.8%, air probability 0.1%
# (2, 1, 10): 12
# Filled 419/5000 blocks
# Selected token 4 with probability 95.7%, air probability 0.0%
# (2, 9, 10): 4
# Filled 420/5000 blocks
# Selected token 1 with probability 99.9%, air probability 99.9%
# Selected token 114 with probability 98.6%, air probability 0.0%
# (5, 0, 10): 114
# Filled 421/5000 blocks
# Selected token 298 with probability 99.9%, air probability 0.0%
# (5, 10, 10): 298
# Filled 422/5000 blocks
# Selected token 12 with probability 100.0%, air probability 0.0%
# (8, 0, 1): 12
# Filled 423/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (10, 5, 10): 4
# Filled 424/5000 blocks
# Selected token 114 with probability 98.6%, air probability 0.0%
# (0, 0, 4): 114
# Filled 425/5000 blocks
# Selected token 114 with probability 100.0%, air probability 0.0%
# (0, 0, 6): 114
# Filled 426/5000 blocks
# Selected token 12 with probability 76.6%, air probability 0.0%
# (0, 4, 10): 12
# Filled 427/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (0, 6, 10): 4
# Filled 428/5000 blocks
# Selected token 114 with probability 100.0%, air probability 0.0%
# (4, 0, 10): 114
# Filled 429/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (4, 10, 10): 298
# Filled 430/5000 blocks
# Selected token 114 with probability 95.9%, air probability 0.1%
# (6, 0, 10): 114
# Filled 431/5000 blocks
# Selected token 298 with probability 99.9%, air probability 0.0%
# (6, 10, 10): 298
# Filled 432/5000 blocks
# Selected token 12 with probability 80.9%, air probability 0.1%
# (10, 4, 10): 12
# Filled 433/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (10, 10, 6): 298
# Filled 434/5000 blocks
# Selected token 114 with probability 100.0%, air probability 0.0%
# (0, 0, 7): 114
# Filled 435/5000 blocks
# Selected token 12 with probability 97.6%, air probability 0.0%
# (0, 3, 10): 12
# Filled 436/5000 blocks
# Selected token 4 with probability 99.4%, air probability 0.0%
# (0, 7, 10): 4
# Filled 437/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.0%
# (3, 0, 10): 114
# Filled 438/5000 blocks
# Selected token 298 with probability 99.9%, air probability 0.0%
# (3, 10, 10): 298
# Filled 439/5000 blocks
# Selected token 114 with probability 15.1%, air probability 1.5%
# (10, 3, 10): 114
# Filled 440/5000 blocks
# Selected token 114 with probability 47.8%, air probability 1.7%
# (0, 1, 9): 114
# Filled 441/5000 blocks
# Selected token 114 with probability 99.8%, air probability 0.1%
# (1, 0, 9): 114
# Filled 442/5000 blocks
# Selected token 114 with probability 57.9%, air probability 1.4%
# (1, 1, 10): 114
# Filled 443/5000 blocks
# Selected token 114 with probability 100.0%, air probability 0.0%
# (0, 0, 8): 114
# Filled 444/5000 blocks
# Selected token 114 with probability 62.8%, air probability 1.4%
# (0, 2, 10): 114
# Filled 445/5000 blocks
# Selected token 114 with probability 99.9%, air probability 0.0%
# (2, 0, 10): 114
# Filled 446/5000 blocks
# Selected token 298 with probability 95.0%, air probability 2.3%
# (2, 10, 10): 298
# Filled 447/5000 blocks
# Selected token 114 with probability 99.6%, air probability 0.3%
# (0, 0, 9): 114
# Filled 448/5000 blocks
# Selected token 114 with probability 97.2%, air probability 0.4%
# (0, 1, 10): 114
# Filled 449/5000 blocks
# Selected token 114 with probability 99.7%, air probability 0.1%
# (1, 0, 10): 114
# Filled 450/5000 blocks
# Selected token 12 with probability 98.1%, air probability 0.0%
# (9, 0, 0): 12
# Filled 451/5000 blocks
# Selected token 114 with probability 99.7%, air probability 0.2%
# (0, 0, 10): 114
# Filled 452/5000 blocks
# Iteration 5/5
# Selected token 298 with probability 100.0%, air probability 0.0%
# (5, 9, 4): 298
# Filled 453/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (6, 9, 4): 298
# Filled 454/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (3, 9, 4): 298
# Filled 455/5000 blocks
# Selected token 4 with probability 32.5%, air probability 0.2%
# (1, 8, 5): 4
# Filled 456/5000 blocks
# Selected token 298 with probability 98.9%, air probability 0.0%
# (2, 9, 5): 298
# Filled 457/5000 blocks
# Selected token 4 with probability 99.8%, air probability 0.0%
# (1, 8, 4): 4
# Filled 458/5000 blocks
# Selected token 114 with probability 97.7%, air probability 0.0%
# (1, 8, 6): 114
# Filled 459/5000 blocks
# Selected token 4 with probability 99.7%, air probability 0.0%
# (1, 7, 2): 4
# Filled 460/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (1, 8, 3): 4
# Filled 461/5000 blocks
# Selected token 114 with probability 99.4%, air probability 0.0%
# (1, 8, 7): 114
# Filled 462/5000 blocks
# Selected token 4 with probability 95.2%, air probability 0.1%
# (7, 5, 10): 4
# Filled 463/5000 blocks
# Selected token 4 with probability 98.6%, air probability 0.0%
# (9, 7, 8): 4
# Filled 464/5000 blocks
# Selected token 380 with probability 100.0%, air probability 0.0%
# (3, 10, 4): 380
# Filled 465/5000 blocks
# Selected token 12 with probability 49.5%, air probability 0.9%
# (7, 4, 10): 12
# Filled 466/5000 blocks
# Selected token 4 with probability 99.2%, air probability 0.0%
# (10, 6, 7): 4
# Filled 467/5000 blocks
# Selected token 298 with probability 99.6%, air probability 0.0%
# (1, 9, 5): 298
# Filled 468/5000 blocks
# Selected token 4 with probability 68.6%, air probability 0.7%
# (0, 7, 3): 4
# Filled 469/5000 blocks
# Selected token 114 with probability 28.3%, air probability 71.1%
# (1, 9, 6): 114
# Filled 470/5000 blocks
# Selected token 12 with probability 66.3%, air probability 0.8%
# (7, 3, 10): 12
# Filled 471/5000 blocks
# Selected token 4 with probability 26.3%, air probability 0.1%
# (0, 8, 5): 4
# Filled 472/5000 blocks
# Selected token 12 with probability 96.0%, air probability 0.0%
# (1, 2, 2): 12
# Filled 473/5000 blocks
# Selected token 114 with probability 99.8%, air probability 0.0%
# (1, 8, 8): 114
# Filled 474/5000 blocks
# Selected token 380 with probability 99.0%, air probability 1.0%
# (2, 10, 5): 380
# Filled 475/5000 blocks
# Selected token 4 with probability 99.2%, air probability 0.0%
# (9, 8, 8): 4
# Filled 476/5000 blocks
# Selected token 4 with probability 93.5%, air probability 0.2%
# (0, 8, 4): 4
# Filled 477/5000 blocks
# Selected token 298 with probability 8.2%, air probability 0.0%
# (0, 8, 6): 298
# Filled 478/5000 blocks
# Selected token 12 with probability 75.5%, air probability 0.1%
# (1, 1, 3): 12
# Filled 479/5000 blocks
# Selected token 114 with probability 90.3%, air probability 9.6%
# (1, 9, 7): 114
# Filled 480/5000 blocks
# Selected token 4 with probability 19.2%, air probability 0.3%
# (7, 1, 9): 4
# Filled 481/5000 blocks
# Selected token 12 with probability 98.3%, air probability 0.0%
# (0, 3, 2): 12
# Filled 482/5000 blocks
# Selected token 4 with probability 94.0%, air probability 0.3%
# (0, 7, 2): 4
# Filled 483/5000 blocks
# Selected token 298 with probability 22.9%, air probability 0.2%
# (0, 8, 3): 298
# Filled 484/5000 blocks
# Selected token 298 with probability 99.6%, air probability 0.0%
# (0, 8, 7): 298
# Filled 485/5000 blocks
# Selected token 12 with probability 43.3%, air probability 0.2%
# (2, 0, 3): 12
# Filled 486/5000 blocks
# Selected token 12 with probability 99.9%, air probability 0.0%
# (3, 2, 0): 12
# Filled 487/5000 blocks
# Selected token 114 with probability 85.8%, air probability 0.1%
# (7, 0, 8): 114
# Filled 488/5000 blocks
# Selected token 114 with probability 63.8%, air probability 1.5%
# (7, 2, 10): 114
# Filled 489/5000 blocks
# Selected token 114 with probability 6.3%, air probability 0.0%
# (8, 7, 10): 114
# Filled 490/5000 blocks
# Selected token 4 with probability 92.6%, air probability 0.1%
# (10, 7, 8): 4
# Filled 491/5000 blocks
# Selected token 4 with probability 95.8%, air probability 1.8%
# (0, 5, 1): 4
# Filled 492/5000 blocks
# Selected token 12 with probability 67.0%, air probability 0.9%
# (1, 1, 2): 12
# Filled 493/5000 blocks
# Selected token 114 with probability 99.8%, air probability 0.0%
# (1, 8, 9): 114
# Filled 494/5000 blocks
# Selected token 114 with probability 94.5%, air probability 5.4%
# (1, 9, 8): 114
# Filled 495/5000 blocks
# Selected token 380 with probability 99.8%, air probability 0.2%
# (1, 10, 5): 380
# Filled 496/5000 blocks
# Selected token 12 with probability 98.3%, air probability 0.0%
# (5, 1, 0): 12
# Filled 497/5000 blocks
# Selected token 114 with probability 76.8%, air probability 1.9%
# (8, 1, 9): 114
# Filled 498/5000 blocks
# Selected token 12 with probability 94.6%, air probability 0.1%
# (0, 4, 1): 12
# Filled 499/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (0, 6, 1): 4
# Filled 500/5000 blocks
# Selected token 12 with probability 96.9%, air probability 0.1%
# (1, 4, 0): 12
# Filled 501/5000 blocks
# Selected token 1 with probability 99.9%, air probability 99.9%
# Selected token 12 with probability 99.9%, air probability 0.0%
# (4, 1, 0): 12
# Filled 502/5000 blocks
# Selected token 12 with probability 93.5%, air probability 1.1%
# (0, 2, 2): 12
# Filled 503/5000 blocks
# Selected token 298 with probability 99.7%, air probability 0.0%
# (0, 8, 8): 298
# Filled 504/5000 blocks
# Selected token 12 with probability 82.4%, air probability 0.4%
# (2, 0, 2): 12
# Filled 505/5000 blocks
# Selected token 114 with probability 95.7%, air probability 0.6%
# (8, 2, 10): 114
# Filled 506/5000 blocks
# Selected token 114 with probability 76.8%, air probability 0.8%
# (8, 8, 10): 114
# Filled 507/5000 blocks
# Selected token 12 with probability 95.5%, air probability 0.1%
# (0, 1, 3): 12
# Filled 508/5000 blocks
# Selected token 12 with probability 98.1%, air probability 0.1%
# (0, 3, 1): 12
# Filled 509/5000 blocks
# Selected token 4 with probability 99.9%, air probability 0.0%
# (0, 7, 1): 4
# Filled 510/5000 blocks
# Selected token 114 with probability 23.2%, air probability 0.2%
# (1, 0, 3): 114
# Filled 511/5000 blocks
# Selected token 12 with probability 99.6%, air probability 0.0%
# (1, 3, 0): 12
# Filled 512/5000 blocks
# Selected token 1 with probability 99.9%, air probability 99.9%
# Selected token 114 with probability 99.2%, air probability 0.2%
# (7, 0, 9): 114
# Filled 513/5000 blocks
# Selected token 114 with probability 85.7%, air probability 0.8%
# (7, 1, 10): 114
# Filled 514/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (7, 10, 9): 298
# Filled 515/5000 blocks
# Selected token 114 with probability 68.1%, air probability 0.2%
# (9, 7, 10): 114
# Filled 516/5000 blocks
# Selected token 298 with probability 100.0%, air probability 0.0%
# (9, 10, 7): 298
# Filled 517/5000 blocks
# Selected token 1 with probability 4.0%, air probability 4.0%
# Selected token 114 with probability 83.3%, air probability 1.9%
# (9, 1, 9): 114
# Filled 518/5000 blocks
# Selected token 12 with probability 63.4%, air probability 0.4%
# (0, 1, 2): 12
# Filled 519/5000 blocks
# Selected token 298 with probability 99.8%, air probability 0.0%
# (0, 8, 9): 298
# Filled 520/5000 blocks
# Selected token 4 with probability 96.1%, air probability 0.2%
# (1, 8, 10): 4
# Filled 521/5000 blocks
# Selected token 1 with probability 100.0%, air probability 100.0%
# Selected token 12 with probability 63.9%, air probability 0.2%
# (2, 0, 1): 12
# Filled 522/5000 blocks
# Selected token 114 with probability 96.2%, air probability 2.1%
# (8, 1, 10): 114
# Filled 523/5000 blocks
# Selected token 114 with probability 79.7%, air probability 9.5%
# (8, 9, 10): 114
# Filled 524/5000 blocks
# Selected token 298 with probability 99.9%, air probability 0.0%
# (8, 10, 9): 298
# Filled 525/5000 blocks
# Selected token 114 with probability 93.9%, air probability 0.5%
# (9, 2, 10): 114
# Filled 526/5000 blocks
# Selected token 12 with probability 95.0%, air probability 0.0%
# (10, 1, 2): 12
# Filled 527/5000 blocks
# Selected token 114 with probability 84.2%, air probability 0.4%
# (10, 2, 9): 114
# Filled 528/5000 blocks
# Selected token 4 with probability 100.0%, air probability 0.0%
# (10, 9, 8): 4
# Filled 529/5000 blocks
# Selected token 114 with probability 99.4%, air probability 0.0%
# (0, 0, 3): 114
# Filled 530/5000 blocks
# Selected token 114 with probability 99.1%, air probability 0.1%
# (7, 0, 10): 114
# Filled 531/5000 blocks
# Selected token 298 with probability 99.8%, air probability 0.0%
# (7, 10, 10): 298
# Filled 532/5000 blocks
# Selected token 114 with probability 77.5%, air probability 1.2%
# (10, 7, 10): 114
# Filled 533/5000 blocks
# Selected token 4 with probability 39.0%, air probability 2.1%
# (1, 9, 10): 4
# Filled 534/5000 blocks
# Selected token 1 with probability 100.0%, air probability 100.0%
# Selected token 114 with probability 97.1%, air probability 1.1%
# (9, 1, 10): 114
# Filled 535/5000 blocks
# Selected token 298 with probability 83.2%, air probability 0.0%
# (0, 8, 10): 298
# Filled 536/5000 blocks
# Selected token 1 with probability 99.7%, air probability 99.7%
# Selected token 13 with probability 29.1%, air probability 0.0%
# (10, 0, 2): 13
# Filled 537/5000 blocks
# Selected token 114 with probability 98.5%, air probability 0.2%
# (10, 2, 10): 114
# Filled 538/5000 blocks
# Selected token 298 with probability 99.6%, air probability 0.2%
# (1, 10, 10): 298
# Filled 539/5000 blocks
# Selected token 12 with probability 91.6%, air probability 0.2%
# (10, 0, 0): 12
# Filled 540/5000 blocks
# Generation time: 5.912778615951538

# %%
import time
import json
import requests

filled_structure = masked_structure.clone()
filled_structure[filled_structure == 1] = 0

# The URL of the FastAPI streaming endpoint
url = 'http://127.0.0.1:8000/complete-structure/'

# The input data to send to the server
input_data = {
    'temperature': 0.7,
    'structure': filled_structure.tolist()
}

serialized_data = json.dumps(input_data)

start_time = time.time()

# Make a POST request and stream the response
response = requests.post(url, data=serialized_data, stream=True)

# Check if the request was successful
if response.status_code == 200:
    # Iterate over the response
    for line in response.iter_lines():
        # Filter out keep-alive new lines
        if line:
            decoded_line = line.decode('utf-8')
            json_data = json.loads(decoded_line)
            value = json_data['value']
            z, y, x = json_data['position']
            filled_structure[z, y, x] = value
else:
    print(f"Error: {response.status_code}")

end_time = time.time()
print(f'Request time: {end_time - start_time}')

# Convert the sample to the desired format using the provided function
filled_structure_schematic = schematic_array_converter.array_to_schematic(
    filled_structure)
filled_structure_schematic.name = 'Test'

# Save the sample
filename = f'sample_epoch_{random.random()}_dataloader_{dataset_name}.schem'
filepath = os.path.join('schematic_viewer/public/schematics/filled/', filename)
filled_structure_schematic.save_to_file(Path(filepath), 2)
