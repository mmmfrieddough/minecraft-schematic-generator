# %%
from minecraft_schematic_generator.converter import SchematicArrayConverter
from minecraft_schematic_generator.modules import LightningTransformerMinecraftStructureGenerator

experiment_name = 'center_data'
model_version = 13
# checkpoint_path = f'../lightning_logs/{experiment_name}/version_{model_version}/checkpoints/epoch=20-step=3096980 copy 2.ckpt'
checkpoint_path = f'../lightning_logs/{experiment_name}/version_{model_version}/checkpoints/last.ckpt'
model = LightningTransformerMinecraftStructureGenerator.load_from_checkpoint(
    checkpoint_path)
model.eval()

converter = SchematicArrayConverter()

# %%
import os

from minecraft_schematic_generator.converter import SchematicArrayConverter
from minecraft_schematic_generator.modules.data_module import MinecraftDataModule

hdf5_file = '../data/data_v2.h5'
data_module = MinecraftDataModule(
    file_path=hdf5_file,
    batch_size=1,
    # num_workers=4
)

data_module.setup(index=1)
val_dataloaders = data_module.val_dataloader()
# val_dataloaders = [data_module.train_dataloader()]
schematic_array_converter = SchematicArrayConverter()
# Out:
# Loading training datasets: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# Loading validation datasets: 100%|██████████| 1/1 [00:00<00:00,  5.92it/s]
# Loading test datasets: 100%|██████████| 1/1 [00:00<00:00,  6.10it/s]

# %%
import random
from pathlib import Path

# Pick a random validation dataloader
dataloader = random.choice(val_dataloaders)
i = val_dataloaders.index(dataloader)
dataset = data_module.val_datasets[i][1]

# Pick a random sample from the dataloader
i = random.randint(0, len(dataset) - 1)
full_structure, masked_structure = dataset[i]

full_structure_schematic = schematic_array_converter.array_to_schematic(full_structure)
full_structure_schematic.name = 'Test'
full_structure_schematic.save_to_file(Path('full_structure.schem'), 2)

# Fill the masked positions with pink stained glass for visualization
masked_structure_visual = masked_structure.clone()
masked_structure_visual[masked_structure == 0] = 1

masked_structure_schematic = schematic_array_converter.array_to_schematic(masked_structure_visual)
masked_structure_schematic.name = 'Test'

# Save the sample
masked_structure_schematic.save_to_file(Path('masked_structure.schem'), 2)

# %%
import torch
import torch.nn.functional as F

# Fill the masked positions with pink stained glass for visualization
masked_structure = dataset._mask_structure(full_structure)
masked_structure_visual = masked_structure.clone()

kernel = torch.ones((1, 1, 3, 3, 3), dtype=masked_structure_visual.dtype, device=masked_structure_visual.device)
kernel[0, 0, 1, 1, 1] = 0  # Ignore the central element

# Create a mask of elements greater than 1
greater_than_1 = masked_structure_visual > 1
print(greater_than_1.sum())

# Convolve to count neighbors that are greater than 1
greater_than_1 = greater_than_1.unsqueeze(0).unsqueeze(0)
neighbors_greater_than_1 = F.conv3d(
    greater_than_1.float(), kernel.float(), padding=1) >= 1
neighbors_greater_than_1 = neighbors_greater_than_1.squeeze(0).squeeze(0)
print(neighbors_greater_than_1.sum())

# Create a mask for elements that are 0
is_zero = masked_structure_visual == 0
print(is_zero.sum())

# Combine the masks
mask = neighbors_greater_than_1 & is_zero
print(mask.sum())

masked_structure_visual[masked_structure == 0] = 2173
masked_structure_visual[mask == 1] = 456
masked_structure_schematic = schematic_array_converter.array_to_schematic(masked_structure_visual)
masked_structure_schematic.name = 'Test'

# Save the sample
masked_structure_schematic.save_to_file(Path('masked_structure.schem'), 2)
# Out:
# tensor(48)
# tensor(392)
# tensor(1283)
# tensor(346)

# %%
import time

filled_structure = masked_structure.clone()

# Remove air
filled_structure[filled_structure == 1] = 0

# Generate a sample using the model
start_time = time.time()
for predicted_token, z, y, x in model.fill_structure(filled_structure, temperature=0.7, start_radius=1, max_iterations=5, max_blocks=50, air_probability_iteration_scaling=0.0):
    print(f'({z}, {y}, {x}): {predicted_token}')
    filled_structure[z, y, x] = predicted_token
end_time = time.time()
print(f'Generation time: {end_time - start_time}')

filled_structure[filled_structure == 0] = 2173

filled_structure_schematic = schematic_array_converter.array_to_schematic(
    filled_structure)
filled_structure_schematic.name = 'Test'

# Save the sample
filled_structure_schematic.save_to_file(Path('filled_structure.schem'), 2)
# Out:
# Iteration 1/5
# Selected token 1 with probability 71.9%, air probability 71.9%
# Selected token 1 with probability 14.1%, air probability 14.1%
# Selected token 1 with probability 56.7%, air probability 56.7%
# Selected token 3451 with probability 1.6%, air probability 51.2%
# (5, 5, 6): 3451
# Filled 1/50 blocks
# Selected token 1 with probability 80.4%, air probability 80.4%
# Selected token 3170 with probability 3.9%, air probability 57.6%
# (6, 5, 5): 3170
# Filled 2/50 blocks
# Selected token 1 with probability 81.6%, air probability 81.6%
# Selected token 1 with probability 96.7%, air probability 96.7%
# Selected token 1 with probability 73.0%, air probability 73.0%
# Selected token 1 with probability 97.6%, air probability 97.6%
# Selected token 1 with probability 77.1%, air probability 77.1%
# Selected token 1 with probability 69.6%, air probability 69.6%
# Selected token 1 with probability 97.3%, air probability 97.3%
# Selected token 1 with probability 94.2%, air probability 94.2%
# Selected token 1 with probability 72.8%, air probability 72.8%
# Selected token 1 with probability 50.1%, air probability 50.1%
# Selected token 1 with probability 96.8%, air probability 96.8%
# Selected token 1 with probability 97.3%, air probability 97.3%
# Selected token 1 with probability 91.7%, air probability 91.7%
# Selected token 1 with probability 99.1%, air probability 99.1%
# Selected token 1 with probability 96.0%, air probability 96.0%
# Selected token 3170 with probability 6.2%, air probability 58.6%
# (6, 4, 4): 3170
# Filled 3/50 blocks
# Selected token 1 with probability 98.1%, air probability 98.1%
# Selected token 1 with probability 97.2%, air probability 97.2%
# Selected token 3444 with probability 14.2%, air probability 67.7%
# (5, 3, 5): 3444
# Filled 4/50 blocks
# Selected token 1 with probability 84.6%, air probability 84.6%
# Selected token 2173 with probability 4.4%, air probability 65.4%
# (7, 5, 5): 2173
# Filled 5/50 blocks
# Selected token 3326 with probability 1.0%, air probability 67.1%
# (5, 3, 4): 3326
# Filled 6/50 blocks
# Selected token 2218 with probability 10.1%, air probability 55.3%
# (5, 3, 6): 2218
# Filled 7/50 blocks
# Selected token 3444 with probability 13.7%, air probability 69.5%
# (5, 4, 7): 3444
# Filled 8/50 blocks
# Selected token 1 with probability 86.7%, air probability 86.7%
# Selected token 1 with probability 50.1%, air probability 50.1%
# Selected token 1 with probability 73.9%, air probability 73.9%
# Selected token 2173 with probability 10.8%, air probability 38.1%
# (6, 3, 4): 2173
# Filled 9/50 blocks
# Selected token 1 with probability 41.8%, air probability 41.8%
# Selected token 1 with probability 67.4%, air probability 67.4%
# Selected token 3444 with probability 31.5%, air probability 29.3%
# (7, 4, 6): 3444
# Filled 10/50 blocks
# Selected token 2173 with probability 7.3%, air probability 46.3%
# (5, 3, 7): 2173
# Filled 11/50 blocks
# Selected token 1 with probability 95.4%, air probability 95.4%
# Selected token 2218 with probability 9.7%, air probability 49.0%
# (6, 3, 7): 2218
# Filled 12/50 blocks
# Iteration 2/5
# Selected token 1 with probability 98.3%, air probability 98.3%
# Selected token 2173 with probability 2.8%, air probability 67.1%
# (4, 3, 5): 2173
# Filled 13/50 blocks
# Selected token 1 with probability 39.5%, air probability 39.5%
# Selected token 1 with probability 95.9%, air probability 95.9%
# Selected token 1 with probability 98.9%, air probability 98.9%
# Selected token 1 with probability 98.3%, air probability 98.3%
# Selected token 1 with probability 99.2%, air probability 99.2%
# Selected token 2218 with probability 10.3%, air probability 57.8%
# (4, 3, 4): 2218
# Filled 14/50 blocks
# Selected token 1 with probability 27.3%, air probability 27.3%
# Selected token 1 with probability 96.9%, air probability 96.9%
# Selected token 1 with probability 61.2%, air probability 61.2%
# Selected token 1 with probability 96.2%, air probability 96.2%
# Selected token 1 with probability 87.0%, air probability 87.0%
# Selected token 1 with probability 99.7%, air probability 99.7%
# Selected token 1 with probability 99.2%, air probability 99.2%
# Selected token 1 with probability 99.6%, air probability 99.6%
# Selected token 1 with probability 56.2%, air probability 56.2%
# Selected token 1 with probability 84.6%, air probability 84.6%
# Selected token 3450 with probability 0.0%, air probability 89.1%
# (4, 3, 3): 3450
# Filled 15/50 blocks
# Selected token 2218 with probability 29.3%, air probability 24.6%
# (4, 3, 7): 2218
# Filled 16/50 blocks
# Selected token 1 with probability 83.2%, air probability 83.2%
# Selected token 1 with probability 60.2%, air probability 60.2%
# Selected token 1 with probability 86.9%, air probability 86.9%
# Selected token 1 with probability 33.3%, air probability 33.3%
# Selected token 1 with probability 51.6%, air probability 51.6%
# Selected token 3170 with probability 9.9%, air probability 43.0%
# (5, 2, 6): 3170
# Filled 17/50 blocks
# Selected token 2218 with probability 11.8%, air probability 64.0%
# (5, 4, 8): 2218
# Filled 18/50 blocks
# Selected token 2173 with probability 4.4%, air probability 65.6%
# (6, 2, 5): 2173
# Filled 19/50 blocks
# Selected token 1 with probability 95.6%, air probability 95.6%
# Selected token 2218 with probability 3.0%, air probability 86.4%
# (8, 5, 4): 2218
# Filled 20/50 blocks
# Selected token 1 with probability 90.7%, air probability 90.7%
# Selected token 1 with probability 97.9%, air probability 97.9%
# Selected token 3444 with probability 10.4%, air probability 50.4%
# (4, 2, 4): 3444
# Filled 21/50 blocks
# Selected token 3444 with probability 15.9%, air probability 22.9%
# (4, 2, 6): 3444
# Filled 22/50 blocks
# Selected token 1 with probability 29.2%, air probability 29.2%
# Selected token 3444 with probability 12.1%, air probability 60.9%
# (6, 4, 8): 3444
# Filled 23/50 blocks
# Selected token 1 with probability 57.1%, air probability 57.1%
# Selected token 1 with probability 97.5%, air probability 97.5%
# Selected token 1 with probability 98.7%, air probability 98.7%
# Selected token 3444 with probability 16.0%, air probability 50.9%
# (7, 3, 3): 3444
# Filled 24/50 blocks
# Selected token 3170 with probability 12.3%, air probability 35.0%
# (5, 2, 3): 3170
# Filled 25/50 blocks
# Selected token 3444 with probability 15.4%, air probability 28.9%
# (5, 2, 7): 3444
# Filled 26/50 blocks
# Selected token 3170 with probability 15.5%, air probability 10.5%
# (5, 3, 8): 3170
# Filled 27/50 blocks
# Selected token 1 with probability 81.3%, air probability 81.3%
# Selected token 1 with probability 90.9%, air probability 90.9%
# Selected token 1 with probability 41.1%, air probability 41.1%
# Selected token 3444 with probability 14.1%, air probability 9.7%
# (4, 2, 7): 3444
# Filled 28/50 blocks
# Selected token 2218 with probability 40.8%, air probability 7.1%
# (4, 3, 8): 2218
# Filled 29/50 blocks
# Selected token 3444 with probability 8.0%, air probability 61.8%
# (6, 2, 3): 3444
# Filled 30/50 blocks
# Selected token 1 with probability 51.7%, air probability 51.7%
# Selected token 1 with probability 78.6%, air probability 78.6%
# Selected token 3444 with probability 11.9%, air probability 45.3%
# (7, 2, 6): 3444
# Filled 31/50 blocks
# Selected token 1 with probability 49.6%, air probability 49.6%
# Selected token 2218 with probability 23.8%, air probability 18.1%
# (8, 3, 6): 2218
# Filled 32/50 blocks
# Selected token 1 with probability 70.9%, air probability 70.9%
# Selected token 1 with probability 74.5%, air probability 74.5%
# Selected token 3170 with probability 16.8%, air probability 23.8%
# (7, 2, 7): 3170
# Filled 33/50 blocks
# Selected token 2218 with probability 20.3%, air probability 28.8%
# (8, 3, 7): 2218
# Filled 34/50 blocks
# Selected token 2218 with probability 27.5%, air probability 7.7%
# (5, 2, 8): 2218
# Filled 35/50 blocks
# Selected token 1 with probability 6.1%, air probability 6.1%
# Selected token 3451 with probability 1.2%, air probability 13.9%
# (6, 2, 8): 3451
# Filled 36/50 blocks
# Selected token 1 with probability 38.3%, air probability 38.3%
# Iteration 3/5
# Selected token 1 with probability 63.7%, air probability 63.7%
# Selected token 1 with probability 86.1%, air probability 86.1%
# Selected token 1 with probability 76.9%, air probability 76.9%
# Selected token 2218 with probability 18.3%, air probability 45.5%
# (3, 3, 5): 2218
# Filled 37/50 blocks
# Selected token 2173 with probability 7.5%, air probability 39.3%
# (3, 3, 4): 2173
# Filled 38/50 blocks
# Selected token 3170 with probability 13.3%, air probability 26.0%
# (3, 3, 6): 3170
# Filled 39/50 blocks
# Selected token 1 with probability 56.4%, air probability 56.4%
# Selected token 3444 with probability 17.4%, air probability 13.1%
# (3, 4, 7): 3444
# Filled 40/50 blocks
# Selected token 1 with probability 99.3%, air probability 99.3%
# Selected token 1 with probability 98.4%, air probability 98.4%
# Selected token 1 with probability 93.4%, air probability 93.4%
# Selected token 1 with probability 98.3%, air probability 98.3%
# Selected token 2218 with probability 16.2%, air probability 42.0%
# (3, 3, 3): 2218
# Filled 41/50 blocks
# Selected token 3444 with probability 15.9%, air probability 6.9%
# (3, 3, 7): 3444
# Filled 42/50 blocks
# Selected token 2173 with probability 14.3%, air probability 33.5%
# (3, 2, 5): 2173
# Filled 43/50 blocks
# Selected token 3170 with probability 2.9%, air probability 84.2%
# (5, 3, 2): 3170
# Filled 44/50 blocks
# Selected token 1 with probability 98.3%, air probability 98.3%
# Selected token 2173 with probability 16.4%, air probability 30.1%
# (3, 2, 4): 2173
# Filled 45/50 blocks
# Selected token 2173 with probability 18.0%, air probability 18.2%
# (3, 2, 6): 2173
# Filled 46/50 blocks
# Selected token 3326 with probability 7.0%, air probability 10.3%
# (3, 4, 2): 3326
# Filled 47/50 blocks
# Selected token 3326 with probability 11.2%, air probability 4.4%
# (3, 4, 8): 3326
# Filled 48/50 blocks
# Selected token 3444 with probability 20.0%, air probability 28.1%
# (4, 3, 2): 3444
# Filled 49/50 blocks
# Selected token 1 with probability 63.7%, air probability 63.7%
# Selected token 1 with probability 83.7%, air probability 83.7%
# Selected token 1 with probability 74.7%, air probability 74.7%
# Selected token 1 with probability 91.2%, air probability 91.2%
# Selected token 1 with probability 30.6%, air probability 30.6%
# Selected token 1 with probability 68.6%, air probability 68.6%
# Selected token 3444 with probability 18.2%, air probability 21.7%
# (3, 2, 3): 3444
# Filled 50/50 blocks
# Generation time: 1.8483283519744873

# %%
import time
import json
import requests

filled_structure = masked_structure.clone()
filled_structure[filled_structure == 1] = 0

# The URL of the FastAPI streaming endpoint
url = 'http://127.0.0.1:8000/complete-structure/'

# The input data to send to the server
input_data = {
    'temperature': 0.7,
    'structure': filled_structure.tolist()
}

serialized_data = json.dumps(input_data)

start_time = time.time()

# Make a POST request and stream the response
response = requests.post(url, data=serialized_data, stream=True)

# Check if the request was successful
if response.status_code == 200:
    # Iterate over the response
    for line in response.iter_lines():
        # Filter out keep-alive new lines
        if line:
            decoded_line = line.decode('utf-8')
            json_data = json.loads(decoded_line)
            value = json_data['value']
            z, y, x = json_data['position']
            filled_structure[z, y, x] = value
else:
    print(f"Error: {response.status_code}")

end_time = time.time()
print(f'Request time: {end_time - start_time}')

# Convert the sample to the desired format using the provided function
filled_structure_schematic = schematic_array_converter.array_to_schematic(
    filled_structure)
filled_structure_schematic.name = 'Test'

# Save the sample
filename = f'sample_epoch_{random.random()}_dataloader_{dataset_name}.schem'
filepath = os.path.join('schematic_viewer/public/schematics/filled/', filename)
filled_structure_schematic.save_to_file(Path(filepath), 2)
