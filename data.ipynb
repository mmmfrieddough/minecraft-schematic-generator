# %% [markdown]
# Generate data

# %%
import random

random.seed(0)

from common import constants
from schematic_generator import generator

configs = [
    # Simple shapes
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": [lambda: random.randint(1, (constants.REGION_SIZE[0] // 2) - 1)] * 5,
        "structure_block_types": [[block] for block in constants.AIR] + [lambda: random.sample(constants.AIR, 3)] * len(constants.AIR),
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE]
    },
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": [lambda: random.randint(1, constants.REGION_SIZE[0] - 1)] * 5,
        "structure_block_types": [[block] for block in constants.AIR] + [lambda: random.sample(constants.AIR, 3)] * len(constants.AIR),
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE]
    },
    # Filled
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": [lambda: random.randint(3, (constants.REGION_SIZE[0] // 2) - 1)] * 3,
        "structure_block_types": [[block] for block in constants.AIR] + [lambda: random.sample(constants.AIR, 3)] * (len(constants.AIR) // 3),
        "structure_fill_block_types": [["minecraft:air"], lambda: random.sample(constants.AIR, 1), lambda: random.sample(constants.AIR, 3)],
        "thickness": [lambda: random.randint(1, 3)],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE]
    },
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": [lambda: random.randint(7, constants.REGION_SIZE[0] - 1)] * 3,
        "structure_block_types": [[block] for block in constants.AIR] + [lambda: random.sample(constants.AIR, 3)] * (len(constants.AIR) // 3),
        "structure_fill_block_types": [["minecraft:air"], lambda: random.sample(constants.AIR, 1), lambda: random.sample(constants.AIR, 3)],
        "thickness": [lambda: random.randint(1, 3)],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE]
    }
]

simple_cubes = [
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": range(2, min(constants.REGION_SIZE) + 1),
        "structure_block_types": [[block] for block in constants.SIMPLE_BLOCK_TYPES],
        "background_block_types": [[constants.AIR]],
        "position_offsets": [4],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE],
        "descriptions": [0]
    }
]

mixed_cubes = [
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": [lambda: random.randint(3, min(constants.REGION_SIZE))],
        "structure_block_types": [random.sample(constants.SIMPLE_BLOCK_TYPES, random.randint(2, 3)) for _ in range(len(constants.SIMPLE_BLOCK_TYPES) * 4)],
        "background_block_types": [[constants.AIR]],
        "position_offsets": [4],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)] * 4,
        "region_size": [constants.REGION_SIZE],
        "descriptions": [0]
    }
]

simple_spheres = [
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": range(1, min(constants.REGION_SIZE) // 2),
        "structure_block_types": [[block] for block in constants.SIMPLE_BLOCK_TYPES],
        "background_block_types": [[constants.AIR]],
        "position_offsets": [4],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE],
        "descriptions": [0]
    }
]

mixed_spheres = [
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": [lambda: random.randint(1, min(constants.REGION_SIZE) // 2)],
        "structure_block_types": [random.sample(constants.SIMPLE_BLOCK_TYPES, random.randint(2, 3)) for _ in range(len(constants.SIMPLE_BLOCK_TYPES) * 4)],
        "background_block_types": [[constants.AIR]],
        "position_offsets": [4],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)] * 4,
        "region_size": [constants.REGION_SIZE],
        "descriptions": [0]
    }
]

generator.generate_samples_from_configurations(simple_cubes, 'simple_cubes')
generator.generate_samples_from_configurations(mixed_cubes, 'mixed_cubes')
generator.generate_samples_from_configurations(
    simple_spheres, 'simple_spheres')
generator.generate_samples_from_configurations(mixed_spheres, 'mixed_spheres')
# Out:
# Generating samples for simple_cubes: 100%|██████████| 5950/5950 [00:16<00:00, 361.79it/s]
# Removing old sample 00001af6ba3aa8883f504449019ef92a6d6007863d8744e33a5536cf90bd45e8.schem
# Removing old sample 000047ccd928f6c3cfe9b47c2bb228cd4b9eacfa2823d61e6c51f891ce366ef3.schem
# Removing old sample 0003db7b52b4fa08d4ce0e4a9104e57013b25d529fb4d16e3d0a893ef0138c8d.schem
# Removing old sample 0006a8cf45b5e4af361ae446ac21191333e321478c0b7e7e58e5f353b1132dfc.schem
# Removing old sample 000825eded7a89d12384a6d82ba119770c19101120cdd18f83132cc65c5635c1.schem
# Removing old sample 0008b92290f63c6552f463e949e66845d8492ea3a3b2b924c26a72882dcdb3f3.schem
# Removing old sample 000b216fff0c08141477c18eb0f9e047160c8f7af2352cf6cf94d1fce168366f.schem
# Removing old sample 000b2a943783e7c25ecc5e80159082cbd97b62bced699a3fbf94727b71ced876.schem
# Removing old sample 0011017807047b2334ca07e5098ab20e70e4ef437074cd95e2a76c1dfb578af8.schem
# Removing old sample 0012c0b763022c07b46cf39ddd81082426cd0b5f8a7810f593842079d440736b.schem
# Removing old sample 00133c45f675d8b233c7c669b5d5b00141f57876964b2576d9fec8f0a5d82e4a.schem
# Removing old sample 0014e54fc9521993a9277dc622b723aec4b9c89e03d0af8f3ef5008d498f606f.schem
# Removing old sample 0015c60d470740b01fcad2e41d9829d2e177ba3674d9f671e6e1961e700be2e8.schem
# Removing old sample 001c01ec0a95917b4e2f52e9bd0a32d25f415c0b03c86faf554b80ee7c112b02.schem
# Removing old sample 00202744b0061b0a429ba3a8606188dec5bb89de0a491a8c42993fdd6b296e1e.schem
# Removing old sample 0023741479c05a42c0262d341883c1c92dd528cdbcd49bb28b7f9284ea25f621.schem
# Removing old sample 002489cb5d5a88d33dda8b5de394ee039f135bcc8bbc48222ae024aea9169d7b.schem
# Removing old sample 002741329aa4f8040b6c695acbe1d1d539871c2cd07eb8103465e34c24507b23.schem
# Removing old sample 002a45c6bd8624d109bd5671cb504217ff21ea851613d1d95ec6c3a4c97719f2.schem
# Removing old sample 002bb41f2f4a236f8680ea3f49b033bfa67a68eb9b086c93085316f59bf686f7.schem
# Removing old sample 002f108f34fad1410dcaed565e1595d1ea5a27388cd67e9bf88796be4b4d3be8.schem
# Removing old sample 0035c4c7cd9ad0b033a21bdab1b3020f51589ee9f46ce98ae65db8d04dd8d4ba.schem
# Removing old sample 00367d2c064d92c79ccfb35d3eaef1ccff4cc8e298f2a3fc9268a55eaac0bf59.schem
# Removing old sample 0037e85fbbe51d3692d41f662947c217a719a2e106ef4635ba095ff83fe641de.schem
# Removing old sample 00381af80fcdbdb8a30f35ff6fead16c4f0d1d78952621a54eb544638e267d03.schem
# Removing old sample 003bc3bc98eba6d359ff81cd0acf52742e4d9a36b8a2c4e4116ea1f1300d0b69.schem
# Removing old sample 003c09c00563dff5643a739b8301f7507027124dc03419ef314d42e2e2e59783.schem
# Removing old sample 003e7fd7a617177f8ca9a8f46eb576ec8734fba65d83a955224376f88a29f36a.schem
# Removing old sample 004626870ccec8a8f4c4122cc96de64ac5ba8bfcac313cd5da846624d0a1afb1.schem
# Removing old sample 0049614a0b83a7633eab3966157ed4d2be357f6cedbcf1ea1d5748d6bcfaf20f.schem
# Removing old sample 004f65fd0efc6de347938e0a6c627ee0df354751f8d5eeee1d9eda2f21d08a02.schem
# Removing old sample 00525e8b39cf198f02c8d31726123376981d6d3f14f942f3adc3bdee11dd2e38.schem
# Removing old sample 005b8504a468f724fa0a076bb6538fc043d8637b150cfbd3c948213d4af59f76.schem
# Removing old sample 005ec79e1fff022db1a05fe8d96292ccf9cb6708f1ce251a68c2a370f932fd2d.schem
# Removing old sample 006075ca9a3aaaaec93457b42ddb3df71469e3a23580f3a508595f27c7f6aa80.schem
# Removing old sample 0063082772c53c9e28a53008fb02c06372accecd18cd8ccc4cd0d890c349b675.schem
# Removing old sample 00692e6cf1396d0cb844fa4c3e471be12b045e53a5d6b52e9bb870c60563115b.schem
# Removing old sample 006ff36d9576bfa224e843cb10bcf3a5804f627cb8041e172bbb043cfe9b17ad.schem
# Removing old sample 0073f2254642fb0a4f729bbc4fbb45a7ebbfb332faa07bfced849a06216a9939.schem
# Removing old sample 0077c19e7172fb69ce0203cf30d304e61a94a4880112cce042839ed9ca51c88b.schem
# Removing old sample 00792d880c5e1e954b3f13ca9dd918150f13e850d152af93f320395f46e0ab0c.schem
# Removing old sample 00798e47b576054054ce91fa574e7a4ef15290ca6d316318e8b496f82a31a7a6.schem
# Removing old sample 007d8d2eb30dc866f825fc97143cfa827058188251b214c9cd69b86ad5644d9a.schem
# Removing old sample 008708b2be248cd11e5e601360927558379b96594470205412ce3d2c268ddd38.schem
# Removing old sample 00897605d7969b512a4078fed3391ac14382ff40bdd938ac0e4ffc0fdefd5edc.schem
# Removing old sample 008fb01062582a1156d91c2b66e729da9e167b81d43420afb5fb2c884127f8cb.schem
# Removing old sample 009207bf75347f734b78652dc88be510bf796ef4ecd53a1d799396fd507e80df.schem
# Removing old sample 0095082f12fc335417d034998c7ceea27b59d0b1d6b472400483a4792f31fa0b.schem
# Removing old sample 0096a2d573fb9dc80c5738206eba45dde63074582730d8659ef85ab28590be6c.schem
# Removing old sample 00993ae4542509e1d48255a18f7dd98da1d8c892b4bbc0ea86c4eff6d2a7741d.schem
# Removing old sample 009b97632f7a510728cc955749b1ba500ef36fc0f638fd9b260505037553eead.schem
# Removing old sample 009e0bf1218a0a01d0e4d27fce1efe03a126face5a6ba58024355fa145682075.schem
# Removing old sample 00a14d1d72acb7aa594a3d2755fcdb5a0508382bc045fa1ea99933d27589df0d.schem
# Removing old sample 00a242ab6bb2b41fdc8e683fb5558deaeffa1e601d4c70bf781880ac089e6f58.schem
# Removing old sample 00a3a06d5ff8fdc7086e97b4397effd627e43cfba279213e6428f78a2a68a951.schem
# Removing old sample 00a4c6bc11582190444168de6d13b27b5e35640e7ab390f2693c411a82c64749.schem
# Removing old sample 00a6f326470d6d1fdef2c3fdafdc8404bc41448cf437da86057f8559d1d97635.schem
# Removing old sample 00a8d0b44f29bcde9c995e447a76eccb0835a09fc1447aea2922995bb52251e2.schem
# Removing old sample 00b1617068d1f2a46f3de8227d1ce48871ea74e891ff65ed3d2d2e850a4e01d0.schem
# Removing old sample 00b76ba79744dd6163588d14b4f83c8d4724f97d36555c75f29fa2f13d314af2.schem
# Removing old sample 00ba43292547882b4540e8c2986b0ed28e921a73f817ca5454db8a821b95db07.schem
# Removing old sample 00be8c4c323ef5594d96f4f57a511ba00ed7d8e97336782c509e7d5a4c720f4a.schem
# Removing old sample 00c022261c6906f1e74f672d0885e4d9de081ef7d3c43cfe67d506502ac768e5.schem
# Removing old sample 00c6670730dec249a0e422a3bf6b702a8c153d51f3e2db8b3fead86463d1f38a.schem
# Removing old sample 00cae7630f5ff6fdd2a1cbb8da2abc874ee0c3b8384d141c713fbdc11a0d5d95.schem
# Removing old sample 00ccf1c59b59be8fff92958e83b519c6ef76c14e1aefc4e4b52bd94a7eee6edb.schem
# Removing old sample 00d14da7a12b2bd9dd6effdfc5a5d0b15887468849ebc6634339c58dcb414c29.schem
# Removing old sample 00d67b67853cd9bb31f0e5585f9f499cb3ef091f7c23b620e2f3762bb9a66f5f.schem
# Removing old sample 00d91908c907bd1bd75c6a238fbd78a96b8e8c7d42963c343e966ba88cdb829f.schem
# Removing old sample 00dcd31cd226e32f25da25227acc5ecddbf1a9990159f5302df92e3b21a03aa0.schem
# Removing old sample 00ddd18439979dcdcb54c63e5415694085e3dbbdd6986b433296f11943a35a50.schem
# Removing old sample 00df7cb5aa5370e9a9509a2ce665b49af3f47dc940af41055abf34039b19f8bc.schem
# Removing old sample 00e39406da77f7183402f999cce5d0582adcaad87425bcba8c15b3964507bc64.schem
# Removing old sample 00e7331e0fa0e2e68ffc0417e495b4205ed677dc4c8423a9e065f5ea44757390.schem
# Removing old sample 00e9df16eef8b75e1ba426c823465116313fa9db06c9c3dd4a1b729e82e7385d.schem
# Removing old sample 00ea12350d05f9707268e007f2db1cc5a370279f558cf7644840b7dc0a486901.schem
# Removing old sample 00ebfac5ec15358249259386f49c465dcd9a4725d71b1676e60d254daae76236.schem
# Removing old sample 00ec50dbfe1b62057ddb3b182bf6b1f36e58d9c241f6ab5430f2669e75a9853e.schem
# Removing old sample 00ecce8df36391f84c4080108d2182d9b84fbeade5dab2b351fba3a07e49bea9.schem
# Removing old sample 00effb84616a4ee01a299cad430da4608530a6dd9dde0b50d72e63269b0faeaf.schem
# Removing old sample 00f2eb00ed812dcf8c70ce5f4be50468e37b6d5c68f857d165df8851aae00065.schem
# Removing old sample 00f32ec14234a217e4e99623c4280830b954c4108e07eaf1591d61027c49421d.schem
# Removing old sample 00f60ecf84e83016af3722bbad896b8a526d3b1d5ada72995055845369984451.schem
# Removing old sample 00f8bbee3d237ca51d8b790457266c39cab44e10bb283b6077026d9cf8d8ab2e.schem
# Removing old sample 00ff4c690bb7445dc2c58a6043d222d9ac812db00d20c04ff0c2d05a36ffba52.schem
# Removing old sample 01071f79e900573b5fc10b6742f3253a100131eb59df73b3e937b77905344092.schem
# Removing old sample 0107271d8f63809db2f7800aaa7ad7f24e806ac607086cc98c6f75bbd5d9161c.schem
# Removing old sample 010e882a5f992ce457fa8f3a5414c81f9485074c007f869e15fe2fc63419ec2e.schem
# Removing old sample 011081e094c0ac91087345c4c9b091b894cffcf71dfbc17c8dcbd191c7624107.schem
# Removing old sample 0111fefe5fe67348644a5f93d57ac1850385cbe6c8b30a5a28289bc7de9c1674.schem
# Removing old sample 0115258b09a682204ca3c7860367d41e0e2ced760d7f1fda77b6b0681b3c942e.schem
# Removing old sample 011c0249599f6fbec824d2888e16871cee4b3a21af068512261143ac9809fc3e.schem
# Removing old sample 0123af0fea199cd090a6660add7ba9d3cafc48fc1ef29c5d3138ba37514c6fff.schem
# Removing old sample 0126ec0aa711b01424bc2adca465b4934f6681dff451ce2d3d9c4b8c2d59a981.schem
# Removing old sample 012700e00aa5e86556a8544e5210df3448dc69fd3a2463322378b7691669064d.schem
# Removing old sample 01279e7112724dd0df8a49c68a456b379068d25b4e8d92bec26d01b67dd51864.schem
# Removing old sample 012b71bd5cb4cd6950a19cfd024cf68986650084202709cd0390979478a0b3cd.schem
# Removing old sample 013166413a141b3f0b175228ac0c6737e8f06033b0e73dcff594712d6daca611.schem
# Removing old sample 0132e51b9f25477fd4a8bb05301d5ec561aa7adfa3ec2152d197450dfefce575.schem
# Removing old sample 0133a046dc5110908fae19bc42210dfd0a524102f2c4ed55a96484cb8e1bcb9e.schem
# Removing old sample 013572fa940a591913b18010aa7c0e615069bc17ab7fa10fbb1ac1265eb360d2.schem
# Removing old sample 013ccbd043c9e90e75727e3d744c192cef627275d22d6cbc6d614bf1b1d849aa.schem
# Removing old sample 01428289a4b7d4b2d87b8a680e5d2a03ce3d574fb1308a421ba496a49fd7cfca.schem
# Removing old sample 0144e1162cb3a5f246daebeb2fc1fe3b1869815b1840f941cebba00b438b036f.schem
# Removing old sample 014519404a06f62c66f6ecde0569e63d2b8ec6d0c5c5111d75398c345500ff48.schem
# Removing old sample 01462868c2cf348637b8f8e7a6371059c69b7297fa933ecb9151a6eb2d28b11f.schem
# Removing old sample 014742de491905d33a6f1f78b3ea1a700ec7ddef3c81f74732e0bd620dace6b6.schem
# Removing old sample 0147fdb59a84e637b4cb6033295f4f1e2729099122f74aae05f9a4c67fc9d392.schem
# Removing old sample 014a440e0fbeb9c06ade966911833d7f34227ccb9ccbfe2c2f5ec2f0f5372a15.schem
# Removing old sample 014b795ed19d17c6c952a9c81f0f51e4aa208199ebe8ec6bc2689cd4d696cf90.schem
# Removing old sample 0154f1340ddb0dbed0b79a04f7a764a10ea3404fa90e3a6349a59032afc4b7ed.schem
# Removing old sample 0156743c1d234c569d10206291a38468bbd2d067c2acd2784817ec352e4263dc.schem
# Removing old sample 01573e090b637699fc3469ba68821f5eb7f3ef265ed9a57d1540e3db77760327.schem
# Removing old sample 0158d23f64377f3cb2f8680b6585190ee19d56b393472ae086dec6e8ea07d6fa.schem
# Removing old sample 01594f2211c30bb6e1c28de8c5234468256f9b969bf49c3e4cb0f9e45d672f11.schem
# Removing old sample 015a110e222e104e9311be2b84f4cdc4cd7b8de65875e47a40655c80a42938bf.schem
# Removing old sample 015ac2798f9b6dd8691433ab4c0966381efbfa6f27ef39459b465b9eb7a801a9.schem
# Removing old sample 015c7daf2e0405762931f9dc8f83b72018a694b081314d22d5e2e30db3cd4a07.schem
# Removing old sample 015fae829064687ea2cfcacb15bd3276b0e0aede2ed8930edce9252d92de16c3.schem
# Removing old sample 01612739fd17c388d80b31ca6ccff1117c5a13a7c401eba66345f80c8a20b37d.schem
# Removing old sample 01650132c75b2516117310fe7b76955ec2169fd072c97b19c8897eb89696a8f7.schem
# Removing old sample 0166fb731d1c030d50d85b6c98e7b29d4c05db296c02bf74984242271456c05c.schem
# Removing old sample 01684ee85e9c3dbefe002f63dbed594c6138984fe5c82d70d8b18fe60374f1b4.schem
# Removing old sample 01697417d52be9bb9f2bcb15cce14fb5bcfeb72f708d685e81ab3b9f553c148c.schem
# Removing old sample 016a452fb62e2620f664fa76c38fe78cf6c1a35742741d0a38c3aa009ee18854.schem
# Removing old sample 016c59fbb9a4de58fd3ce8414dd97bd9ad06da6a2a6cb6f4b21f11b56feaba37.schem
# Removing old sample 016cc7b14ad4a8c4233e1547fde057db67fce9feee8fad77a390247e11018f52.schem
# Removing old sample 01702ae06c8a9d10bc292a207612da180ee4368366d479738bb2aea6c4c8bbf4.schem
# Removing old sample 017754891fd37df81a18baf1548d1cfe98cf263f705d17f019e5706cf339d84b.schem
# Removing old sample 0179f3b2edd8d27eb2ed95c6ee094456813bde7af3df7ac9e7923b4623b5c00a.schem
# Removing old sample 017a45c5bdcdf9b79140281dcf05e86205b7c59c3b8645baeaff032bedbf36b2.schem
# Removing old sample 017aa4f2387c1fd900ef22552a0a5fdc73c8b15d48134335e488196d178d9efd.schem
# Removing old sample 017e77c0bbd64c6f469de7a137b47f9d6f0e6351d75cef2e74a5576937ae5db2.schem
# Removing old sample 017f107feadf1b8bb2ddd4e4a19742716ace2c2aff42b655235b8bdd27e97a2d.schem
# Removing old sample 0180533669abeacf4a769df00d503cb1ca9048b1593428ca4bc1f2913bccd41a.schem
# Removing old sample 0180671031a3895e63706679315484cb6b2e8b135703f743146b9bc6bb2372cb.schem
# Removing old sample 01807b30561fbfeb2c377ccb1e6a18bb96d7fc4f147b9c62a1ece973e42b13d6.schem
# Removing old sample 01846b5f113abc8ebe6060bf04438197d7a638d8db7e4d01d2b630709461b1fe.schem
# Removing old sample 0185a29d315ae9fb19b82ce46e5fa2599b5c3d7ed3fc803cf4de9a92bce1c580.schem
# Removing old sample 0188d320e6d612bfbf3b14ac55e13cbb2b8a1d2ec06c654d3d88136d7d11b029.schem
# Removing old sample 0188d5b04b28260310b1c43ebfd2234f673f35fd2159a2f874ce55e1c2dd52c2.schem
# Removing old sample 0189a968ebf4a46cd5822a23180214546ebc18414726e0ddcb0ea36f98863139.schem
# Removing old sample 0189fd34112cc4bf89ff3201608b1765bced40c1af7afb453c0bf1d9c3986ca7.schem
# Removing old sample 018c148bcec6efee7a8bbce54a1178f8c14acf3b1e7a9265d6657eedd1a16683.schem
# Removing old sample 0195ed557bf80501e0e864a02db1e37393ed44e90faa5433e97ee5c54099af8f.schem
# Removing old sample 01987b24892daa6e2acbaf628e39e20d2d66eaf95c24094a0583b1120ff779be.schem
# Removing old sample 01994495fb5a62d8b2634fc1e9fda3d3ebd86a313d2455f702334b025b16ffa5.schem
# Removing old sample 019afcb790a682fb108b4277e216d18ce25cc35a468c3c1ac279933c2b785f6a.schem
# Removing old sample 019e653fd636dd4362dcdcdc1bccf58b74e170dc8847e35ae1f9b3b1cb28bef8.schem
# Removing old sample 01a7c167c9ae465f7b6a9bc8fc82c64971821bdf0846b696a14b463c7083e2ef.schem
# Removing old sample 01aa7cb86391214650d67353100528d54a504a559c09b2d192ffa13dbdbfc787.schem
# Removing old sample 01aad2aa6416c1a505ae0e33355de968405ea9329d503e5053267e97a27cae6f.schem
# Removing old sample 01ab0f40dacf5e1caeb2339ff485f7dfedb346cc1e185e39fca8eb5083c3e5b1.schem
# Removing old sample 01b3145f08be77bfd13c95d261dc663a09f5bb72c325a9e1c44296a4dea247b3.schem
# Removing old sample 01b74c53fb5f2d3663f086a79a1cdf0f3faf25da5343754aaac7318e68dd0a9e.schem
# Removing old sample 01c00279508002dec88d7c2fa6e9186dba617cb6619c309607b2dd51a900fc25.schem
# Removing old sample 01c04371a8c2878c79d95c9e0fa7b0dfd38371179160f6c6d9c23e38bc55c8ec.schem
# Removing old sample 01c1f912e68bdd8d9656a32db6830e495c91d43223e8d969da04955ba0c27dfb.schem
# Removing old sample 01c439f7b91805bd669a6b63a8a1e4bac9b88ad4f829a595a228ded0626f724a.schem
# Removing old sample 01c68467eb7db9105d4a19f8de7117b12606f3c9fa2e40c0b2bba5e2a9e54258.schem
# Removing old sample 01c85dbd27e7e5a5d5302f9ead1868850011ffafbf5554e439fe988efc2c484e.schem
# Removing old sample 01c9e1a539566c9932131c4a727983c81ab26789b57009767261ac21be5d8729.schem
# Removing old sample 01c9fb82d57796bf07e77885b2b73ff8cb898c9404629eb5bb5beaefe59195d2.schem
# Removing old sample 01cdc934bf54e76f4191b161dea610d648b64043c75a9f68fe84bb5ec7fc98f2.schem
# Removing old sample 01d4b1362fcb4b9f5453f1b7878ea97bed06224570d7db596ade99da1291c23f.schem
# Removing old sample 01d594818bb32407bb465916be7ef3e572e5e7dddf93431d1cf68b73901da952.schem
# Removing old sample 01daa6887a086f96f597ae294ef34ba194c0a5b0b5286fd2fdb6999fe0369b2d.schem
# Removing old sample 01e44b72c77eb66c8f8ac44a9d80b34ff7a518b91683a91fde22dd31efa04a86.schem
# Removing old sample 01e7b2937b417087b87994ebdd5a67513cae847abcab8f29f7e6a5964f36c23d.schem
# Removing old sample 01e8bab37e86248dac305aa3be5dd572a3b5eb9c6a1684dd3652122084faa827.schem
# Removing old sample 01ea9f60c1607e9a08105776924fd56311e78dc379a273d5da601a4584043b1a.schem
# Removing old sample 01eb00951c400e160310041a0d58a1ba41614ea1f527d59009afe65d61a0b9ef.schem
# Removing old sample 01ec64a34137ce78cc0d5f9df3b6cb23941e923d8ca4003f567cdb178bd66d4c.schem
# Removing old sample 01eec12b6178db5884bb681d1bdcd8190cbf23f6faf9fc70e91f8d715d029d82.schem
# Removing old sample 01f03c6b8b47a15b36e90829e93dec95ea346adf52581cb550f69374f5116028.schem
# Removing old sample 01f68c2446cb32c26305c51ed3162f16cf392e96433fb18605a739b56ba6a8d2.schem
# Removing old sample 01f7703f2645e74f5263f68512281493037801b2b367259283e14453e9293812.schem
# Removing old sample 01fdb1b6a6112561bef9529791821d2ad2bfdfa1e6fd4732164b4bfb9091a0e0.schem
# Removing old sample 01fe4257ac896b85c287e6c948fa03b41ea5956916d6800a198944baed335eb1.schem
# Removing old sample 0203a49cd0b447b0eb05440deacc70deb9a151080a0df60810eb8a3d8c986d4e.schem
# Removing old sample 02040e313f67b9254d5644f4cfe2cd318ab01e649b5874cf754b1a4067d6b787.schem
# Removing old sample 0204bc6bd9b00353d47b0719bb9347ae59a6e3b58d3e6821f31ada13f11c1776.schem
# Removing old sample 0206051ddf0ae05c7b81a655ab2968e33fd59954755f881f86de6099cc9533ca.schem
# Removing old sample 020c52c1ae5dd641e386ea57c9c538394a303530a8cc5e069ac46b0c4b909e12.schem
# Removing old sample 020ea330cae3e84e210628869094fc0a4ed96b84bc002ad19c5b3c8902bd8cb9.schem
# Removing old sample 0217126bcfe64a75bcd35d35a6fbcd9f83fbd7d4b7913e71146057bc61b18c16.schem
# Removing old sample 0217de89d80e6846424a202ffb4699886a2285b463fd69509089a39e0fddee79.schem
# Removing old sample 021856fabf36a6ee889068153693cccded76f779a2912de9aef478c096bcd611.schem
# Removing old sample 0218a034e4a161cf5c34b9a68cf509fb53022a83cefbc3da26a1627f41e9bf42.schem
# Removing old sample 021d4bec0cf83a0619d9a1a5119fb88a0e668a6373d1d16460ee491f0b67135a.schem
# Removing old sample 021f554994255b9e8f9441070d619d7b7a40df25338de99fdcd660843d11fe9a.schem
# Removing old sample 02220aa248960e90026761eb99eca3d33c5f7cb5f23ec45ebd4dbeb56f63e92f.schem
# Removing old sample 022231d11855e6ea04eed49c4ae9f1d529957cc96294137781a4afc9a0fb321c.schem
# Removing old sample 022401f637c6853265baece987e1a27c26bf89284f2ef8bf0e927cb24bf4162f.schem
# Removing old sample 02255b05185faafecd324357359ff52945afdcc4fb3f30d2241b6d0ce1848342.schem
# Removing old sample 0225f889381e71aa515618c305b4492586dba070195258a814e9ff4a5ad3b4c0.schem
# Removing old sample 022f4c1a4a04acb2e9866de1601ece34a8280ec83987f1d833f847e42a1987b9.schem
# Removing old sample 02313666194a98ad4b93ab49dc8d68c461343bd6b0a96bb29754d83e05f4c9b8.schem
# Removing old sample 0231a603ef1ca25d6febefa928c3cef4626c3e5c244fabc7e013fd1d5017937f.schem
# Removing old sample 0235c3b176439adcfe24f57f82243e086578f1aac29d682f99ec8a5a5cbc56b3.schem
# Removing old sample 02369db73d2cba62fcd5f5cd96a35f1608e10352bb9bc3424592b5d4e850cdac.schem
# Removing old sample 02370574a600eb6beb4e335938285ff23c96b0b03c0824cee86a196abb2fbf9e.schem
# Removing old sample 023a27c9aa8ad80ef520f7708d2a85b6ab6d99c5f4d236d026ff15d4f96538db.schem
# Removing old sample 023a9db3721ab01472da01684843be061191e0e28f471387ed7a7ca170e89fcc.schem
# Removing old sample 023bb0cb4cdc68f46e660d55c52d4c4b672ca1a1884818a2cee23947e58361e4.schem
# Removing old sample 02410992dd2847cbbf992d6520ffad2b2928847bfd95cfaca0abe7ad4c9bb1c1.schem
# Removing old sample 0241bfb07417045350083005c2c2ebc4e485a2d7a8d2a6cb49fb01e2d55137a2.schem
# Removing old sample 02464fdf2451f20f97f636edda4944bd05e507cafff0fb4819de8f45d662a487.schem
# Removing old sample 02475807d02657f6ae9b892d8f7450a3b39e045ad63d60dddba3ba3a531b7a2b.schem
# Removing old sample 024afd2bb13bf325bf0c82bff4574f0eff2c0c4f3d68e05973cf161d28c131c4.schem
# Removing old sample 024c7553dda39db2b1e3d18c2224c9977befd85b0a4d3bf61e375b8949dc519c.schem
# Removing old sample 025547852c6d8276d8401910f6406ccca70066e5e35765a54a88aaac95d26912.schem
# Removing old sample 025c333cefd4a990f575681038f92625808734e43911e9cedea222af95acc960.schem
# Removing old sample 025e530975688428b6a1afa72a7822996fd9823b0bd3e8f1d592551b0e0711db.schem
# Removing old sample 025ed40f09d4fb7f3a1b7cd5c90fccc6e96fd54a2fc3ea512280240112af302b.schem
# Removing old sample 02643ff919dd80fdb131227d89d03e190fb835f69d1ae9b726e0375ec60c052e.schem
# Removing old sample 0265160131a53c368dda4930574ae0b31d840c70ec966dcfe2770222d4131d92.schem
# Removing old sample 02675f4f0ab313ef699c8a711b86b39214a1754553ddc12cdda6ffa62e944827.schem
# Removing old sample 0269ba4b0307aa631e30a66d0ab4d1497257a2e9cd8650cb3fbbe93f31a909f1.schem
# Removing old sample 0269dbc524cf78a9039bd757c0da4625ec77150382fa1629dd5f50be9b7572ea.schem
# Removing old sample 026a1e58a1f4194642593a6828f12a5b146948786b5ead765fecdfbdabfbfd2b.schem
# Removing old sample 026b6523849aa37c78f9713afe37b3034d7f0b4c42d8b9d90b325b1eb3742c82.schem
# Removing old sample 026c272763e95057404acf611ecaeb8081c809e6d65b60f2d23616490f736c92.schem
# Removing old sample 026df7c50a27b36c3fdbbdc7e4058adf2e86be65d886db813c8ee5eef8fda056.schem
# Removing old sample 02749b965ce1960421cf7a5e0779cb7d181301bf92c9b5632edf75a06aa64bf9.schem
# Removing old sample 0274a83d63b33ba688bfcb1bf5444924360a9491fc4a880d749ef347e2aaa9e1.schem
# Removing old sample 0275d10c72ae337ed0a40646d81eee965252d26e14abb00f28df51fd1d9370ed.schem
# Removing old sample 027861c0bb68f0bca82efd82cb68a37105ec51a0901f5f204b8487a6663b4b37.schem
# Removing old sample 02787b295f984530037890dc07a5f4845798d86b19e14b763daba8de68675719.schem
# Removing old sample 027a9cd69139a35caac6fdd712a715bd39aa1bb1b4e63600f1fff02650c1451a.schem
# Removing old sample 027ea6b9f3a687f8cdba478617c93b59ebbcd5a8841f046fb31dbec6ddc40415.schem
# Removing old sample 028201dfff763bc91ec6124c23d3aecbcb4b199cacfbd87a79c4d9d22c7c0753.schem
# Removing old sample 028850a739000fa27602546578ed7285f4a1855a3e60d8318ddb726e98850f70.schem
# Removing old sample 028eb3b23d31158676f13d279ed6d1205587de81a2dca3c19a83bc242a6e61f6.schem
# Removing old sample 0298d700094936d8dae927334e29a835638415edb1fcc8f34502b68f406e3689.schem
# Removing old sample 02991d30a678eb5bd177012aaf74f38fca80f89c56db2c02af2aa6513cd086a1.schem
# Removing old sample 02998f0db0a6dd76a2ebbbafbb7f547baf62548725678402ee6149e4cb13d59d.schem
# Removing old sample 029dd6b6a17ff8a013813d08811ec01397bef45a6fb18693f36e8d3fd5cbef06.schem
# Removing old sample 029ea3027c19ec5522bf9db53c5985e8cf2b4e87681e9c257e6c638e9462dc9e.schem
# Removing old sample 02a268696e42c09af4f9b8f00b40c206a60dc705f4ce32793526760b178d782c.schem
# Removing old sample 02a4b4fc3e16053d6e5719b7f056dbd14a7191bf7b5f861704876894b2d8a51b.schem
# Removing old sample 02a6a764d7aa069900d2c4e6858c85b1e93056979faebefab57a32f6c856d2c7.schem
# Removing old sample 02a704aba933f385c2979f9aa2540af88866367f8076dc5f2e29b1e4ac880a1e.schem
# Removing old sample 02a8675e3429f27c56d1287ab54f800293a5884c6488a97e3497275d055131b8.schem
# Removing old sample 02ad774d7ce498617b57d39e195538481cbf8ca4c4e64934ca9bc53ff3de065a.schem
# Removing old sample 02b1641a6f424f34f84418f635a19145167a81ab2a652aa93dfebbf41482f897.schem
# Removing old sample 02b7a6c9c123268c40bb13e20b62abab9dffe636675d8e48406453a7e6452f77.schem
# Removing old sample 02be8ee3b0c50939ef40f1fa822a051e85f64a068aca046f3eb0065d291f064e.schem
# Removing old sample 02bf7e456a584ec428c0fb11b76f09144e7445961ffcd55e0f6ac2119cce2f97.schem
# Removing old sample 02c260068198ab217b2afb947d0d9a2452ec8ffea63c607cf77ddcb115c182f7.schem
# Removing old sample 02c3aa64fd8daaf1bd063a28d8435b324c7cdfdca8d289c8768319c111e5f25e.schem
# Removing old sample 02c7f6764e728c51c4632d9dd18708dcf4f943846b942f613b0f724a323200aa.schem
# Removing old sample 02cea4883c1fb118aa0b2b0c7681b3af41f01b3a4206760940e9c03fd128e4e3.schem
# Removing old sample 02ced2d16fd1fa30b257accced5b3370c217f81f49a6331cd40880df75c5e832.schem
# Removing old sample 02cf5b8a55dce145810e857cac68ccfc78269f2eb221da6e7fd625eb13090075.schem
# Removing old sample 02d3c874870a2c92df82cd598a3c3d400434b0b4dc566264bd1ccdda9e772f48.schem
# Removing old sample 02d4970caaf90a793f85af993c04e1a4a10d2f57e3e714288ef762c3806776a9.schem
# Removing old sample 02d57902fbda72ee0a9f88ee29aef40fbd66812fa03483e8143923e256055fea.schem
# Removing old sample 02d61daafd088fd521f9716a10050595013e587771df86078824851b37440002.schem
# Removing old sample 02dc1a7e76bf9729293797e57e4d4b4c9e1bd5a8886541d1d85f5e3872cf9102.schem
# Removing old sample 02dc5fc1d166c443d45d79306f61938927d7dbd16d439e52ebf4241d3d51a27f.schem
# Removing old sample 02df76a7bfbc231d51d7cd4cf10c7f3d7be6183549992f6b64b10473bea43dc0.schem
# Removing old sample 02eab5a68ad3b1edb7f98c851376457d7085928909437432d39110a0af9b850b.schem
# Removing old sample 02ec0d87e5b164e97bf90b202fe3c91e13ae8adf8989db9e1912b255ec6e5fb9.schem
# Removing old sample 02ef03422b8abba349176647ea6aca00b72623edb3679ffde30369556ca1aa08.schem
# Removing old sample 02f17fad9914e57242eaf077d93e7012ea2bb410be19441629c2ec64306d9b10.schem
# Removing old sample 03001b6417b244b0b0cda3e5559e203740dd5ede3910e0c9b80b3ad5c31fe698.schem
# Removing old sample 03015a542111fcf39f473980709bff6b124ca31a60368a5c6c6bc76dfce417cb.schem
# Removing old sample 0301e8115912211c3f367224ceb2ff3e2af5a307e92f0468337e75e53324446b.schem
# Removing old sample 0301eb120004999e8189b4f1f8366d62efa490d70bc5ce79dfd1ca1ee63f0c3b.schem
# Removing old sample 030648a1eb9fa3ee75d7b576918992b3c0e58a22fd6fff40a966cf19e4b212be.schem
# Removing old sample 0308e12c5786fb8642f030e59608af8abfa22af766b1ee4e6e23821caa45d090.schem
# Removing old sample 030c965e89e8fc78be620ee1494d4ad3a2c6352d1aad6f966759a3a5d6569cc4.schem
# Removing old sample 030dc2ce95ce82a9a90d4543db8341096e6e76736ce5080f4f954f2d69ce7427.schem
# Removing old sample 030f7f18d23e0faf49e5f13a4d53ff0d04020bd98d7d5ce6c9c7e8bd138b05d8.schem
# Removing old sample 030fa75647dd0fb9f416904c0e70175ade1c989413a5116a9c6075e72a22f555.schem
# Removing old sample 0317974aeb07c36622205c2cab1501fe26c8c866db855a6f88b9fab50985e118.schem
# Removing old sample 0318a6f92925b8ee4dc2a8f66dfbf34b31809b522ac050ae52188e1f02b177b0.schem
# Removing old sample 031a07f8b722dfa505d8689c790f8a62f3c0480f36ee5863a883d8e5d4127457.schem
# Removing old sample 031a2267476434033f432b60bfd856919ad9cd5ccc6e72a9f2597c4f03bc5821.schem
# Removing old sample 031affa161a77dc5be77e5c2b6cbe36f921218759d116e6cd247568ec93e60a8.schem
# Removing old sample 031d52983347207bf08fd01247c33a6ead34e8b57052b611ad84b9bada5bffaa.schem
# Removing old sample 031f2e68b792a336b4cdcfbee0df872894e14cb625e3add9d072897a9df42301.schem
# Removing old sample 03240ffcb1445ba69717084c8834ac2719700931c7ab432d58d89399dabaa822.schem
# Removing old sample 0327118a03c9f55c8c95bcb1181885bd70216261c568f3493eee6b73f81c0979.schem
# Removing old sample 032ae4fdc2a83429ef1d7c6eb2c35f1bfb3e9f5dcd2e3d7c2dcd059b42529c6c.schem
# Removing old sample 032c873dc454f9845a3be9a2093e32f11e28ea01a22ddccb321b034c14792b09.schem
# Removing old sample 032e3ca46a9f0386ec75431a3769c5a1cd7d44da256831966cbe74346010d57e.schem
# Removing old sample 032f258962b275a05594474801774fba2f5e3ddc2dad73ce8453a768d7c33d67.schem
# Removing old sample 03302b81f1261c34e87f03ff14ff53d16279c4541dd7089a8b43ff69f562e0b4.schem
# Removing old sample 03307871acb0e5bc82ab2b755f660f4a85c0b3ba3387fa1e5e1382b8c0804da7.schem
# Removing old sample 0339aee518f96bda666c294e1b10be793368f0a7bf01e797281467cd9ae7e05d.schem
# Removing old sample 033af00b034cbc94bbf078f0b94be754f0bb9357c5523389fad0193e07ce975a.schem
# Removing old sample 033b4b6517bd8bce1e1daf23d376b80b861f9501f1247d0f2debf543fb02c427.schem
# Removing old sample 033b96792eb303f09731c9d889089a38212642b93b2191c8fda65475e64bf92a.schem
# Removing old sample 03402406271df187e264f2481ae86f6495b018ae479339d09edf3a2d4cdb534a.schem
# Removing old sample 0341e08d33e422853bad188a9d7587a26b88e157da14e7f647c204a4ae702d63.schem
# Removing old sample 03435d32bd070e3cab8b98a711d4055c4447b78b98d0a059d1835e1e3963f026.schem
# Removing old sample 0345a3181006f4163b633ad2c3d2bff413b6d787fb80278ea2eaf32564264e15.schem
# Removing old sample 03497f4ce4bd75638206a191a2ab6d4d0eb6d0a593b9ceffa7ed7f99e3f443fe.schem
# Removing old sample 034bbdeba60be3ee383176376aff3ac733cb6daa551f4fcef3e3b489d0a30d77.schem
# Removing old sample 034c4b3c24cfb8be40992a99ff4ae7b2e2e90edfca569cec12dc437b978a32e8.schem
# Removing old sample 034e5110f38ef040bea52d17a9077db09ee8e16b97ca716e25ca4930a2eb64e2.schem
# Removing old sample 034e93e77eebc5990c7ab6a8cf3fee75f9e56521e50c15198ee570f068f4f82f.schem
# Removing old sample 035058d54f8283ae88ab01b4964cea154d68e102e5d9ab486c7123f6a7df8106.schem
# Removing old sample 03553876a509d9530fa5176921d806bc0eedaa4823b54d80d2e87061944f8718.schem
# Removing old sample 0356f30d5719b961b683c3e731e0057594c4559726fc3a7ee283da264310304a.schem
# Removing old sample 0359cef16026aa97f10bd7e2f6544549c8eb6892373f079efd82e1496cae9dfd.schem
# Removing old sample 035e9e470a8f5f7364f03be9c152686ee1772ae3be6a587c249ffc521e0a074b.schem
# Removing old sample 036160a9e39a887e36f613b44f5bb409a2386581a86956ff21ee7e7b039b3cd2.schem
# Removing old sample 03629c4fa2735235b0321519cfcc6c7dd998578ee13de30f2cfff62feaa0718d.schem
# Removing old sample 0365dc43b28ef48305492352bee3b631a456716c37d68f4820f77010e24da5df.schem
# Removing old sample 036888f5180f6c76781098088249b5ab772b3b66ce7d5fa1a81d34d759a41dc1.schem
# Removing old sample 036b6443b964a2fd12b57d5d4cd19d5baa4f315ca3cf3dc87f06350a263afb74.schem
# Removing old sample 036bd51c6cdeb3ea72bff744d115904ae50d0c3747897ef5994e8cb2c642e648.schem
# Removing old sample 036c52d4ac804a48d04d444aa34eb2378fdee600f53aecafc928391b04891592.schem
# Removing old sample 037307b7f32f867208459f1b3993b01ac8b0c02b8138a6d986dec6f75749deeb.schem
# Removing old sample 03788ed4f4606126ad68bf506a05fd03277d1e0d35d8ad53bc1c0bfeab7d87c1.schem
# Removing old sample 03797e94c099805e519a4628c51604c7d51cc00277f534602177ff168278fc70.schem
# Removing old sample 0379c7d2ca56d325644ba7b929f9b945418246f2d6044194d0d727df7b0fbc7b.schem
# Removing old sample 037a688a6927452c1ecf7b77c5d1f93effe72a5ebbe7bb3bf166fea03b1350e4.schem
# Removing old sample 037c9cb5579d446cc7281997d91bf1174d8aa98e51d16030067376f9c1d655ef.schem
# Removing old sample 037cdf078d3efcaee80edb86ea30d4b06f8b8fa97c6009d314eeea900220a431.schem
# Removing old sample 03805b70475346bffca7c73020377e5dc7d1d6f5f06e85c10e3729d970fe5fda.schem
# Removing old sample 0381987751bf0d0c51038b748110c5217352e2ee4a0a74a0a251894d0c3bac42.schem
# Removing old sample 0383c35b84f68e7136d9e765d2c863b87826a8990028a9fef3f700ab671ea387.schem
# Removing old sample 038433d3b6d7787839db304b7925be4442aeadc57fbf835387b8fe939f0e3dcc.schem
# Removing old sample 0387547f5d537ae4ea88223809a64d631c0a87fc6e2e474c8ef80d0f7ae192e8.schem
# Removing old sample 0388ef47fb9136577f1311fa1fe26ba7a4196332e6c45bac2a1473dbbbca9ef2.schem
# Removing old sample 038b9218ee9bcf4fb92357d9dfdd439cc7f9cc206a5c113430e5a5a16dc17f6c.schem
# Removing old sample 03911eac911c43664f58baf24745388d8415d7a4a146bf563485066038bca87c.schem
# Removing old sample 0398568d1192bb57b433889ba7b8eee33f8965a1688b15a12e872666af1c62ed.schem
# Removing old sample 039af1e31705285a6940c914279c7b8bf3c3f635d9bcbe863ac4a7c1d63a640f.schem
# Removing old sample 039e8e119e1ab15ebdc1a8ffbe779805e22e773221bd91a676f856a800636ad1.schem
# Removing old sample 03a05cc131b8848ab04cdacdb11af3c04e1b380a406594b8f995f60cdc1263f0.schem
# Removing old sample 03ad44734c9e87789bac9a26753fdcc531f95f910cb5db76cfeecacbe859c961.schem
# Removing old sample 03b5514f2052320722e23a713bf4ef0291ff95cf7d1c4f4c2f8dd552f534714c.schem
# Removing old sample 03c05f94d1af1e78920708c78077fb6822038de17ac40c4237342c61bb263d6e.schem
# Removing old sample 03c207b5d9888cac9cb7f9cdff35da3bd4db1a76476a10f1f4672b32bf280b2b.schem
# Removing old sample 03c77497237a6700e6c61cf95b5e3fb3b3ad294e41a7cda74cb405d02bae8930.schem
# Removing old sample 03c7c143809016b6c2d11c08bfc31180d358f64659acfe7a2064fff23d06cb34.schem
# Removing old sample 03ca773947b44150d4b60a811aeb4191d595357af6bd9481dcd2cd4c065ee971.schem
# Removing old sample 03cc484fcbbbb0be0ad6f4f0e2b04758c881148de23bc4b356e4f966fe3ff155.schem
# Removing old sample 03cd50b8b9b044bbc247ac5de7bda964aab96eeff946a4d5013311332298a747.schem
# Removing old sample 03d2128754d173bc67941b1a87f9259cd57b1f56ffbf0f549fc634383507d0cf.schem
# Removing old sample 03ddac010bf41d55cd1256fe76bf0e5eb21c070108f8fa266d9174de6a9d23b5.schem
# Removing old sample 03ddf28f53cf12850f05a18be7ae2a3cc7ac5a8cdca7844bf6e3a1bc5fbf588f.schem
# Removing old sample 03df531cb9faf97459e86e3cc330e82cb256de8e2af8ff7aa58941f8714b535c.schem
# Removing old sample 03dfe7361baf9d9d62d993fea37bbf8b4bc9a07d0f66a224595100cb98b61fd0.schem
# Removing old sample 03e1fe3c41e2eea9ed428447ef8e7c0b84ca571f2808396c3397cc537d6998c6.schem
# Removing old sample 03e26aa0c420ec0a4abb4561dc32794a419e45675bb97b4a849a77a645a0c170.schem
# Removing old sample 03e57220bce033980931f651e5ff3138a962f8d6791bcbd455352ceb63e7100d.schem
# Removing old sample 03e5bee79b715e6a16ece6468aa054561d194b87ab67cbeac6b0741f5cc41dee.schem
# Removing old sample 03e78d9d08029b1a1ca06cfc14385a7c6ec6490ed82953215c49d76193a6d51c.schem
# Removing old sample 03e944925237ddc4841fe21fbd7d6b420fd1a80cb2afa61305f9d3e2836486ef.schem
# Removing old sample 03e945d2c57a3eb31785c8e9cfc9efa1c0d8c31aebe7dedbb5c12d34e88315ce.schem
# Removing old sample 03ec606d2e84710d72a531139687fdccf5021c16a34f69b836b31b9db37cfc6b.schem
# Removing old sample 03ef5b792a462c0e37f40ed4d59b2f6b745392a4638154240a191edb16275519.schem
# Removing old sample 03fa18d78f966c8cf1415cf9608da0dcb3cac9ca088c8b73832b9b9489d82d23.schem
# Removing old sample 03fa5ac2b9a050504b5826132f1ee905600f78b8b717d386359d61e4bc835204.schem
# Removing old sample 0404e48d583a4a587a3a96c43f6ba4a65178a027878235c119551ab037780c37.schem
# Removing old sample 04073f55b028dbcc3ad0797299217bf52c60db15bd1aed3c36aea016851bd0fd.schem
# Removing old sample 0407f979029c1ac5450945dcac79bf6fb6fd8ded07c32c81b79b64d38675985c.schem
# Removing old sample 040c53cd8dca204b3d6abc547bf44c473785650aed56378a724e42b48ae6549d.schem
# Removing old sample 0414e026cfaedfddbaa5bfeab1f8bf7415a49d1a7e374b8087031b1d031d61b5.schem
# Removing old sample 041550cbd35d83df8671326b8963e0ca36880f6a7c0c1a818af6f6c5f6adc50c.schem
# Removing old sample 041800cf6c0f57c99ad8bf90085b330bae6ab386b2f6fee934096edd4e54c62f.schem
# Removing old sample 041821c876f8f2daff350f490365cb5b90f55ebee90647d5eb67be0b4868afd0.schem
# Removing old sample 0419de8dcd1a32486a5e901101afe6de3e0158431f27ed22787393debe0dff10.schem
# Removing old sample 041a1696591156a3e2dc8b16cbb2bee926584593feae96a28da37f2e6309d02c.schem
# Removing old sample 042102d7bbc2c63843ce7caf70e86c6fe4b56e475a7237ecaabb36a0fdb83192.schem
# Removing old sample 0426a4664a8244863ad05f57d70cc2abc9181b60fd474db3b071a1d6246dc6e5.schem
# Removing old sample 0427c27289c3f5dc56529c5f659d09727025a4726199b57812e659e34df3f2cb.schem
# Removing old sample 0427e4f39408cdd3fa7f0119c8067c16d031f55fb1583f0b7c27090e78f9ce15.schem
# Removing old sample 042facfee3ea16f4989df0bc7d9496e604430adfdaa289d1df38918fe3b90001.schem
# Removing old sample 042fe280c26c0b7c1b78a5c874423887a9fae1f11ca9774fb0b2cc601c404fba.schem
# Removing old sample 04349a1f5bb6683519646975482201ea690dde022becc880744cdf1584700695.schem
# Removing old sample 04397abb2b6f3e6a201d07ee4ab05addbc37dd7144df08356000bff419fab34d.schem
# Removing old sample 043dfce5da18fb8692c06df90c482de5ba30efdbb136fae700535ce563b3ec3e.schem
# Removing old sample 044343b047dabfe81b413a7c038daeea49ca9b03eacad0f33273538ddf026265.schem
# Removing old sample 0444c023dacb5d0571918d96c185845d3aca85843694c3b624f92408b5dc5006.schem
# Removing old sample 04493dacafbf86dbfdf5b6b7e5fffb0c90990895cce4db9cf097d9ad4b01f73c.schem
# Removing old sample 044aa09979a68973fe796706e95e5f57f860e092d0fc87bcb55e91dbd6caa926.schem
# Removing old sample 044ab51bbbeda0c76058ea08312aeb3eff94de09bc8b88f446b1045a21cde196.schem
# Removing old sample 044d26415ced1407e86221c1f34e1b4c82a2770ed0ac538c4005a99083cc3c77.schem
# Removing old sample 044f21e4c58812ad139844dd0a9f22658fa32c2e9bbc092f3cffd20b6019d5f5.schem
# Removing old sample 045a7301a61a108e875c6a2e7ba620caa5565d9e36e01d6322dadabd5fdbb3e0.schem
# Removing old sample 0460535a5547274d0776e0645790f94322736c26b57329c5586a794754ed952d.schem
# Removing old sample 04617ba27950cf77a9c6ff790ee51e1cc1c9f26bfa3672a9999b7265587d15fc.schem
# Removing old sample 04619e7ac609cc412582e320acf341f2b33b276f5d1ed5bf7fadf7b30a0b0f5a.schem
# Removing old sample 0463ff2e1470725cdead76f0de9d0dfe8fff1c4a27d8917cbb070547016683b9.schem
# Removing old sample 046acc4a158a53a6ddf8ea797251b2a9b6c99c9a44a9370e0d9fd89962626c59.schem
# Removing old sample 0473288850eda9cf7dfe07ae21eddc9ee20c4cca59f05708c31b9e83eebb2e67.schem
# Removing old sample 0479186bdfd9d6e050e649e1c03a3fe9191efab6e0a0143498a29340b0bcb16e.schem
# Removing old sample 047e2efea6b7454336b0d7ff0cb696a7d3979adea1363fa084b4aa20723f2928.schem
# Removing old sample 047e3b7d633f40c788268eda10dcb150a49ba20a412762ee688a6d33b320efb7.schem
# Removing old sample 04820f1a576999560258ae703f0e4cfe2e6a0e27077bfa2863ed496f20c2e4a3.schem
# Removing old sample 048660643095d1ee0b3869ee8bab9cfe56c29f4f12e53d506f103b40de042e8e.schem
# Removing old sample 0486adaa22644be4ef1e2ac02b8cd9f61b5675bcb5332301f2eee4d065e3e4d1.schem
# Removing old sample 048989ca03f08cb68ddd2dbbd7644318fba0d607f894dfd0c8526e44162f2fed.schem
# Removing old sample 048db9dded45c4e03cc3c8c1b44342412c48610a7efc55238ac915bf44416202.schem
# Removing old sample 048fe8f31989bab6e8914ed019ad3406001c6a4b3dcb5e37ab688fb01e663803.schem
# Removing old sample 0490cbcdd8a31b4b69804ce667d58a446e5c3bb59ebb29055383092f68eba5ab.schem
# Removing old sample 04944cf651379c232426106057c169777f9bc512a1ae0b127b8c26e880c522e8.schem
# Removing old sample 0494d3b51753f9ddf99753bce333b5722d3f419da98de71397fd3f02880ba8ad.schem
# Removing old sample 0498766251ef39482cd882674a7512deff7a47afe8abfe9056a780c3e9859dd9.schem
# Removing old sample 0499e8bc650f5b93837fb121c65c489949cfe10f438796ff64229a5f9c3e7463.schem
# Removing old sample 049bbe1fb999d1f96d405b8c8743c303952efce5de9a1175ee33a4baffb6c836.schem
# Removing old sample 049be2bffb3cd5634a643e4a325bbb037281e0777c3daf986b2b4c2157c989c8.schem
# Removing old sample 049dcd769d1a8a4e3806924e488972160a86aa420b83be9c6d55030c313a93f4.schem
# Removing old sample 04a079c06d4bc6aedd797f83598b316bdeddfe8c43238b9449c9c0a3c587c621.schem
# Removing old sample 04a30781640d03a8f37cac71cb8c115923e55355478a9a0cd01f3e91c38897c2.schem
# Removing old sample 04a35b42654b0685ceb81062fc6c277d4a35a8fae7cb72dec0e769e30c7ced68.schem
# Removing old sample 04a7ba3c78b1ad47cfcfd556f389910f0816e5224694b0dce70d59142825772c.schem
# Removing old sample 04ac3c337976ef69a6a36fa8368ead4db68feeda0f8a304bada9431a39a9a61f.schem
# Removing old sample 04b0cb4bb7b9c23de0fb1debaa93dc4d9b5e8d7806b54fc3842f9b97dbf88f83.schem
# Removing old sample 04b29a7b6be5cb98ecf32d72cc09b9b9300245ad444e35a340969caa162bf55d.schem
# Removing old sample 04bb142db3bab728dcd5be2814469570e9f43f1298f6acd7dc5c63eb4cd7b5ab.schem
# Removing old sample 04bf324a595b2caa206fcf98b830db408a3eb0aca37da174e3db9ac6cf0feae0.schem
# Removing old sample 04c6fa9435dc9066290d9058070efcfb3f18b62e343e046001bb9537ef052d71.schem
# Removing old sample 04c8b15f1a3c137fe3fc6ca0827a27863ac9420fbb8f77ecb8ca2f7d805e5ad9.schem
# Removing old sample 04d2be4a0ae6607b8edf55e346af0b6ec23a85867c3d0fc5701e63b90c52ad09.schem
# Removing old sample 04d66f18ad76f997198b8fc3f176aeed41fc98accbf451fd066e8e9ad3ec60ab.schem
# Removing old sample 04d8d81058dcc6aefa125674d5f2d06d76b951937754ccbfd963e3c7fddfc6b4.schem
# Removing old sample 04de13d63254a39641bffa3db3601ade025caf26f9f5f32a17698aeb831d14ea.schem
# Removing old sample 04e24e686c84bff3c9d6385095e1191b41b83b038d2febf06455faa488b48698.schem
# Removing old sample 04e7aa487c620054a956efc319db2d5319e13daaa83a688d97856b256affe6bd.schem
# Removing old sample 04eccf398a64ab19494146db9dc51ec8c4218e6c0a5b6d807a7e384caff195c6.schem
# Removing old sample 04f17703e7ed2f5a0270e4767f3dbd9e49c285a0e4609b355bdaa7f1a71d643b.schem
# Removing old sample 04f5de2af31e43ab9f4d3f59d79852c6f91c52f136e2e193647876c6e2d5248d.schem
# Removing old sample 04fbc72c82a04888fd28210072849d8882b89b6466106b817ba2f8b7284d59fd.schem
# Removing old sample 04fbfebd94c0bf0a33dd5c3ebd25cb7450155801afd54e07ac25c369a0883f7f.schem
# Removing old sample 04fd4d7a471e02e49af4e88dc2440d3f2c9213c7fd53d95933f61ae03e0709b0.schem
# Removing old sample 050276ac41160983a9c3879d592e6bdcb1229b2496ee9511df886f0f0a64a17c.schem
# Removing old sample 0502b62053e9d2b3aa44b9c2f14c56256241cf50a2f8616da1bf1d2de1078003.schem
# Removing old sample 0504a95bf60c5f07ba5fdf7496aadd8c40c0aed2af01065c33eb0087b83d1327.schem
# Removing old sample 050a7a5e471d327fd8dfb53e2512e63b5413f94e9ce574056d42bbee3e488429.schem
# Removing old sample 050e8340b970a5571ac193104fe8c3698b57dbb73e26c5faca112a48d46db281.schem
# Removing old sample 0514e9068ada20c8c979ab85a9c29268a98be1b098226146cb083db15673e021.schem
# Removing old sample 051722c085d4b808af646035c60cd8949ed9f7c50b23e66f73550f1079fa1ebf.schem
# Removing old sample 0517c93202c8eb994284421f8b29329a169b807ed93b7c7f1a9fdbd5aba047c0.schem
# Removing old sample 051d4f0c9b6e617101c605f8c1367662a3d6a5a1a630f5a2627b9ccde6a597fa.schem
# Removing old sample 051eee7dbbf197101e0f11aab72d6645649fd0a1f7c4fefb7b370acf6f011bf0.schem
# Removing old sample 0523ce70389aff39900f2960366fa9c30d7a876904053e5ee9b8d5b702163ee3.schem
# Removing old sample 05243cd43f75322994dd039ea044dc382ba830309731d5a85498767921eb9940.schem
# Removing old sample 0524a38e86ccc0830b8c6cc333447147ce06b578cfb1775b032d2955eb98df63.schem
# Removing old sample 052647804042ebbe8280a7c459a558acbfc14cf87ea40e4b987ecb3250d96f9a.schem
# Removing old sample 0527fe0de59ca37ed662ad9156b2575f953b977672bdf7c250e95b9d208b42b0.schem
# Removing old sample 052b0c3123b05ee7a350aa7d638bfaf1883720ffdf75e65e0a4a4fb4d4067a8c.schem
# Removing old sample 052d81c8ed9d4cba2378bfd08f37aadb2c71a4fedcbf95f6e45f7df0993104e4.schem
# Removing old sample 052d8d68f0b435b9df8fc69ea1d2c422e090119a06ca8669e470258a0d0ee0e0.schem
# Removing old sample 052d9679f23f9b36eb61a1ebdf3148ca2e792257faf911b90a693b7ee55d6115.schem
# Removing old sample 052f149500f09d2a92fa2360e46014edfa03bbe5938f6071da80b1e1212b0e17.schem
# Removing old sample 05311f6a3aaff6498a8a609b432f747875a2d2cbc01dcada3bfb52e93b6c4a8e.schem
# Removing old sample 05402fa262ef0550f30372d82c7301f376148a36183295e7c4bd798391609cea.schem
# Removing old sample 0541d1d9e6c55b2d599f18750806be8349eaa436c4c42144cf04ae2546a23b6a.schem
# Removing old sample 05489de764fbac2c058aeb3afe90de53799419941ec99b1d55bc92d6d0e524a5.schem
# Removing old sample 0548ba1381818386076a0d80a2b2944734061df875e6b53c448ab18b6529b463.schem
# Removing old sample 054e15c7bc88d5773201c24b5ab6de951721f6111fbe534e0d875cd6776f4320.schem
# Removing old sample 054e2580918097aa9f330e8dc6f2d77e032d4c6485916aa27bc7db84ede84bfc.schem
# Removing old sample 054e570d4e59e77e6c9d4d978307bdd86b1c57f9d75c69a0890658005bbdab96.schem
# Removing old sample 054ec0b866434be13d73b7e8d8932425740ce0c84dbc2d19afa9b693b8a4ad51.schem
# Removing old sample 054f56cacd6116c3429de44087d41a0b64d40ba6fdd4cffe91a60bf461031db8.schem
# Removing old sample 054fcc3745e7afc256f085c7c06c3418c187b336115fc1d78f4e8290bcfd3594.schem
# Removing old sample 0550ef7e86db3440b3e04709a06ffb649c75a9af870ce4f024294a7b9ad10e4f.schem
# Removing old sample 05518caa2d1334489d7d0f985809959f682e3aebc8f22aef939a51e46451d7ce.schem
# Removing old sample 055bc7811e2cb8fbb55247fa52954c5d5588da3066dd368d4e71206f5cd6198b.schem
# Removing old sample 055ddccbe2078ddff7a5d39fd7116fbc6f7b983c3b02ca51f7aca5b0025ec22c.schem
# Removing old sample 055f750f8c6144be5b28a7841bef23e205f16d6236d17b92eb25b2ca0d9ff3ce.schem
# Removing old sample 0564e634e1c8632fa4afad87a26e80de0362601ed3f838201e607469e83f28bd.schem
# Removing old sample 05690e2a20395a3598524dbb1b8b48a5c20243fa9637c6bb04bc73e485962f2a.schem
# Removing old sample 056ab9d999fdf8324c27f69d8fc3128c77d6084cb994e36fdcb013ed5497386f.schem
# Removing old sample 056c637560c1755a43bfe6f3298946a4dad1f51d4e160077513024c7c026ec19.schem
# Removing old sample 056e396b8155572a84f8bac2e96a70744f2bd293fb8adee379c73bfb19593e4e.schem
# Removing old sample 05711f1e27dad689faa3db87d1ef9fa2ebc1b6018d970b9fd221528fe0c2b5a9.schem
# Removing old sample 0578907238264172c3d04cab3da292352113f99737c31f99288e45954ff82d93.schem
# Removing old sample 057f5313c63b7f87ddae215ba08f7ff96daeccd461d6847bf862c4b8172d59b5.schem
# Removing old sample 0580c78c16d2fdad14581ba1d565763897c8177b183c30214fbcb75655ad49ee.schem
# Removing old sample 0589aed831d49811a35614b9a2458e391083964b8ab64ee8f2bd3f73ee9cb10c.schem
# Removing old sample 058c510592756eee863204061748edbee8a1473a2c3245e173f6c92f309b814c.schem
# Removing old sample 058ce6e739cb8f31a520fcb7cf0dbaba0f146c8c6ca9797dfeef20423d16837e.schem
# Removing old sample 058e5c5c790647c6a861dcb4d8675d2b42e57804b4aaf685d96a0c2ee85930fb.schem
# Removing old sample 05925f4a685ccbc85766a76a5201793a1f9beaaecc8eefe994207d1cd6fe5011.schem
# Removing old sample 0594323368d77476933c93e34ed53297e2c630ebbe37b5da0ffb5129e9bf6503.schem
# Removing old sample 059598d02a532a9e1c0b426bb69a5ef269ab25aef7f2f0cba42d71a937f48d54.schem
# Removing old sample 05971c6cb7d7409d955096c1d3d2985b8b57f4ac9bac3461aa35bd283545f48c.schem
# Removing old sample 05972ea47edeef3884b64b7fb9b69665ccc0c84bdb3ac2bc8d6c116e1f6c4c20.schem
# Removing old sample 059884d9ce024b63cb346569061d844446b78919f4bb1f5cff695fe02f5b78ce.schem
# Removing old sample 0599754e7fcb55997304d192fe3cbf471bbc251a6315b6cfdaf938bb822f76a4.schem
# Removing old sample 05998f19466531fc486ad292d4bee080493b60bea264448a6d15bf68f51587db.schem
# Removing old sample 05a38b343364a8869936e343d0fe87d73ffe2bd7741110a536426f7570048da9.schem
# Removing old sample 05a6aea5154b0c08864386e22323e573c67af8838fed9e8e035b75bf0eacd8e8.schem
# Removing old sample 05a7cff126546e46fb71dc61afa997827c65fd24ff66e6cdaa33c5be0706ff7f.schem
# Removing old sample 05b4ac15196a7bb19a3e9a213aa7db08f984b6f83374b95ae45ad4693b23d615.schem
# Removing old sample 05b502e42d08f0f921746363a2c062425fce73cf642cd9146cc9b7a4697f68b4.schem
# Removing old sample 05b9cf2269b132af5ae894504354def7f88e99fc45aff913a88b2ba1555f2186.schem
# Removing old sample 05bdf9204677a84672405483e02d60dcada1a182bf88cfa5e1db01f8128aa45f.schem
# Removing old sample 05bee6acaf4a1bf81bddece50df8c479110a3a77f8d04da8430f4174b42ef60b.schem
# Removing old sample 05c0e4d090b90216ceddaafc95be50850bf864bf7ef23e069c68ff7d90829dc8.schem
# Removing old sample 05c3243e85e25cd2a50b0b24779d9ad331ab3d831a7ba522fbde794fb8a6131e.schem
# Removing old sample 05cd185ccfff5caeae94ddf6401fe7f5e7a009c33973bf0e73e01ef1b7288e37.schem
# Removing old sample 05d563c4b24f7ac6a07b58681064aebdb6e6662421fba20fd8ff00b3d1cb3053.schem
# Removing old sample 05d7a4478196e43b96d722a6a28224450185f1d9ca48950adece68e072c73371.schem
# Removing old sample 05d9ee1c5baf15b0991817280596be449f0308dc92833f4bd8950749fc3b843e.schem
# Removing old sample 05db7f7ba3c218cb38ce1a01891e149f9fc75a209a19b2ab82fb38c42b7a0d82.schem
# Removing old sample 05df548015d5448805232356bb6c7845cdfa67e5c244e2dc2a047c56d9ae46f6.schem
# Removing old sample 05df88f4ddf4a5b6ee0844bfe460e10511a4334c156a32289abe5bf309340da2.schem
# Removing old sample 05e068de13728634f6f5124e6ec124121fb2fa77785d94178632a0ac7e0b3bb1.schem
# Removing old sample 05e5d77d9b96e84f0246b75ca938cb085d4ccddd82e036a13e2ed5d503f826d6.schem
# Removing old sample 05e6dc3101099a125f66305b736a929854f5070d287b992ed06473b2c56af376.schem
# Removing old sample 05ee8f8d023498deb51f5a305a45be163d8585950ff02f4a0c540e8dd11990c4.schem
# Removing old sample 05efe36b00bbe5f6520b4c870aa1ac21d6b741c25234ad61ebbbc288df590375.schem
# Removing old sample 05f1b0ec50f72654519ca2ff46fb9850f717302503f7d715059fc276205a1c3e.schem
# Removing old sample 05f1eaf588ed8d68ed458a147fd59aa8b057f8a1a13497d09230e4479d8b9b80.schem
# Removing old sample 05f27ead1199803d9898acbeca64e6871b6be1cb86c720cbfbb621524b6ca35b.schem
# Removing old sample 05f394daa143c5af08c9769d3734c12bba441aac311bc926515c307bd3b0cc95.schem
# Removing old sample 05f621053411add72a9e3a427f9ac3e9da7e1b22fa1b728c1325ee3da23f48e9.schem
# Removing old sample 05f9dc1e54e90d0c946236aa96be9aeee381cb5475a7e5d2b599258d9e1bcbaa.schem
# Removing old sample 05fc93514b668f832c5b10c0fc4cc35602de883c772ba4701656eb91f3328020.schem
# Removing old sample 05fde1da7fe61bad1e45005e3dd5360388a3da8801b2fca7b9e99e6df14baefd.schem
# Removing old sample 05fe81f3dfa5fe2c5db7b59a085246cc377edb52897d0ebbd7b66d9e87fd622c.schem
# Removing old sample 0602fb8b06f53dd69387ff01ac1915fee05d710a1335a247399440561f63d8a6.schem
# Removing old sample 0603854cbaa801b090613c209888c0ce4bd78461f330ffc5e087fcdb5922826b.schem
# Removing old sample 06086a12d486172ad76976edef6831ce3b26cf7a5f5e14ec844f83751a63fc6b.schem
# Removing old sample 06097f752cf2870af970907c35737fd60b3ce135e5682abc2588756fbce51bd5.schem
# Removing old sample 0609a26720cfc6713787ea3886e6e29d0b1d545a1ea99bb8d3b1923ab9b43d33.schem
# ...
# Removing old sample fdbec3a7e907344de022bd5a3bdbcf0728e99708880626b202dbf9a329081892.schem
# Removing old sample fdc1f174b266d8786c6e746278dbe52eb7fcbe257f7a06157019fd5fc12ce7d6.schem
# Removing old sample fdc488268ebf37f4cd1b6cd0ccd54de8949a4f0665a7518975293a2ed28140f6.schem
# Removing old sample fdc6bda107efa88b3fbdad6bac6cfcacb8da171cd89335ffcc8b9b6c423a5d28.schem
# Removing old sample fdc8279e2bdb11d00e42544e664f466fd7c97d61db8e5fccc6db2ff0c6d2a471.schem
# Removing old sample fdd6bd59f280d5f3fa164fe2c9165f89477c406ccd82ebcd04ebc87cc7aac435.schem
# Removing old sample fddb7ac60818c9b934fcf612b8f4baa4fcefd5f56605ad469bc4166463c76ed7.schem
# Removing old sample fddbf3fbd90339086c74c0492c60ea34654318d02b5a2f2ef8118a0fd6f9ac6c.schem
# Removing old sample fddd381ea8da3543dbcdfe6ae80d9d7e5bbe91559d99cf19df3b65c23bae637c.schem
# Removing old sample fdddeec5be0a55c30ef01f486f80345f5236ad27bb031e1eff9660a80cd5ef6f.schem
# Removing old sample fddf92698ee552a180df2049fb2c45977cf6e1dac348bc9e56c8c683f1d3347b.schem
# Removing old sample fde7f5e82caa1e6df79f4f5c70839c4f05558e67f54fadb984e63e41345e6ff0.schem
# Removing old sample fdedcc06494065bcec306faf94e0dede2c38bd9aaa7020520dd9cdf203fb48fa.schem
# Removing old sample fdf50a04c781c2c4b2b81cccfae6345a9d1487fc0f76a4e5ac10af03a2446c9d.schem
# Removing old sample fdf73705d57934547e3894f849e19c6b05623f9fc47d9917e20cb31eac2d4c92.schem
# Removing old sample fdf9b392246a0b3adab339155eb33b3db912eb7157fc48bb653c431bad8c0a97.schem
# Removing old sample fdf9f7987b9d5a8f77f7d2546ac4e5186c842ba23795ea15566d5c08f84cf75f.schem
# Removing old sample fdfba67afc8de1511656cf52ebb33801e1f7c01ef941ad87bdc8bf8e82f92cbf.schem
# Removing old sample fe02f1cda85409721b02a06d16fe58f2501710e4e17bf5c38ab5eb4e0e8bec98.schem
# Removing old sample fe03f973e91dd4c19c542e193c858266c5ece5f922fda4fc289ed35bb54c50f0.schem
# Removing old sample fe06e088b889633083ba9550b891c19515b31c9a0958cbce41a7aab472f032cc.schem
# Removing old sample fe0cd58286f8abf961220f27658762834e8382cd90014e8daa11fb5a89a6f5b0.schem
# Removing old sample fe0e230f61881bc893dec184b4891371feaaecddd5b868d00f6d19a94894037f.schem
# Removing old sample fe1594c468479ab834369ff65abf4f66acdf9e8d2d2f283644e11d6d83318bcb.schem
# Removing old sample fe1ce78aabe8ce47e3ac3aacfecc1de250247ac3d2aff78f9fbec9230aab7cb8.schem
# Removing old sample fe1e18fad6cae5da9e4b36ad19914df848774dc80141764b76926a30437f9af8.schem
# Removing old sample fe1f40bcaec6185fe62935a43e27abb538b0543f37b90bd3f1b9baa9430052e8.schem
# Removing old sample fe2395cba1707296ceb7427b00985c90529ca3768c9aab50cee37e1607f8de68.schem
# Removing old sample fe2a8de7a399917559bae9be286787a0024599b92b800e5e624601e0ff8a0c77.schem
# Removing old sample fe313e665e2b1d1611e609cf755572dbf93b4f380b79ad909f82e45ec4359ceb.schem
# Removing old sample fe3472b10c44ef090d03c4203c53bb94ebef5317974fef225889519964e18da5.schem
# Removing old sample fe3d44bb1b21f37144f671f7c091bbc72626de87ef369b526aa95b4a3f9f4b61.schem
# Removing old sample fe4a452a8b55d23549eb8550d24d0ca3eb59a293b334640a6ffc466ec0bd0429.schem
# Removing old sample fe4a527204f8f1e87b79b99b67fb7d1e2790034c1b59a4687770fa5d801da324.schem
# Removing old sample fe4b594bb816d506f3ccb6bdf592b90a32ff29aa6c85a0db5583e671fa04afe8.schem
# Removing old sample fe4ec5ba110aedef531303f857b6adaa6a82a5c57a72065cbd87cadeb72dc131.schem
# Removing old sample fe4ed63034b88bdd8df5d466b2b6a83f8ebe38f16fa9b40e292621a6a8236ebd.schem
# Removing old sample fe543493508d754d0fff9f65fb6cb284230d668a7229a4bc92443a0fba63e401.schem
# Removing old sample fe544f651f982e91b0bd0a9153ff2263d4286ccd6b0e7525a75df6425048c033.schem
# Removing old sample fe608900d52860ecd4ed8a65857df291640169b5dacc1f28939e80dc280f4373.schem
# Removing old sample fe674e343004fbeca4825ea46fd101313affd715557d3529af81536604301dae.schem
# Removing old sample fe739b8ccf307c2c79a37d16e1f4646fdb07aa64a96ad2083bef3974cca8a61f.schem
# Removing old sample fe74c9fdcb8ba17992ef0348cf9b9c04f4423a914b3a0153e04eae160e40eca5.schem
# Removing old sample fe7649028d736311437e64fdf39a261c37ea33be18921fe5a1d7eb8a888ce63c.schem
# Removing old sample fe76715edb20bcb621c495b03ef7b23e9aa09eab79fe17b33bc60766f51cfd93.schem
# Removing old sample fe7a965394a6ce0cb481a47d54b22212bb1b33c7b90033e7eba5f814eaef5c6a.schem
# Removing old sample fe7b2fd34eb46642ea5c4b7831e056a116689a2474ad3e45dc4bce2838971c72.schem
# Removing old sample fe7ebb6a7c7d8f0284d2a01bffeea19f1432f531f58b82863ab8d19d9bbf9a1c.schem
# Removing old sample fe8083ab18e9ac376fcb0dfdcf002c1dd01de044bbd142cab9b1688c7ea932d4.schem
# Removing old sample fe80eb46d5788c6fe47e3b53f136886bf25b4a5483ea916dd0521003d2266900.schem
# Removing old sample fe85c4b8975c77d94c66e3ae718ea19cd3e7b9fd18c34b3a6e410d93c31eae76.schem
# Removing old sample fe8c4c5163435fe9b2320896f5555841dd4c928d7a9ba492d169434b82662f15.schem
# Removing old sample fe8d311d935ac6916e1e34d3a294a616d5ac6214b1a7c7731359863d35f43bad.schem
# Removing old sample fe90835e110341ce7ac675200db999f2ce3510e5c90188237bb089d734056fc4.schem
# Removing old sample fe9a135983a01eeb72d2089abe76f670672e06078b94aaff974a1d6f005b0ac7.schem
# Removing old sample fe9da7a2fa28362a13e280f842cf58d6c511c61c044da727c05eb90a1b2bb9c0.schem
# Removing old sample fea6eaea983565fb2c8a9adf11ef3ac2e01b3b0f38250eb2f999f85943b7fd3e.schem
# Removing old sample fea7f981da1d994426ab91e5d988194e1212f6a9d01c61acdc0f7c461f56f953.schem
# Removing old sample feabedb4ec4d32fc91f0eca95d953a83e333aee569364bca116fb03806913a7e.schem
# Removing old sample fead6f12866fc8dce46ee2cfeb13274034eadb1cde69979f540442eebb336b5a.schem
# Removing old sample feaf228e49a2e4d9ebeedc80e62233f21174c56f263db15f0a9c41defb0a04c0.schem
# Removing old sample feb1ca303862668c687b785e9324ef4e7da9f58825357ef01ccd86db3100c5a4.schem
# Removing old sample feb29940ce272b4784593eada4116e265da93b4dd57b655ff44842247a4c3eca.schem
# Removing old sample feb38c8688fefa26f1dccbc43892311136b5df5d3f8c6e85db9c605a13f4f2eb.schem
# Removing old sample feb5554e5ffe13b6903638b0df2f3d81cf9250525f6fae1f2e918b6039b56259.schem
# Removing old sample feb7042240cc513f17a20a74f8c7a753b86d75e9a2ae54255cf9d7ce49079610.schem
# Removing old sample feb8b00948e0cd69195e31c31b7feb31265593762909d7c350d5e0c86339074f.schem
# Removing old sample feba4b241f98d2531f572a5ae72e9295f9c33a06dc510c9452ef0137bef7b212.schem
# Removing old sample febaee863e144ae854e70950677d217cc14fb6141fcb473e54fd9428fca17951.schem
# Removing old sample fec3d2264d3d0d1dca28b4a0fcfb8d030127866c4e135473890d52cb6dea6004.schem
# Removing old sample feca2e94b99c0b1971deb18aeb2b9745f7df63457b02a073b2e3faded9da720d.schem
# Removing old sample feca6d3f9c81c3b1e56434127fd8546e818e9cbf8c9f26d0cf7deca3db239eea.schem
# Removing old sample fecb9658d843079ffdce0c3fe52ff471bdab8637bf33766a51917d4a533ed783.schem
# Removing old sample fecd2f9ee22261bb57334fef2dfe1ce56df9c80bba25d9d75b0690b723beaf9a.schem
# Removing old sample fece7e295ddc98e82aac41c809580011e6f0a0e761c2d94acd065a97b07405c5.schem
# Removing old sample fed25cc105b2816384afbe8e90e809fdccdd87a489e533bcce3a9dcf0afc98c6.schem
# Removing old sample fed8dcf6bae996fcc2b55db859a62de4091642ecea12eff94b1ab0cee046dec6.schem
# Removing old sample fedbbbd635cfa3dadf3b442269a55648d129ce38d0ec5c5cd4ce6e9e2df1d334.schem
# Removing old sample fedd50cfd66f3cd2f37bb86eebe0d050712d7951ff364b327316b97dd5f9ae74.schem
# Removing old sample fedd52a92bc828a392ab291ff83da46f5b372acceb2c51d7b9cd2746ce57ebfc.schem
# Removing old sample fede486db80ab7da90d22e02f12c794872066ec1fcfd9f14c7159500e6175b30.schem
# Removing old sample fee01e2e23450bf28124ad33985966fd0a24a785e12f10d8e3dfce40affdd1bc.schem
# Removing old sample fee21b94564214a3efaae19b081a25eabd1194c729bcff1f255cf3844f58763c.schem
# Removing old sample fee44764f67e7faf148058fe810792f7009f3e821f8cb2b58b1c93feacea029d.schem
# Removing old sample fee58c107f28343db28f3f7d96f4a9fa40745ab9b97fe74d6466b9ba17a33d89.schem
# Removing old sample feec504feae91d79f8a7a12fba4edfc94675464242f4bc415c8841f3a6ba603d.schem
# Removing old sample fef4b86a8ad218cd44fc47b48a9c67ba93b64f1b8fc6e7d02d2d7c78adec5fda.schem
# Removing old sample fef7c74ab4e356fca3d6ae6747c3225a32bccecf0094bae6f557a6620027e19e.schem
# Removing old sample fef860e4b499718efd87bcee47eca318cde27200113f4d1ec6bade3eef51a952.schem
# Removing old sample fef8c9b7cdb35a1e9d75d6aa2894db30865a9519c6613ee9a48449c913bb7b44.schem
# Removing old sample fefa1c240ae9b3cc153b10088158d20c9df47dca987cd43912a6690311094953.schem
# Removing old sample fefacb1fcd724b4bc238d29efe757edb0c62df73f404e6d999b1ce9d3a0d89a6.schem
# Removing old sample fefd32a9b92897a368bdee9c8965fdddfc73bc344e861de324e02b2bf5d34ffa.schem
# Removing old sample fefd61030d25d63f820aaa7cea78ce5d836ef6c32efa65b3baebe2b3460ef25e.schem
# Removing old sample ff0765dad600acb9d8ea68c6c144036c106d00749a9ba048e6982567056c0cb7.schem
# Removing old sample ff08cacbc035dcceae148af7de5e6b02075bc7c48f76841fa4f271bc379110fb.schem
# Removing old sample ff0c353202a1db7948349fc8adb277ac54b907afdf9fe10167ea3baa22785fe6.schem
# Removing old sample ff0e9c86a705da3a446ffbb790d5b9bb5bf53b35989977e5cdf6ffef22be87e1.schem
# Removing old sample ff11d93181bffa2b54ec373e942f4906b1685ccf71ee48e3651412270daa271a.schem
# Removing old sample ff18e93a765c671682134979ed2fa0f63ff8ec05865380a42ae556e6ec935353.schem
# Removing old sample ff193a693ba2e110e45ec550da5485290bef6824ccf46cb7c5fafe2847d72a89.schem
# Removing old sample ff1df4ebc11e854d68945845e4259db2bb03537a0c50644d0a718339d5b478b2.schem
# Removing old sample ff203ab88781f2017729ce055ce8ec91a90fbe5042963d98355be7ac5be23f94.schem
# Removing old sample ff24731e587c8bcd4cfaf2d125d627e1e19ba00811b92904cf6d6f1120182a09.schem
# Removing old sample ff25c359f3e0e9b26cb8ee8e68425d0c97054a5a07e38b1626ab9a4e5ada99dd.schem
# Removing old sample ff273d8160b912653fedaab6ea3a50ec023269415599f2e27d4b80b0a3667cbb.schem
# Removing old sample ff297410a060931364a06dd0ff011650f79d6c2528cf06a796f2a3ce58a23cd4.schem
# Removing old sample ff29ba92389902af51717f966dbb7be2786454961f5ec670ce9d685dd86d379e.schem
# Removing old sample ff2c8a536b4339dad5bf32d13e719c18f6a10addbbea0d7440d4c02ded6a666b.schem
# Removing old sample ff30c6b2520d46073b1d5190725e5558f7357e2d91ae22c392f62a5f2105d882.schem
# Removing old sample ff32423ad63aff1a03bef7ab8807b6c2784548e244ffb84e77054f7232527920.schem
# Removing old sample ff32579f2cf4cc4ec1c891dcb1d33cd8e11388c32c407c6a18597070a636502e.schem
# Removing old sample ff33e5c57efd95e106f933c76907e6b5ff816964c1edc8cf5cd6998da0a55752.schem
# Removing old sample ff358302e36f20cbb2cf0e7376dbe83b22bce3ab7bc2dbf07d884964274cda8a.schem
# Removing old sample ff37d83a2584f890cba5a2beafc1a5ad8b9949258529d63388a339aeb8c63ef0.schem
# Removing old sample ff37de042893fa5e96e54c270ba7ba0d8308993e96250d64355b9b6b271a59cd.schem
# Removing old sample ff384efd41addf77ee2aacceb9a291a0be59822ef93498ddb6ae54c67a7ec403.schem
# Removing old sample ff390c20111916dad479f4cbc14261b879d01f8ea505b6875342039737f112d3.schem
# Removing old sample ff3a0a6f71ec986ae3feb9ad8a525c6efef7b822a26808e49ac3315d3c3e782b.schem
# Removing old sample ff4021a5e21e715f22f0358f984ded17024721ebf8d1fad7ccd590dccaf2068c.schem
# Removing old sample ff423d1ea4ecdd9d616aaeb8f49896ef015fdc3e894affff3f75022d2e00e74f.schem
# Removing old sample ff43d0c93a066da9cb4b7a807750b2f77486192c6cc9843b01b111ca03697c1e.schem
# Removing old sample ff459074697d3497787f9a7eb9ae5b822919152ea100b2a6478b1b9e16b6803d.schem
# Removing old sample ff46a7e523c8d115604b550a02c45d176acd7d924c684f08dabc7f9a7e6949cb.schem
# Removing old sample ff4af24a25f23b6f968e1dc28dbdf4aac68a730645367f08488cf0956b7a775d.schem
# Removing old sample ff4b5ecc3f51dca105b2764e21b837655d9bb53fe61cfc53942703735b410159.schem
# Removing old sample ff4cec88e47bf4706998471f21ebd17ca8b41d2fe9b3fa67e83a07f3c18559fa.schem
# Removing old sample ff4d8cfa2df90c947d481a728be8175a41300b6b7143fdd41dfc03659ce205f4.schem
# Removing old sample ff501fd25ff325c23d272a4517a7d5126bfc8fb217ee5ffd6edc1ba84c5a2706.schem
# Removing old sample ff5930548c0723e8defb8889a0719e9bee7f74c9388e17c8a17a86ccb19acdbf.schem
# Removing old sample ff5ea32b7f46b95ec91df15efb19729d72343044793987553c35253dc6423315.schem
# Removing old sample ff61f3c262ba7e8174bad921ddcb6827d59d93541d851d32ffdf79f749c19ece.schem
# Removing old sample ff693982a560f665e1e0e7ee4107563425016c04736956622ffbfb629a704087.schem
# Removing old sample ff717f1a5bfb2a65474b59e4f9189bceb9eeebd01a57cde29f50932c5f75216e.schem
# Removing old sample ff7432a9c658d765087be7d13087323331f4d7ba701a40497e2af5cff692e651.schem
# Removing old sample ff7be5e7cea22db73992faa364e64734859424896b7472afacfe3f4fe9c0f58b.schem
# Removing old sample ff82366fbda25997dbc7e565d45e4a97d8114b6122006e9bafffc7801583865a.schem
# Removing old sample ff88a6b2bd9d33dd03bc19f1e7cb064a8a187a9db635f0f91efe7b3d59684950.schem
# Removing old sample ff89b77394083ad5a8a1186dda20336b7467a6338541b726337de9823029e951.schem
# Removing old sample ff8d918cf5ae5edc9ec0049c264863cd0c47934489a82498ef2252e12fc7530d.schem
# Removing old sample ff8ec39360ce89ba119f5ac08afbb30d26532908221e6b64ce8f941ec123cf0c.schem
# Removing old sample ff8f3c6882c648d95b207edd7b332f7fb420e2506700677028c366f2f321578b.schem
# Removing old sample ff9291a9ca50684b4d6fb405d766b5a4678b43c328a7c27c3c182a0811deb9ab.schem
# Removing old sample ff994ca7bba25404f8e209716578487eca3c9ffe6525295bc1c1f63ee478be56.schem
# Removing old sample ff9bc2eb6b197fe8dd89ce5e0dff4518b293c60d44b888865c2507b9757fca3c.schem
# Removing old sample ffa54aef60ac9451d8e865b1bbe46b45681e73cc28fd2ee92da2dd6a4230fa10.schem
# Removing old sample ffa7710ea3f61f6f7d3d016f8c95160e9b7ab96e6efe51ad6d1abff8d75f2daf.schem
# Removing old sample ffac218c360aad9dda473f6b71122c159feb488df2468aebd4379e0e4257815f.schem
# Removing old sample ffae56e471e19984c34724e0f280df7e640ee87aad7c54ca9cba4be36acb2c7b.schem
# Removing old sample ffafc57309f6777bec08cff29eabc3cfa3a3306ffa54a0c24e3cbcdc9b9a1e82.schem
# Removing old sample ffb00ee08d6af6c5df556310a9ffe881844befe3eab02998ac3c6edfb070d1fd.schem
# Removing old sample ffb3816c15f402b150fdc48a849e616a49722fe58ad0e6b8b720328218821b2c.schem
# Removing old sample ffb8e3839cc2a4b4b9e16744fb301bfbe4a7bfc4e165060c4c740ffd4d5f85de.schem
# Removing old sample ffbc0d6780d1dfc3a542d807e190cdd5aa9d22057b40f16a9f2827a1ae3176b4.schem
# Removing old sample ffc07481099244b9013653db807e63c295689f0c2145569d520ddb458366d3ee.schem
# Removing old sample ffc3ae081c2838625cde9cbb97290420b48e6b7bbfee842fa1204459d3cb878b.schem
# Removing old sample ffc686906819d04342d2434a9253f5283c3115b17aa71e1aa127e7fc508f47e5.schem
# Removing old sample ffc856fbcd9bd520ec42c1b4dc3ebbf7ccd07c20e3ef17abfe3a46e8c1f68d47.schem
# Removing old sample ffca4bf9cc48135ea2aeba0ad877177ba24665f5a6da9719ea399b8e44660dcc.schem
# Removing old sample ffcc95f0c5e072c5ec5bccce4133b946c599202ad164c7f67f3592710a073f7f.schem
# Removing old sample ffd4d9a28724d947489d1c83bd98f0bb50a207e2b3eb2eee3b9b891144ad95cd.schem
# Removing old sample ffdbeb0b522baec2be5346962b10684e4fca362f28eb16df16ed0515d60fcc6d.schem
# Removing old sample ffdc235f706b5ac5c02dcfbf52910bbd0bd6563081e0efefe91d754c66aaa641.schem
# Removing old sample ffdfbb57f4d1eb1d0586e36f03ecc536587995a04f42a3ef59641d6c686db547.schem
# Removing old sample ffe01da50b5cfe66372582ed2f764d42a4c06cfb8ae6d6f55e8d6d1ae511aac7.schem
# Removing old sample ffe1755e323f9273b63f397357be0129a8e8cf67929ee28371e0537bedbab93f.schem
# Removing old sample ffeacd88940dd4742bd85a9239bd3fb6ecbe69e4d51f90689a1258432ff25340.schem
# Removing old sample fff5e817be071fa06f625c4ef7eca68f30cefcf499952ddcbe2c28ed0996f373.schem
# Removing old sample fff74c223cb7004498023bc1d5b021f91e278af2ecd06328cad7d5bc8af1cea6.schem
# Removing old sample fff8332e03440d94b11bb8e17e338368e6e58f1f119102f00cf5dc9821ab5ae0.schem
# Removing old sample fff83abb815aed0a8d13ba8f6bccb32945e2b2c9efd90b16e79386b0208d736c.schem
# Removing old sample fffa1be05caf651763597e90660de28e8890d19c799d625c0d4c33ce980d3592.schem
# Generating samples for mixed_cubes: 100%|██████████| 13213/13213 [00:38<00:00, 346.51it/s]
# Generating samples for simple_spheres: 100%|██████████| 2856/2856 [00:08<00:00, 351.20it/s]
# Generating samples for mixed_spheres: 100%|██████████| 11532/11532 [00:32<00:00, 356.22it/s]

# %%
total_samples = 8250
print(f'Old total samples: {total_samples}')
total_per_block = total_samples // num_blocks
print(f'Old total per block: {total_per_block}')

print()
limit = 16
print(min(1**3, limit))
print(min(2**3, limit))
print(min(3**3, limit))
print(min(4**3, limit))
print(min(5**3, limit))
print(min(6**3, limit))
print(min(7**3, limit))
print(min(8**3, limit))
total = min(1**3, limit) + min(2**3, limit) + min(3**3, limit) + min(4**3, limit) + min(5**3, limit) + min(6**3, limit) + min(7**3, limit) + min(8**3, limit)
print(f'Total: {total}')
print(f'Total total: {total * len(constants.SIMPLE_BLOCK_TYPES)}')
print(f'Reduction: {((total_per_block - total) / total_per_block) * 100:.2f}%')

print()
print('Ratios:')
print(f'{(min(1**3, limit) / total) * 100:.2f}%')
print(f'{(min(2**3, limit) / total) * 100:.2f}%')
print(f'{(min(3**3, limit) / total) * 100:.2f}%')
print(f'{(min(4**3, limit) / total) * 100:.2f}%')
print(f'{(min(5**3, limit) / total) * 100:.2f}%')
print(f'{(min(6**3, limit) / total) * 100:.2f}%')
print(f'{(min(7**3, limit) / total) * 100:.2f}%')
print(f'{(min(8**3, limit) / total) * 100:.2f}%')

print()
increase = len(constants.SIMPLE_BLOCK_TYPES) // num_blocks
print(f'Increase: {increase}')
total_new = increase * total_samples
print(f'New total samples: {total_new}')
scaling_reduction = 0.1
total_reduced = int(total_new * scaling_reduction)
print(f'Reduced total samples: {total_reduced}')

print()
print(f'New total per block: {total_reduced // len(constants.SIMPLE_BLOCK_TYPES)}')
# Out:
# Old total samples: 8250
# Old total per block: 825
#
# 1
# 8
# 16
# 16
# 16
# 16
# 16
# 16
# Total: 105
# Total total: 24990
# Reduction: 87.27%
#
# Ratios:
# 0.95%
# 7.62%
# 15.24%
# 15.24%
# 15.24%
# 15.24%
# 15.24%
# 15.24%
#
# Increase: 23
# New total samples: 189750
# Reduced total samples: 18975
#
# New total per block: 79

# %%
import os
from schempy import Schematic
from pathlib import Path
import hashlib

descriptions = [
    'An oak tree.',
    'A tree.',
    'A standard oak tree.',
    'A simple oak tree.',
    'A classic oak tree.',
    'A typical oak tree.',
    'A beneric oak tree.',
    'A basic oak tree.',
    'A small oak tree.',
    'An unmodified oak tree.',
    'An unaltered oak tree.',
    'A naturally generated oak tree.',
]

input_directory = 'data/schematics/trees'
output_directory = 'data/schematics/trees_pos_4'
count = 0
for filename in os.listdir(input_directory):
    if filename.endswith('.schem') and count < 1000:
        schematic = Schematic.from_file(Path(os.path.join(input_directory, filename)))
        file_hash = hashlib.sha256(filename.encode()).hexdigest()
        schematic.name = descriptions[0]
        schematic.author = "mmmfrieddough"
        schematic.metadata = {'SchematicGenerator': {'Prompts': descriptions}}
        schematic.save_to_file(Path(os.path.join(output_directory, f'{file_hash}.schem')), 2)
        count += 1

# %%
import random
from amulet import load_level
from amulet.api.selection import SelectionBox, SelectionGroup
from amulet.api.level import World
import amulet

def generate_random_coordinates(world, section_size):
    bounds = world.bounds('minecraft:overworld')
    x_range = (bounds.min[0], bounds.max[0] - section_size)
    y_range = (bounds.min[1], bounds.max[1] - section_size)
    z_range = (bounds.min[2], bounds.max[2] - section_size)

    return (
        random.randint(*x_range),
        random.randint(*y_range),
        random.randint(*z_range)
    )


# def extract_cubic_section(world: World, start_coords, section_size):
#     x_start, y_start, z_start = start_coords
#     selection = SelectionBox((x_start, y_start, z_start), (x_start +
#                              section_size, y_start + section_size, z_start + section_size))

#     # Initialize a structure to hold the blocks
#     cubic_section = {}

#     for cx, cz in selection.chunk_locations():
#         chunk = world.get_chunk(cx, cz, 'minecraft:overworld')
#         for bx, by, bz in selection.:
#             if chunk.bounds.contains_block((bx, by, bz)):
#                 block = chunk.get_block(bx, by, bz)
#                 cubic_section[(bx, by, bz)] = block

#     return cubic_section


# Path to your Minecraft world
world_path = "New World (2)"

# Load the world
world = load_level(world_path)

selection = SelectionGroup(SelectionBox((0, 0, 0), (16, 16, 16)))
structure = world.extract_structure(selection, 'minecraft:overworld')
wrapper = amulet.load_format('test.schem')
wrapper.create_and_open('java', 3578, bounds=selection, overwrite=True)
wrapper._path = 'test.schem'
structure.save(wrapper)

# Remember to close the world when done
world.close()

# cubic_section now contains the block data with their 3D coordinates
# Out:
# INFO - Loading level New World (2)
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Prepare data

# %%
from data_preparer import load_schematics

schematics_dir = 'data/schematics'
hdf5_path = 'data/data.h5'
load_schematics(schematics_dir, hdf5_path, (0.7, 0.15, 0.15), dataset_names=['world-11-29-2022-2'])
# Out:
# Loading schematics from data/schematics into data/data.h5
# Processing dataset: world-11-29-2022-2
# Split data into 2484 training samples, 538 validation samples, and 549 test samples.
# Generating set: train: 100%|██████████| 2484/2484 [00:19<00:00, 128.35it/s]
# Generating set: validation: 100%|██████████| 538/538 [00:03<00:00, 154.97it/s]
# Generating set: test: 100%|██████████| 549/549 [00:03<00:00, 160.14it/s]
# Finished updating HDF5 file.

# %% [markdown]
# Check Data

# %%
import os

import h5py

from common.file_paths import BASE_DIR
import random

with h5py.File(os.path.join(BASE_DIR, 'data.h5'), 'r') as hf:
    # Iterate over dataset splits (train, val, test)
    print(f"Total splits: {len(hf)}")
    for split in hf:
        split_group = hf[split]
        print(f"  Split: {split}")
        print(f"  Total datasets: {len(split_group)}")

        # Iterate over datasets
        for dataset in split_group:
            dataset_group = split_group[dataset]
            total_samples = len(dataset_group.keys())
            print(f"    Dataset: {dataset}")
            print(f"    Total samples: {total_samples}")
            print(f"    Random sample:")

            # Get a random sample
            name = random.choice(list(dataset_group.keys()))
            structure = dataset_group[name]['structure']

            # Print the name, description, and data of the sample
            print(f"      Name: {name}")
            print(f"      Structure: {structure.shape}")
# Out:
# Total splits: 3
#   Split: test
#   Total datasets: 1
#     Dataset: world-11-29-2022-2
#     Total samples: 549
#     Random sample:
#       Name: f31be6e96d29cc13096b9ba881c88cd0f907ab7c32a6c008e2c3b1cf3c9fae22
#       Structure: (11, 11, 11)
#   Split: train
#   Total datasets: 1
#     Dataset: world-11-29-2022-2
#     Total samples: 2484
#     Random sample:
#       Name: 0f1c298683e722a932233b62c9d9f0c81109f973c55596c9061deac579fb2e85
#       Structure: (11, 11, 11)
#   Split: validation
#   Total datasets: 1
#     Dataset: world-11-29-2022-2
#     Total samples: 538
#     Random sample:
#       Name: d7b8bb917dd332b3d9a7228ab193f91db451ac493f5020ac69d79c9d888e0a52
#       Structure: (11, 11, 11)
