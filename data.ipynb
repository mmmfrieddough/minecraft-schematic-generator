# %% [markdown]
# Generate data

# %%
import random

from common import constants
from schematic_generator import generator

random.seed(0)

configs = [
    # Simple shapes
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": [lambda: random.randint(1, (constants.REGION_SIZE[0] // 2) - 1)] * 5,
        "structure_block_types": [[block] for block in constants.AIR] + [lambda: random.sample(constants.AIR, 3)] * len(constants.AIR),
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE]
    },
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": [lambda: random.randint(1, constants.REGION_SIZE[0] - 1)] * 5,
        "structure_block_types": [[block] for block in constants.AIR] + [lambda: random.sample(constants.AIR, 3)] * len(constants.AIR),
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE]
    },
    # Filled
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": [lambda: random.randint(3, (constants.REGION_SIZE[0] // 2) - 1)] * 3,
        "structure_block_types": [[block] for block in constants.AIR] + [lambda: random.sample(constants.AIR, 3)] * (len(constants.AIR) // 3),
        "structure_fill_block_types": [["minecraft:air"], lambda: random.sample(constants.AIR, 1), lambda: random.sample(constants.AIR, 3)],
        "thickness": [lambda: random.randint(1, 3)],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE]
    },
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": [lambda: random.randint(7, constants.REGION_SIZE[0] - 1)] * 3,
        "structure_block_types": [[block] for block in constants.AIR] + [lambda: random.sample(constants.AIR, 3)] * (len(constants.AIR) // 3),
        "structure_fill_block_types": [["minecraft:air"], lambda: random.sample(constants.AIR, 1), lambda: random.sample(constants.AIR, 3)],
        "thickness": [lambda: random.randint(1, 3)],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE]
    }
]

simple_cubes = [
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": range(1, min(constants.REGION_SIZE) + 1),
        "structure_block_types": [[block] for block in constants.SIMPLE_BLOCK_TYPES],
        "background_block_types": [[constants.AIR]],
        "position_offsets": [16],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.REGION_SIZE],
        "descriptions": [1000]
    }
]

# mixed_cubes = [
#     {
#         "generator_type": ["shape"],
#         "shape_type": ["cube"],
#         "side_length": range(3, min(constants.REGION_SIZE) - 1),
#         "structure_block_types": [random.sample(sample_blocks, random.randint(2, 4)) for _ in range(len(sample_blocks) // 5)],
#         "background_block_types": [["minecraft:air"]],
#         "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))] * 5,
#         "random_seed": [lambda: random.randint(0, 2**32 - 1)] * 10,
#         "region_size": [constants.REGION_SIZE]
#     }
# ]

# simple_spheres = [
#     {
#         "generator_type": ["shape"],
#         "shape_type": ["sphere"],
#         "radius": range(1, (min(constants.REGION_SIZE) // 2) - 1),
#         "structure_block_types": [[block] for block in sample_blocks],
#         "background_block_types": [["minecraft:air"]],
#         "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))] * 10,
#         "random_seed": [lambda: random.randint(0, 2**32 - 1)],
#         "region_size": [constants.REGION_SIZE]
#     }
# ]

# mixed_spheres = [
#     {
#         "generator_type": ["shape"],
#         "shape_type": ["sphere"],
#         "radius": range(1, (min(constants.REGION_SIZE) // 2) - 1),
#         "structure_block_types": [random.sample(sample_blocks, random.randint(2, 4)) for _ in range(len(sample_blocks) // 5)],
#         "background_block_types": [["minecraft:air"]],
#         "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))] * 5,
#         "random_seed": [lambda: random.randint(0, 2**32 - 1)] * 10,
#         "region_size": [constants.REGION_SIZE]
#     }
# ]

generator.generate_samples_from_configurations(simple_cubes, 'simple_cubes')
# generator.generate_samples_from_configurations(mixed_cubes, 'mixed_cubes')
# generator.generate_samples_from_configurations(simple_spheres, 'simple_spheres')
# generator.generate_samples_from_configurations(mixed_spheres, 'mixed_spheres')
# Out:
# Generating samples for simple_cubes: 100%|██████████| 24990/24990 [00:01<00:00, 14342.97it/s]

# %%
total_samples = 8250
print(f'Old total samples: {total_samples}')
total_per_block = total_samples // num_blocks
print(f'Old total per block: {total_per_block}')

print()
limit = 16
print(min(1**3, limit))
print(min(2**3, limit))
print(min(3**3, limit))
print(min(4**3, limit))
print(min(5**3, limit))
print(min(6**3, limit))
print(min(7**3, limit))
print(min(8**3, limit))
total = min(1**3, limit) + min(2**3, limit) + min(3**3, limit) + min(4**3, limit) + min(5**3, limit) + min(6**3, limit) + min(7**3, limit) + min(8**3, limit)
print(f'Total: {total}')
print(f'Total total: {total * len(constants.SIMPLE_BLOCK_TYPES)}')
print(f'Reduction: {((total_per_block - total) / total_per_block) * 100:.2f}%')

print()
print('Ratios:')
print(f'{(min(1**3, limit) / total) * 100:.2f}%')
print(f'{(min(2**3, limit) / total) * 100:.2f}%')
print(f'{(min(3**3, limit) / total) * 100:.2f}%')
print(f'{(min(4**3, limit) / total) * 100:.2f}%')
print(f'{(min(5**3, limit) / total) * 100:.2f}%')
print(f'{(min(6**3, limit) / total) * 100:.2f}%')
print(f'{(min(7**3, limit) / total) * 100:.2f}%')
print(f'{(min(8**3, limit) / total) * 100:.2f}%')

print()
increase = len(constants.SIMPLE_BLOCK_TYPES) // num_blocks
print(f'Increase: {increase}')
total_new = increase * total_samples
print(f'New total samples: {total_new}')
scaling_reduction = 0.1
total_reduced = int(total_new * scaling_reduction)
print(f'Reduced total samples: {total_reduced}')

print()
print(f'New total per block: {total_reduced // len(constants.SIMPLE_BLOCK_TYPES)}')
# Out:
# Old total samples: 8250
# Old total per block: 825
#
# 1
# 8
# 16
# 16
# 16
# 16
# 16
# 16
# Total: 105
# Total total: 24990
# Reduction: 87.27%
#
# Ratios:
# 0.95%
# 7.62%
# 15.24%
# 15.24%
# 15.24%
# 15.24%
# 15.24%
# 15.24%
#
# Increase: 23
# New total samples: 189750
# Reduced total samples: 18975
#
# New total per block: 79

# %% [markdown]
# Prepare data

# %%
from data_preparer import load_schematics

schematics_dir = 'data/schematics'
hdf5_path = 'data/data.h5'
load_schematics(schematics_dir, hdf5_path, (0.7, 0.15, 0.15))
# Out:
# Loading schematics from data/schematics into data/data.h5
# Processing generator type: simple_cubes
# Split data into 17633 training samples, 3649 validation samples, and 3708 test samples.
# Generating set: train: 100%|██████████| 17633/17633 [02:04<00:00, 141.15it/s]
# Generating set: validation: 100%|██████████| 3649/3649 [00:25<00:00, 141.98it/s]
# Generating set: test: 100%|██████████| 3708/3708 [00:26<00:00, 141.52it/s]
# Finished updating HDF5 file.

# %% [markdown]
# Check Data

# %%
import os

import h5py

from common.file_paths import BASE_DIR
import random

with h5py.File(os.path.join(BASE_DIR, 'data.h5'), 'r') as hf:
    # Iterate over dataset splits (train, val, test)
    print(f"Total splits: {len(hf)}")
    for split in hf:
        split_group = hf[split]
        print(f"  Split: {split}")
        print(f"  Total generator types: {len(split_group)}")

        # Iterate over generator types
        for generator_type in split_group:
            generator_group = split_group[generator_type]
            total_samples = len(generator_group.keys())
            print(f"    Generator Type: {generator_type}")
            print(f"    Total samples: {total_samples}")
            print(f"    Random sample:")

            # Get a random sample
            name = random.choice(list(generator_group.keys()))
            prompts = generator_group[name]['prompts']
            structure = generator_group[name]['structure']

            # Print the name, description, and data of the sample
            print(f"      Name: {name}")
            print(f"      Total Prompts: {len(prompts)}")
            print(f"      First 10 prompts:")
            for prompt in prompts[:10]:
                print(f"        {prompt.decode('utf-8')}")
            print(f"      Structure: {structure.shape}")
# Out:
# Total splits: 3
#   Split: test
#   Total generator types: 1
#     Generator Type: simple_cubes
#     Total samples: 1243
#     Random sample:
#       Name: dc81811590226fa960893c5019cd95f41a5361389ef14957000bb259e9099c29
#       Total Prompts: 1000
#       First 10 prompts:
#         A perfect cube, with a side length of 3 blocks.
#         A solid, perfect cube, made of end stone brick, with a side length of 3 blocks.
#         A perfect, end stone brick cube, with a side length of 3 blocks.
#         A cube. It is made of end stone brick. It is floating within an empty void. It has a side length of 3 blocks.
#         An end stone brick, 3 blocks wide, solid cube.
#         A 3 blocks wide, end stone brick cube. It is floating within an empty void.
#         A solid cube, made of end stone brick, with a side length of 3 blocks. It is floating within an empty void.
#         A solid cube, made of end stone brick. It has a side length of 3 blocks, floating within an empty void.
#         A solid, 3 blocks wide cube.
#         A solid, end stone brick, perfect cube, with a side length of 3 blocks, floating within an empty void.
#       Structure: (8, 8, 8)
#   Split: train
#   Total generator types: 1
#     Generator Type: simple_cubes
#     Total samples: 5788
#     Random sample:
#       Name: 496783772979ed72adf2fcd842d7a90f73fd4002110023f9dbb0a988a7fb96ce
#       Total Prompts: 1000
#       First 10 prompts:
#         A lime wool, solid cube, with a side length of 6 blocks.
#         A solid cube. It has a side length of 6 blocks. It is made of lime wool, floating within an empty void.
#         A cube. It is made of lime wool, floating within an empty void, with a side length of 6 blocks.
#         A cube. It is floating within an empty void, with a side length of 6 blocks, made of lime wool.
#         A solid, perfect cube, with a side length of 6 blocks. It is floating within an empty void, made of lime wool.
#         A solid cube, made of lime wool, with a side length of 6 blocks. It is floating within an empty void.
#         A solid, perfect, lime wool, 6 blocks wide cube. It is floating within an empty void.
#         A solid, perfect, lime wool cube, with a side length of 6 blocks, floating within an empty void.
#         A perfect cube. It is floating within an empty void. It is made of lime wool. It has a side length of 6 blocks.
#         A 6 blocks wide, perfect cube. It is made of lime wool, floating within an empty void.
#       Structure: (8, 8, 8)
#   Split: validation
#   Total generator types: 1
#     Generator Type: simple_cubes
#     Total samples: 1219
#     Random sample:
#       Name: cab1df1b99956bb822a9a6600e74fd64b9187e66ffd3ad791890bb088f33f5d0
#       Total Prompts: 1000
#       First 10 prompts:
#         A solid, perfect, 2 blocks wide cube.
#         A solid, lime stained glass cube, with a side length of 2 blocks.
#         A perfect cube. It has a side length of 2 blocks, made of lime stained glass. It is floating within an empty void.
#         A solid, perfect cube, with a side length of 2 blocks. It is floating within an empty void, made of lime stained glass.
#         A solid cube. It has a side length of 2 blocks, made of lime stained glass.
#         A perfect, solid cube, floating within an empty void. It is made of lime stained glass.
#         A perfect, solid cube, with a side length of 2 blocks. It is made of lime stained glass, floating within an empty void.
#         A solid, perfect cube. It has a side length of 2 blocks. It is made of lime stained glass.
#         A 2 blocks wide, solid, perfect, lime stained glass cube, floating within an empty void.
#         A cube. It is floating within an empty void.
#       Structure: (8, 8, 8)
