# %% [markdown]
# Generate data

# %%
import random

from common import constants
from schematic_generator import generator

random.seed(0)

configs = [
    # Simple shapes
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": [lambda: random.randint(1, (constants.region_size[0] // 2) - 1)] * 5,
        "structure_block_types": [[block] for block in constants.simple_block_types] + [lambda: random.sample(constants.simple_block_types, 3)] * len(constants.simple_block_types),
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.region_size]
    },
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": [lambda: random.randint(1, constants.region_size[0] - 1)] * 5,
        "structure_block_types": [[block] for block in constants.simple_block_types] + [lambda: random.sample(constants.simple_block_types, 3)] * len(constants.simple_block_types),
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.region_size]
    },
    # Filled
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": [lambda: random.randint(3, (constants.region_size[0] // 2) - 1)] * 3,
        "structure_block_types": [[block] for block in constants.simple_block_types] + [lambda: random.sample(constants.simple_block_types, 3)] * (len(constants.simple_block_types) // 3),
        "structure_fill_block_types": [["minecraft:air"], lambda: random.sample(constants.simple_block_types, 1), lambda: random.sample(constants.simple_block_types, 3)],
        "thickness": [lambda: random.randint(1, 3)],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.region_size]
    },
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": [lambda: random.randint(7, constants.region_size[0] - 1)] * 3,
        "structure_block_types": [[block] for block in constants.simple_block_types] + [lambda: random.sample(constants.simple_block_types, 3)] * (len(constants.simple_block_types) // 3),
        "structure_fill_block_types": [["minecraft:air"], lambda: random.sample(constants.simple_block_types, 1), lambda: random.sample(constants.simple_block_types, 3)],
        "thickness": [lambda: random.randint(1, 3)],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))],
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.region_size]
    }
]

num_blocks = 10
sample_blocks = random.sample(constants.simple_block_types, num_blocks)

simple_cubes = [
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": range(3, min(constants.region_size) - 1),
        "structure_block_types": [[block] for block in sample_blocks],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))] * 5,
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.region_size]
    }
]

mixed_cubes = [
    {
        "generator_type": ["shape"],
        "shape_type": ["cube"],
        "side_length": range(3, min(constants.region_size) - 1),
        "structure_block_types": [random.sample(sample_blocks, random.randint(2, 4)) for _ in range(len(sample_blocks) // 5)],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))] * 5,
        "random_seed": [lambda: random.randint(0, 2**32 - 1)] * 5,
        "region_size": [constants.region_size]
    }
]

simple_spheres = [
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": range(1, (min(constants.region_size) // 2) - 1),
        "structure_block_types": [[block] for block in sample_blocks],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))] * 5,
        "random_seed": [lambda: random.randint(0, 2**32 - 1)],
        "region_size": [constants.region_size]
    }
]

mixed_spheres = [
    {
        "generator_type": ["shape"],
        "shape_type": ["sphere"],
        "radius": range(1, (min(constants.region_size) // 2) - 1),
        "structure_block_types": [random.sample(sample_blocks, random.randint(2, 4)) for _ in range(len(sample_blocks) // 5)],
        "background_block_types": [["minecraft:air"]],
        "position_offset": [lambda: (random.randint(-100, 100), random.randint(-100, 100), random.randint(-100, 100))] * 5,
        "random_seed": [lambda: random.randint(0, 2**32 - 1)] * 5,
        "region_size": [constants.region_size]
    }
]

generator.generate_samples_from_configurations(simple_cubes, 'simple_cubes')
generator.generate_samples_from_configurations(mixed_cubes, 'mixed_cubes')
generator.generate_samples_from_configurations(simple_spheres, 'simple_spheres')
generator.generate_samples_from_configurations(mixed_spheres, 'mixed_spheres')
# Out:
# Generating samples for simple_cubes: 100%|██████████| 100/100 [00:00<00:00, 10002.87it/s]
# Generating samples for mixed_cubes: 100%|██████████| 100/100 [00:00<00:00, 15381.22it/s]
# Generating samples for simple_spheres: 100%|██████████| 50/50 [00:00<00:00, 16648.03it/s]
# Generating samples for mixed_spheres: 100%|██████████| 50/50 [00:00<00:00, 20009.08it/s]

# %% [markdown]
# Prepare data

# %%
from data_preparer import load_schematics

schematics_dir = 'data/schematics'
hdf5_path = 'data/data.h5'
load_schematics(schematics_dir, hdf5_path, (0.7, 0.15, 0.15))
# Out:
# Loading schematics from data/schematics into data/data.h5
# Processing generator type: mixed_cubes
# Split data into 73 training samples, 18 validation samples, and 9 test samples.
# Generating set: train: 100%|██████████| 73/73 [00:00<00:00, 523.18it/s]
# Generating set: validation: 100%|██████████| 18/18 [00:00<00:00, 600.04it/s]
# Generating set: test: 100%|██████████| 9/9 [00:00<00:00, 562.39it/s]
# Processing generator type: mixed_spheres
# Split data into 42 training samples, 3 validation samples, and 5 test samples.
# Generating set: train: 100%|██████████| 42/42 [00:00<00:00, 591.39it/s]
# Generating set: validation: 100%|██████████| 3/3 [00:00<00:00, 599.87it/s]
# Generating set: test: 100%|██████████| 5/5 [00:00<00:00, 625.16it/s]
# Processing generator type: simple_cubes
# Split data into 64 training samples, 16 validation samples, and 20 test samples.
# Generating set: train: 100%|██████████| 64/64 [00:00<00:00, 592.47it/s]
# Generating set: validation: 100%|██████████| 16/16 [00:00<00:00, 603.37it/s]
# Generating set: test: 100%|██████████| 20/20 [00:00<00:00, 624.99it/s]
# Processing generator type: simple_spheres
# Split data into 30 training samples, 7 validation samples, and 13 test samples.
# Generating set: train: 100%|██████████| 30/30 [00:00<00:00, 631.52it/s]
# Generating set: validation: 100%|██████████| 7/7 [00:00<00:00, 635.25it/s]
# Generating set: test: 100%|██████████| 13/13 [00:00<00:00, 619.05it/s]
# Finished updating HDF5 file.

# %% [markdown]
# Check Data

# %%
import os

import h5py

from common.file_paths import BASE_DIR
import random

with h5py.File(os.path.join(BASE_DIR, 'data.h5'), 'r') as hf:
    # Iterate over dataset splits (train, val, test)
    print(f"Total splits: {len(hf)}")
    for split in hf:
        split_group = hf[split]
        print(f"  Split: {split}")
        print(f"  Total generator types: {len(split_group)}")

        # Iterate over generator types
        for generator_type in split_group:
            generator_group = split_group[generator_type]
            total_samples = len(generator_group.keys())
            print(f"    Generator Type: {generator_type}")
            print(f"    Total samples: {total_samples}")
            print(f"    Random sample:")

            # Get a random sample
            name = random.choice(list(generator_group.keys()))
            prompts = generator_group[name]['prompts']
            structure = generator_group[name]['structure']

            # Print the name, description, and data of the sample
            print(f"      Name: {name}")
            print(f"      Prompts:")
            for prompt in prompts:
                print(f"        {prompt.decode('utf-8')}")
            print(f"      Structure: {structure.shape}")
# Out:
# Total splits: 3
#   Split: test
#   Total generator types: 4
#     Generator Type: mixed_cubes
#     Total samples: 9
#     Random sample:
#       Name: ee96f2938babdfa5aa32ff3ec083ff9416e8ea73b89eb1e9664c01f320845355
#       Prompts:
#         A perfect solid cube with a side length of 3 blocks. It is composed of raw iron block and crying obsidian. It is floating within an empty void.
#         A perfect solid cube made of raw iron block and crying obsidian, each side precisely 3 blocks, floating immaculately in a void.
#         An impeccably constructed raw iron block and crying obsidian cube, with 3 blocks along each edge, hovers in an empty void.
#         A flawless raw iron block and crying obsidian cube, 3 blocks in size, suspended in a void.
#         A meticulously crafted cube, perfect in geometry, made of raw iron block and crying obsidian and measuring 3 blocks per side, set against the backdrop of an empty void.
#         Visualize a raw iron block and crying obsidian cube, perfect in its construction, 3 blocks to a side, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: mixed_spheres
#     Total samples: 5
#     Random sample:
#       Name: f416385cb5d977b044e8c36664bf6aa05d775dc7e6362a7f031464a188991512
#       Prompts:
#         A perfect solid sphere with a radius of 2 blocks. It is composed of raw iron block, gray terracotta, and crying obsidian. It is floating within an empty void.
#         A perfect solid sphere made of raw iron block, gray terracotta, and crying obsidian, a radius of precisely 2 blocks, floating immaculately in a void.
#         An impeccably constructed raw iron block, gray terracotta, and crying obsidian sphere, with 2 blocks in radius, hovers in an empty void.
#         A flawless raw iron block, gray terracotta, and crying obsidian sphere, 2 blocks in radius, suspended in a void.
#         A meticulously crafted sphere, perfect in geometry, made of raw iron block, gray terracotta, and crying obsidian and measuring 2 blocks in radius, set against the backdrop of an empty void.
#         Visualize a raw iron block, gray terracotta, and crying obsidian sphere, perfect in its construction, 2 blocks in radius, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: simple_cubes
#     Total samples: 20
#     Random sample:
#       Name: fcb435d27191251e7b5282ab06d42fa5ad3b49f6240c3d8b682937292f6933af
#       Prompts:
#         A perfect solid cube with a side length of 6 blocks. It is composed of terracotta. It is floating within an empty void.
#         A perfect solid cube made of terracotta, each side precisely 6 blocks, floating immaculately in a void.
#         An impeccably constructed terracotta cube, with 6 blocks along each edge, hovers in an empty void.
#         A flawless terracotta cube, 6 blocks in size, suspended in a void.
#         A meticulously crafted cube, perfect in geometry, made of terracotta and measuring 6 blocks per side, set against the backdrop of an empty void.
#         Visualize a terracotta cube, perfect in its construction, 6 blocks to a side, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: simple_spheres
#     Total samples: 13
#     Random sample:
#       Name: edf5f884e986ad73bc4cf5f55b56e76a2c1681944f51a1ed458966e7c28ba136
#       Prompts:
#         A perfect solid sphere with a radius of 2 blocks. It is composed of deepslate iron ore. It is floating within an empty void.
#         A perfect solid sphere made of deepslate iron ore, a radius of precisely 2 blocks, floating immaculately in a void.
#         An impeccably constructed deepslate iron ore sphere, with 2 blocks in radius, hovers in an empty void.
#         A flawless deepslate iron ore sphere, 2 blocks in radius, suspended in a void.
#         A meticulously crafted sphere, perfect in geometry, made of deepslate iron ore and measuring 2 blocks in radius, set against the backdrop of an empty void.
#         Visualize a deepslate iron ore sphere, perfect in its construction, 2 blocks in radius, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#   Split: train
#   Total generator types: 4
#     Generator Type: mixed_cubes
#     Total samples: 73
#     Random sample:
#       Name: 0b28ac1a26cabda370380e89ebd126bf20fda171248250acb2cb63fd411aae8a
#       Prompts:
#         A perfect solid cube with a side length of 5 blocks. It is composed of raw iron block and crying obsidian. It is floating within an empty void.
#         A perfect solid cube made of raw iron block and crying obsidian, each side precisely 5 blocks, floating immaculately in a void.
#         An impeccably constructed raw iron block and crying obsidian cube, with 5 blocks along each edge, hovers in an empty void.
#         A flawless raw iron block and crying obsidian cube, 5 blocks in size, suspended in a void.
#         A meticulously crafted cube, perfect in geometry, made of raw iron block and crying obsidian and measuring 5 blocks per side, set against the backdrop of an empty void.
#         Visualize a raw iron block and crying obsidian cube, perfect in its construction, 5 blocks to a side, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: mixed_spheres
#     Total samples: 42
#     Random sample:
#       Name: 01a419f7597a2de8eca41a9fb508bdf1e1e171e32a28bfadeab99fc1f16d6b66
#       Prompts:
#         A perfect solid sphere with a radius of 1 block. It is composed of raw iron block, gray terracotta, and crying obsidian. It is floating within an empty void.
#         A perfect solid sphere made of raw iron block, gray terracotta, and crying obsidian, a radius of precisely 1 block, floating immaculately in a void.
#         An impeccably constructed raw iron block, gray terracotta, and crying obsidian sphere, with 1 block in radius, hovers in an empty void.
#         A flawless raw iron block, gray terracotta, and crying obsidian sphere, 1 block in radius, suspended in a void.
#         A meticulously crafted sphere, perfect in geometry, made of raw iron block, gray terracotta, and crying obsidian and measuring 1 block in radius, set against the backdrop of an empty void.
#         Visualize a raw iron block, gray terracotta, and crying obsidian sphere, perfect in its construction, 1 block in radius, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: simple_cubes
#     Total samples: 64
#     Random sample:
#       Name: 5124fa9ad7f1635bf6812117d311b0a0b649693c8bb642ab0d8d008407a20130
#       Prompts:
#         A perfect solid cube with a side length of 6 blocks. It is composed of gray terracotta. It is floating within an empty void.
#         A perfect solid cube made of gray terracotta, each side precisely 6 blocks, floating immaculately in a void.
#         An impeccably constructed gray terracotta cube, with 6 blocks along each edge, hovers in an empty void.
#         A flawless gray terracotta cube, 6 blocks in size, suspended in a void.
#         A meticulously crafted cube, perfect in geometry, made of gray terracotta and measuring 6 blocks per side, set against the backdrop of an empty void.
#         Visualize a gray terracotta cube, perfect in its construction, 6 blocks to a side, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: simple_spheres
#     Total samples: 30
#     Random sample:
#       Name: 07367aa4556c243cffddbd90af3e0b14efa46910d8b730106885e8f96c5a5b6e
#       Prompts:
#         A perfect solid sphere with a radius of 2 blocks. It is composed of terracotta. It is floating within an empty void.
#         A perfect solid sphere made of terracotta, a radius of precisely 2 blocks, floating immaculately in a void.
#         An impeccably constructed terracotta sphere, with 2 blocks in radius, hovers in an empty void.
#         A flawless terracotta sphere, 2 blocks in radius, suspended in a void.
#         A meticulously crafted sphere, perfect in geometry, made of terracotta and measuring 2 blocks in radius, set against the backdrop of an empty void.
#         Visualize a terracotta sphere, perfect in its construction, 2 blocks in radius, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#   Split: validation
#   Total generator types: 4
#     Generator Type: mixed_cubes
#     Total samples: 18
#     Random sample:
#       Name: d81edb419dc2683f77860dbcece90d3ec2bd286b159b1127a5b9f421e1eb71d7
#       Prompts:
#         A perfect solid cube with a side length of 4 blocks. It is composed of raw iron block and crying obsidian. It is floating within an empty void.
#         A perfect solid cube made of raw iron block and crying obsidian, each side precisely 4 blocks, floating immaculately in a void.
#         An impeccably constructed raw iron block and crying obsidian cube, with 4 blocks along each edge, hovers in an empty void.
#         A flawless raw iron block and crying obsidian cube, 4 blocks in size, suspended in a void.
#         A meticulously crafted cube, perfect in geometry, made of raw iron block and crying obsidian and measuring 4 blocks per side, set against the backdrop of an empty void.
#         Visualize a raw iron block and crying obsidian cube, perfect in its construction, 4 blocks to a side, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: mixed_spheres
#     Total samples: 3
#     Random sample:
#       Name: ca7219f7dff4eecedc7f6240c1c0cda5671a7158a7fce57b235982f1fb726213
#       Prompts:
#         A perfect solid sphere with a radius of 2 blocks. It is composed of raw iron block, gray terracotta, and crying obsidian. It is floating within an empty void.
#         A perfect solid sphere made of raw iron block, gray terracotta, and crying obsidian, a radius of precisely 2 blocks, floating immaculately in a void.
#         An impeccably constructed raw iron block, gray terracotta, and crying obsidian sphere, with 2 blocks in radius, hovers in an empty void.
#         A flawless raw iron block, gray terracotta, and crying obsidian sphere, 2 blocks in radius, suspended in a void.
#         A meticulously crafted sphere, perfect in geometry, made of raw iron block, gray terracotta, and crying obsidian and measuring 2 blocks in radius, set against the backdrop of an empty void.
#         Visualize a raw iron block, gray terracotta, and crying obsidian sphere, perfect in its construction, 2 blocks in radius, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: simple_cubes
#     Total samples: 16
#     Random sample:
#       Name: be6b48eceffea07d6db2305038ade81bc6675da0fe10629797e0df7d7e420438
#       Prompts:
#         A perfect solid cube with a side length of 4 blocks. It is composed of raw iron block. It is floating within an empty void.
#         A perfect solid cube made of raw iron block, each side precisely 4 blocks, floating immaculately in a void.
#         An impeccably constructed raw iron block cube, with 4 blocks along each edge, hovers in an empty void.
#         A flawless raw iron block cube, 4 blocks in size, suspended in a void.
#         A meticulously crafted cube, perfect in geometry, made of raw iron block and measuring 4 blocks per side, set against the backdrop of an empty void.
#         Visualize a raw iron block cube, perfect in its construction, 4 blocks to a side, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
#     Generator Type: simple_spheres
#     Total samples: 7
#     Random sample:
#       Name: d584c77c27c3c80d6bb984ef20dafbaab424236a6de013ad746c5d83ec7c51e6
#       Prompts:
#         A perfect solid sphere with a radius of 1 block. It is composed of gray terracotta. It is floating within an empty void.
#         A perfect solid sphere made of gray terracotta, a radius of precisely 1 block, floating immaculately in a void.
#         An impeccably constructed gray terracotta sphere, with 1 block in radius, hovers in an empty void.
#         A flawless gray terracotta sphere, 1 block in radius, suspended in a void.
#         A meticulously crafted sphere, perfect in geometry, made of gray terracotta and measuring 1 block in radius, set against the backdrop of an empty void.
#         Visualize a gray terracotta sphere, perfect in its construction, 1 block in radius, ethereally floating in an expansive void.
#       Structure: (8, 8, 8)
